# %%
# !pip install geopy
# !pip install folium
import pandas as pd
import math
import random
import folium
from geopy.distance import geodesic
# Out:
# Requirement already satisfied: geopy in c:\users\promi\anaconda3\lib\site-packages (2.4.1)
# Requirement already satisfied: geographiclib<3,>=1.52 in c:\users\promi\anaconda3\lib\site-packages (from geopy) (2.0)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\promi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\promi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\promi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\promi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\promi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\promi\anaconda3\lib\site-packages)
# Requirement already satisfied: folium in c:\users\promi\anaconda3\lib\site-packages (0.16.0)
# Requirement already satisfied: branca>=0.6.0 in c:\users\promi\anaconda3\lib\site-packages (from folium) (0.7.1)
# Requirement already satisfied: numpy in c:\users\promi\anaconda3\lib\site-packages (from folium) (1.26.4)
# Requirement already satisfied: requests in c:\users\promi\anaconda3\lib\site-packages (from folium) (2.28.1)
# Requirement already satisfied: xyzservices in c:\users\promi\anaconda3\lib\site-packages (from folium) (2024.4.0)
# Requirement already satisfied: jinja2>=2.9 in c:\users\promi\anaconda3\lib\site-packages (from folium) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\promi\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\promi\anaconda3\lib\site-packages (from requests->folium) (2023.5.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\promi\anaconda3\lib\site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\promi\anaconda3\lib\site-packages (from requests->folium) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\promi\anaconda3\lib\site-packages (from requests->folium) (3.4)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\promi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\promi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\promi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\promi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\promi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\promi\anaconda3\lib\site-packages)

# %%
# Load the charging stations data
charging_stations_df = pd.read_csv("Electric_Vehicle_Charging_Stations.csv")

# Load the places data
places_df = pd.read_csv("coordinates.csv")

# Concatenate "Station Name" and "Street Address" into a new column "Charging Stations"
charging_stations_df["Charging Stations"] = charging_stations_df["Station Name"] + ", " + charging_stations_df["Street Address"]
charging_stations_df = charging_stations_df.drop(columns=["Station Name", "Street Address"])

# Rename the "Places" column to "Locations" in places_df
places_df = places_df.rename(columns={"Places": "Locations"})

# Display the resulting DataFrames
print("Charging Stations DataFrame:")
print(charging_stations_df.head())
print("\nPlaces DataFrame:")
print(places_df.head())
# Out:
# Charging Stations DataFrame:
#            City              Access Days Time EV Level1 EVSE Num  \
# 0        Darien                24 hours daily               NONE
# 1       Meriden  24 hours, for Tesla use only               NONE
# 2  Beacon Falls                24 hours daily               NONE
# 3  Old Saybrook                24 hours daily               NONE
# 4     Fairfield                24 hours daily               NONE
#
#   EV Level2 EVSE Num EV DC Fast Count  Longitude   Latitude  \
# 0                  2             NONE -73.476469  41.072882
# 1               NONE                8 -72.773473  41.527367
# 2                  1             NONE -73.065583  41.445481
# 3                  2             NONE -72.382500  41.310278
# 4                  2             NONE -73.264511  41.143125
#
#                                    Charging Stations
# 0                    BMW OF DARIEN, 138-142 Ledge Rd
# 1        Dunkin’ - Tesla Supercharger, 893 E Main St
# 2  Town of Beacon Falls - Commuter Lot, 105 N Mai...
# 3            OLD SAYBROOK VW, 319 Middlesex Turnpike
# 4           Fairfield Rail Station, 80 Mill Plain Rd
#
# Places DataFrame:
#                                      Locations            City  Longitude  \
# 0                    Connecticut State Capitol        Hartford -72.682280
# 1  Pratt & Whitney Stadium at Rentschler Field   East Hartford -72.618568
# 2                  Talcott Mountain State Park        Simsbury -72.790860
# 3                       New England Air Museum   Windsor Locks -72.691551
# 4               Phelps-Hatheway House & Garden        Suffield -72.652436
#
#     Latitude
# 0  41.764263
# 1  41.759965
# 2  41.835535
# 3  41.947718
# 4  41.980224

# %%
# Create a distance matrix
distance_matrix = pd.DataFrame(index=charging_stations_df["Charging Stations"], columns=places_df["Locations"])

for idx, row in charging_stations_df.iterrows():
    for col in places_df["Locations"]:
        station_coords = (row["Latitude"], row["Longitude"])
        place_coords = (places_df.loc[places_df["Locations"] == col, "Latitude"].values[0],
                        places_df.loc[places_df["Locations"] == col, "Longitude"].values[0])
        distance = geodesic(station_coords, place_coords).miles
        distance_matrix.at[row["Charging Stations"], col] = distance

# %%
# Create a distance matrix with distance for qualifying charging stations
qualifying_charging_stations = charging_stations_df[
    (charging_stations_df["Access Days Time"].str.contains("24 hours")) &
    (
        (pd.to_numeric(charging_stations_df["EV Level2 EVSE Num"], errors='coerce') > 0) |
        (pd.to_numeric(charging_stations_df["EV DC Fast Count"], errors='coerce') > 0)
    )]

qualifying_distance_matrix = pd.DataFrame(index=qualifying_charging_stations["Charging Stations"], columns=places_df["Locations"])

for idx, row in qualifying_charging_stations.iterrows():
    for col in places_df["Locations"]:
        qualifying_distance_matrix.at[row["Charging Stations"], col] = distance_matrix.at[row["Charging Stations"], col]
print(qualifying_distance_matrix)
# Out:
# Locations                                          Connecticut State Capitol  \
# Charging Stations
# BMW OF DARIEN, 138-142 Ledge Rd                                    63.075025
# Dunkin’ - Tesla Supercharger, 893 E Main St                        17.016899
# Town of Beacon Falls - Commuter Lot, 105 N Main St                 29.634424
# OLD SAYBROOK VW, 319 Middlesex Turnpike                            34.974589
# Fairfield Rail Station, 80 Mill Plain Rd                           52.451869
# ...                                                                      ...
# Yankee Doodle, 10 Burnell Boulevard                                58.620315
# 777 MAIN ST, 71 Asylum St                                            0.43666
# Norwich Public Utilities, 173 N Main St                            35.955034
# Fairfield Plaza, 116 Danbury Rd                                    40.647661
# Eastern Connecticut State University - Shakespe...                 24.568266
#
# Locations                                          Pratt & Whitney Stadium at Rentschler Field  \
# Charging Stations
# BMW OF DARIEN, 138-142 Ledge Rd                                                      65.072244
# Dunkin’ - Tesla Supercharger, 893 E Main St                                          17.943901
# Town of Beacon Falls - Commuter Lot, 105 N Main St                                   31.736536
# OLD SAYBROOK VW, 319 Middlesex Turnpike                                              33.360795
# Fairfield Rail Station, 80 Mill Plain Rd                                             54.192729
# ...                                                                                        ...
# Yankee Doodle, 10 Burnell Boulevard                                                  60.603389
# 777 MAIN ST, 71 Asylum St                                                              2.92534
# Norwich Public Utilities, 173 N Main St                                              32.906167
# Fairfield Plaza, 116 Danbury Rd                                                      43.655525
# Eastern Connecticut State University - Shakespe...                                   21.263523
#
# Locations                                          Talcott Mountain State Park  \
# Charging Stations
# BMW OF DARIEN, 138-142 Ledge Rd                                      63.538031
# Dunkin’ - Tesla Supercharger, 893 E Main St                          21.286911
# Town of Beacon Falls - Commuter Lot, 105 N Main St                   30.445097
# OLD SAYBROOK VW, 319 Middlesex Turnpike                               41.97464
# Fairfield Rail Station, 80 Mill Plain Rd                             53.734502
# ...                                                                        ...
# Yankee Doodle, 10 Burnell Boulevard                                  59.168283
# 777 MAIN ST, 71 Asylum St                                             7.662389
# Norwich Public Utilities, 173 N Main St                              43.217362
# Fairfield Plaza, 116 Danbury Rd                                      37.677779
# Eastern Connecticut State University - Shakespe...                   30.833753
#
# Locations                                          New England Air Museum  \
# Charging Stations
# BMW OF DARIEN, 138-142 Ledge Rd                                 72.820038
# Dunkin’ - Tesla Supercharger, 893 E Main St                     29.317788
# Town of Beacon Falls - Commuter Lot, 105 N Main St              39.695127
# OLD SAYBROOK VW, 319 Middlesex Turnpike                         46.811831
# Fairfield Rail Station, 80 Mill Plain Rd                        62.972962
# ...                                                                   ...
# Yankee Doodle, 10 Burnell Boulevard                             68.451176
# 777 MAIN ST, 71 Asylum St                                       12.525848
# Norwich Public Utilities, 173 N Main St                         43.527771
# Fairfield Plaza, 116 Danbury Rd                                 46.193449
# Eastern Connecticut State University - Shakespe...              28.821954
#
# Locations                                          Phelps-Hatheway House & Garden  \
# Charging Stations
# BMW OF DARIEN, 138-142 Ledge Rd                                         75.809603
# Dunkin’ - Tesla Supercharger, 893 E Main St                             31.873587
# Town of Beacon Falls - Commuter Lot, 105 N Main St                       42.64275
# OLD SAYBROOK VW, 319 Middlesex Turnpike                                 48.300665
# Fairfield Rail Station, 80 Mill Plain Rd                                65.907882
# ...                                                                           ...
# Yankee Doodle, 10 Burnell Boulevard                                     71.435252
# 777 MAIN ST, 71 Asylum St                                               14.782011
# Norwich Public Utilities, 173 N Main St                                 43.613563
# Fairfield Plaza, 116 Danbury Rd                                         49.140055
# Eastern Connecticut State University - Shakespe...                      28.347623
#
# Locations                                          Connecticut Trolley Museum  \
# Charging Stations
# BMW OF DARIEN, 138-142 Ledge Rd                                     75.117788
# Dunkin’ - Tesla Supercharger, 893 E Main St                         29.346734
# Town of Beacon Falls - Commuter Lot, 105 N Main St                  41.690526
# OLD SAYBROOK VW, 319 Middlesex Turnpike                             43.734654
# Fairfield Rail Station, 80 Mill Plain Rd                            64.729027
# ...                                                                       ...
# Yankee Doodle, 10 Burnell Boulevard                                 70.686952
# 777 MAIN ST, 71 Asylum St                                           12.105365
# Norwich Public Utilities, 173 N Main St                               38.3069
# Fairfield Plaza, 116 Danbury Rd                                     50.312083
# Eastern Connecticut State University - Shakespe...                  23.105315
#
# Locations                                          Shenipsit State Forest  \
# Charging Stations
# BMW OF DARIEN, 138-142 Ledge Rd                                 82.653065
# Dunkin’ - Tesla Supercharger, 893 E Main St                     35.419798
# Town of Beacon Falls - Commuter Lot, 105 N Main St              49.240636
# OLD SAYBROOK VW, 319 Middlesex Turnpike                         44.971616
# Fairfield Rail Station, 80 Mill Plain Rd                        71.840092
# ...                                                                   ...
# Yankee Doodle, 10 Burnell Boulevard                             78.190201
# 777 MAIN ST, 71 Asylum St                                       19.226618
# Norwich Public Utilities, 173 N Main St                         34.854318
# Fairfield Plaza, 116 Danbury Rd                                 59.152245
# Eastern Connecticut State University - Shakespe...               18.53591
#
# Locations                                          University of Connecticut  \
# Charging Stations
# BMW OF DARIEN, 138-142 Ledge Rd                                    81.251133
# Dunkin’ - Tesla Supercharger, 893 E Main St                        33.122307
# Town of Beacon Falls - Commuter Lot, 105 N Main St                 48.899397
# OLD SAYBROOK VW, 319 Middlesex Turnpike                            34.971529
# Fairfield Rail Station, 80 Mill Plain Rd                           69.673432
# ...                                                                      ...
# Yankee Doodle, 10 Burnell Boulevard                                76.794956
# 777 MAIN ST, 71 Asylum St                                          21.903229
# Norwich Public Utilities, 173 N Main St                            21.702251
# Fairfield Plaza, 116 Danbury Rd                                    62.633156
# Eastern Connecticut State University - Shakespe...                  5.327873
#
# Locations                                          Patriots Park  \
# Charging Stations
# BMW OF DARIEN, 138-142 Ledge Rd                        77.386431
# Dunkin’ - Tesla Supercharger, 893 E Main St            29.291907
# Town of Beacon Falls - Commuter Lot, 105 N Main St     45.149228
# OLD SAYBROOK VW, 319 Middlesex Turnpike                31.778619
# Fairfield Rail Station, 80 Mill Plain Rd               65.788387
# ...                                                          ...
# Yankee Doodle, 10 Burnell Boulevard                    72.933234
# 777 MAIN ST, 71 Asylum St                              19.006567
# Norwich Public Utilities, 173 N Main St                20.781074
# Fairfield Plaza, 116 Danbury Rd                        59.293413
# Eastern Connecticut State University - Shakespe...      5.459239
#
# Locations                                          Wadsworth Falls State Park  \
# Charging Stations
# BMW OF DARIEN, 138-142 Ledge Rd                                     52.126887
# Dunkin’ - Tesla Supercharger, 893 E Main St                           4.58151
# Town of Beacon Falls - Commuter Lot, 105 N Main St                   20.68015
# OLD SAYBROOK VW, 319 Middlesex Turnpike                             22.208087
# Fairfield Rail Station, 80 Mill Plain Rd                            40.541692
# ...                                                                       ...
# Yankee Doodle, 10 Burnell Boulevard                                 47.678455
# 777 MAIN ST, 71 Asylum St                                           15.868392
# Norwich Public Utilities, 173 N Main St                             32.288206
# Fairfield Plaza, 116 Danbury Rd                                     37.954996
# Eastern Connecticut State University - Shakespe...                  28.388461
#
# Locations                                           ... Mystic Seaport Museum  \
# Charging Stations                                   ...
# BMW OF DARIEN, 138-142 Ledge Rd                     ...             81.286476
# Dunkin’ - Tesla Supercharger, 893 E Main St         ...             43.572482
# Town of Beacon Falls - Commuter Lot, 105 N Main St  ...              57.53549
# OLD SAYBROOK VW, 319 Middlesex Turnpike             ...             22.053499
# Fairfield Rail Station, 80 Mill Plain Rd            ...             69.385182
# ...                                                 ...                   ...
# Yankee Doodle, 10 Burnell Boulevard                 ...             77.421964
# 777 MAIN ST, 71 Asylum St                           ...             46.251858
# Norwich Public Utilities, 173 N Main St             ...             12.591171
# Fairfield Plaza, 116 Danbury Rd                     ...             76.671675
# Eastern Connecticut State University - Shakespe...  ...             28.957032
#
# Locations                                          Mohegan Park  \
# Charging Stations
# BMW OF DARIEN, 138-142 Ledge Rd                       80.304596
# Dunkin’ - Tesla Supercharger, 893 E Main St           36.624893
# Town of Beacon Falls - Commuter Lot, 105 N Main St    52.258092
# OLD SAYBROOK VW, 319 Middlesex Turnpike               23.168826
# Fairfield Rail Station, 80 Mill Plain Rd              68.227917
# ...                                                         ...
# Yankee Doodle, 10 Burnell Boulevard                   76.102935
# 777 MAIN ST, 71 Asylum St                             34.839318
# Norwich Public Utilities, 173 N Main St                1.434347
# Fairfield Plaza, 116 Danbury Rd                       69.983793
# Eastern Connecticut State University - Shakespe...    15.021651
#
# Locations                                          Rotary Park & Bandstand  \
# Charging Stations
# BMW OF DARIEN, 138-142 Ledge Rd                                  99.950863
# Dunkin’ - Tesla Supercharger, 893 E Main St                       52.07102
# Town of Beacon Falls - Commuter Lot, 105 N Main St               68.020206
# OLD SAYBROOK VW, 319 Middlesex Turnpike                          48.470468
# Fairfield Rail Station, 80 Mill Plain Rd                          88.19432
# ...                                                                    ...
# Yankee Doodle, 10 Burnell Boulevard                              95.521123
# 777 MAIN ST, 71 Asylum St                                        40.741615
# Norwich Public Utilities, 173 N Main St                           28.00758
# Fairfield Plaza, 116 Danbury Rd                                  81.737043
# Eastern Connecticut State University - Shakespe...               19.666604
#
# Locations                                          Windham Textile & History Museum  \
# Charging Stations
# BMW OF DARIEN, 138-142 Ledge Rd                                           79.374102
# Dunkin’ - Tesla Supercharger, 893 E Main St                               32.018482
# Town of Beacon Falls - Commuter Lot, 105 N Main St                        48.179773
# OLD SAYBROOK VW, 319 Middlesex Turnpike                                   29.133887
# Fairfield Rail Station, 80 Mill Plain Rd                                  67.528757
# ...                                                                             ...
# Yankee Doodle, 10 Burnell Boulevard                                       74.971471
# 777 MAIN ST, 71 Asylum St                                                   24.5358
# Norwich Public Utilities, 173 N Main St                                   14.641373
# Fairfield Plaza, 116 Danbury Rd                                           63.637844
# Eastern Connecticut State University - Shakespe...                         1.910819
#
# Locations                                          Kettletown State Park  \
# Charging Stations
# BMW OF DARIEN, 138-142 Ledge Rd                                28.267775
# Dunkin’ - Tesla Supercharger, 893 E Main St                    23.397717
# Town of Beacon Falls - Commuter Lot, 105 N Main St              7.307301
# OLD SAYBROOK VW, 319 Middlesex Turnpike                        43.472379
# Fairfield Rail Station, 80 Mill Plain Rd                        19.85611
# ...                                                                  ...
# Yankee Doodle, 10 Burnell Boulevard                            23.993672
# 777 MAIN ST, 71 Asylum St                                      36.080589
# Norwich Public Utilities, 173 N Main St                        59.604065
# Fairfield Plaza, 116 Danbury Rd                                14.258022
# Eastern Connecticut State University - Shakespe...              55.90512
#
# Locations                                          Tarrywile Park & Mansion  \
# Charging Stations
# BMW OF DARIEN, 138-142 Ledge Rd                                   21.203763
# Dunkin’ - Tesla Supercharger, 893 E Main St                       36.690559
# Town of Beacon Falls - Commuter Lot, 105 N Main St                20.599557
# OLD SAYBROOK VW, 319 Middlesex Turnpike                           55.841616
# Fairfield Rail Station, 80 Mill Plain Rd                          19.025081
# ...                                                                     ...
# Yankee Doodle, 10 Burnell Boulevard                               18.155599
# 777 MAIN ST, 71 Asylum St                                         48.358351
# Norwich Public Utilities, 173 N Main St                           72.824161
# Fairfield Plaza, 116 Danbury Rd                                    12.39794
# Eastern Connecticut State University - Shakespe...                 69.08624
#
# Locations                                          Lover's Leap State Park  \
# Charging Stations
# BMW OF DARIEN, 138-142 Ledge Rd                                  32.632079
# Dunkin’ - Tesla Supercharger, 893 E Main St                      32.957768
# Town of Beacon Falls - Commuter Lot, 105 N Main St               19.033321
# OLD SAYBROOK VW, 319 Middlesex Turnpike                          55.668767
# Fairfield Rail Station, 80 Mill Plain Rd                         28.594933
# ...                                                                    ...
# Yankee Doodle, 10 Burnell Boulevard                               29.32737
# 777 MAIN ST, 71 Asylum St                                        41.019611
# Norwich Public Utilities, 173 N Main St                          69.761637
# Fairfield Plaza, 116 Danbury Rd                                   1.094021
# Eastern Connecticut State University - Shakespe...               63.602557
#
# Locations                                          Burr Pond State Park  \
# Charging Stations
# BMW OF DARIEN, 138-142 Ledge Rd                               58.542312
# Dunkin’ - Tesla Supercharger, 893 E Main St                   28.865341
# Town of Beacon Falls - Commuter Lot, 105 N Main St            29.366873
# OLD SAYBROOK VW, 319 Middlesex Turnpike                       53.367977
# Fairfield Rail Station, 80 Mill Plain Rd                      50.985672
# ...                                                                 ...
# Yankee Doodle, 10 Burnell Boulevard                           54.558472
# 777 MAIN ST, 71 Asylum St                                     22.742357
# Norwich Public Utilities, 173 N Main St                       58.248532
# Fairfield Plaza, 116 Danbury Rd                               27.381543
# Eastern Connecticut State University - Shakespe...            46.567575
#
# Locations                                          Lake Compounce  \
# Charging Stations
# BMW OF DARIEN, 138-142 Ledge Rd                         48.637391
# Dunkin’ - Tesla Supercharger, 893 E Main St             10.997149
# Town of Beacon Falls - Commuter Lot, 105 N Main St      15.385367
# OLD SAYBROOK VW, 319 Middlesex Turnpike                 36.137011
# Fairfield Rail Station, 80 Mill Plain Rd                38.670601
# ...                                                           ...
# Yankee Doodle, 10 Burnell Boulevard                     44.233124
# 777 MAIN ST, 71 Asylum St                               15.493991
# Norwich Public Utilities, 173 N Main St                 45.190237
# Fairfield Plaza, 116 Danbury Rd                         26.286225
# Eastern Connecticut State University - Shakespe...      37.567124
#
# Locations                                          Hill-Stead Museum
# Charging Stations
# BMW OF DARIEN, 138-142 Ledge Rd                            56.292216
# Dunkin’ - Tesla Supercharger, 893 E Main St                13.654466
# Town of Beacon Falls - Commuter Lot, 105 N Main St         22.925067
# OLD SAYBROOK VW, 319 Middlesex Turnpike                     36.38222
# Fairfield Rail Station, 80 Mill Plain Rd                   46.129213
# ...                                                              ...
# Yankee Doodle, 10 Burnell Boulevard                        51.874435
# 777 MAIN ST, 71 Asylum St                                   8.152284
# Norwich Public Utilities, 173 N Main St                    41.432302
# Fairfield Plaza, 116 Danbury Rd                            32.936819
# Eastern Connecticut State University - Shakespe...         31.678699
#
# [301 rows x 34 columns]

# %%
# Create a location distance matrix
location_distance_matrix = pd.DataFrame(index=places_df["Locations"], columns=places_df["Locations"])

for idx1, row1 in places_df.iterrows():
    for idx2, row2 in places_df.iterrows():
        location1_coords = (row1["Latitude"], row1["Longitude"])
        location2_coords = (row2["Latitude"], row2["Longitude"])
        distance = geodesic(location1_coords, location2_coords).miles
        location_distance_matrix.at[row1["Locations"], row2["Locations"]] = distance

# Display the location distance matrix
print("Location Distance Matrix:")
print(location_distance_matrix)
# Out:
# Location Distance Matrix:
# Locations                                   Connecticut State Capitol  \
# Locations
# Connecticut State Capitol                                         0.0
# Pratt & Whitney Stadium at Rentschler Field                  3.305513
# Talcott Mountain State Park                                  7.459013
# New England Air Museum                                      12.670356
# Phelps-Hatheway House & Garden                              14.984078
# Connecticut Trolley Museum                                  12.426005
# Shenipsit State Forest                                      19.631927
# University of Connecticut                                   22.325602
# Patriots Park                                               19.411611
# Wadsworth Falls State Park                                  15.691763
# Hubbard Park                                                16.901365
# Wharton Brook State Park                                    24.752078
# Yale University                                             33.325053
# Sleeping Giant State Park                                    26.22279
# Boothe Memorial Park and Museum                             42.711079
# Seaside Park                                                49.186032
# The Maritime Aquarium                                       59.570117
# Stamford Museum & Nature Center                             62.838247
# Bruce Museum                                                70.915352
# Westport Country Playhouse                                  55.335878
# Fairfield Museum and History Center                         52.097025
# Pequonnock River Trail                                      42.010175
# Silver Sands State Park                                     43.753013
# Fort Trumbull State Park                                     42.10342
# Mystic Seaport Museum                                       46.475617
# Mohegan Park                                                35.133745
# Rotary Park & Bandstand                                     41.174668
# Windham Textile & History Museum                            24.910038
# Kettletown State Park                                       35.665304
# Tarrywile Park & Mansion                                    47.929578
# Lover's Leap State Park                                     40.582972
# Burr Pond State Park                                        22.414253
# Lake Compounce                                              15.066512
# Hill-Stead Museum                                             7.71563
#
# Locations                                   Pratt & Whitney Stadium at Rentschler Field  \
# Locations
# Connecticut State Capitol                                                      3.305513
# Pratt & Whitney Stadium at Rentschler Field                                         0.0
# Talcott Mountain State Park                                                   10.313711
# New England Air Museum                                                        13.494078
# Phelps-Hatheway House & Garden                                                 15.30149
# Connecticut Trolley Museum                                                    11.692456
# Shenipsit State Forest                                                        17.648036
# University of Connecticut                                                     19.119187
# Patriots Park                                                                 16.126857
# Wadsworth Falls State Park                                                    15.785157
# Hubbard Park                                                                  18.447182
# Wharton Brook State Park                                                      25.746877
# Yale University                                                               34.430711
# Sleeping Giant State Park                                                     27.545941
# Boothe Memorial Park and Museum                                               44.273593
# Seaside Park                                                                  50.787443
# The Maritime Aquarium                                                         61.522157
# Stamford Museum & Nature Center                                               65.040615
# Bruce Museum                                                                   73.03012
# Westport Country Playhouse                                                    57.258983
# Fairfield Museum and History Center                                           53.798252
# Pequonnock River Trail                                                         44.18988
# Silver Sands State Park                                                       45.105939
# Fort Trumbull State Park                                                      39.557751
# Mystic Seaport Museum                                                         43.687972
# Mohegan Park                                                                  32.043024
# Rotary Park & Bandstand                                                       38.089947
# Windham Textile & History Museum                                              21.610488
# Kettletown State Park                                                         38.049175
# Tarrywile Park & Mansion                                                      50.558272
# Lover's Leap State Park                                                       43.554294
# Burr Pond State Park                                                          25.632739
# Lake Compounce                                                                 17.74258
# Hill-Stead Museum                                                              10.76093
#
# Locations                                   Talcott Mountain State Park  \
# Locations
# Connecticut State Capitol                                      7.459013
# Pratt & Whitney Stadium at Rentschler Field                   10.313711
# Talcott Mountain State Park                                         0.0
# New England Air Museum                                         9.282897
# Phelps-Hatheway House & Garden                                12.273853
# Connecticut Trolley Museum                                    12.634645
# Shenipsit State Forest                                        21.562537
# University of Connecticut                                     27.782438
# Patriots Park                                                 25.447602
# Wadsworth Falls State Park                                    21.310879
# Hubbard Park                                                  19.964701
# Wharton Brook State Park                                      28.429212
# Yale University                                               36.474165
# Sleeping Giant State Park                                     29.155712
# Boothe Memorial Park and Museum                               44.602144
# Seaside Park                                                  50.871589
# The Maritime Aquarium                                         60.195744
# Stamford Museum & Nature Center                               62.695674
# Bruce Museum                                                  70.970639
# Westport Country Playhouse                                    56.089933
# Fairfield Museum and History Center                           53.487585
# Pequonnock River Trail                                        42.227466
# Silver Sands State Park                                       46.124782
# Fort Trumbull State Park                                      49.558532
# Mystic Seaport Museum                                         53.912339
# Mohegan Park                                                   42.34241
# Rotary Park & Bandstand                                       45.727951
# Windham Textile & History Museum                              31.431509
# Kettletown State Park                                         35.383485
# Tarrywile Park & Mansion                                      46.517208
# Lover's Leap State Park                                       37.805346
# Burr Pond State Park                                          15.752389
# Lake Compounce                                                15.064613
# Hill-Stead Museum                                              7.980657
#
# Locations                                   New England Air Museum  \
# Locations
# Connecticut State Capitol                                12.670356
# Pratt & Whitney Stadium at Rentschler Field              13.494078
# Talcott Mountain State Park                               9.282897
# New England Air Museum                                         0.0
# Phelps-Hatheway House & Garden                            3.015383
# Connecticut Trolley Museum                                6.007109
# Shenipsit State Forest                                   14.626535
# University of Connecticut                                24.550286
# Patriots Park                                            23.444868
# Wadsworth Falls State Park                               28.353311
# Hubbard Park                                             28.564044
# Wharton Brook State Park                                 36.851561
# Yale University                                          45.183303
# Sleeping Giant State Park                                37.907581
# Boothe Memorial Park and Museum                          53.727783
# Seaside Park                                             60.048593
# The Maritime Aquarium                                    69.478219
# Stamford Museum & Nature Center                          71.941868
# Bruce Museum                                             80.230041
# Westport Country Playhouse                               65.368746
# Fairfield Museum and History Center                      62.712744
# Pequonnock River Trail                                   51.509129
# Silver Sands State Park                                  55.135879
# Fort Trumbull State Park                                 51.901526
# Mystic Seaport Museum                                    55.286493
# Mohegan Park                                             42.428739
# Rotary Park & Bandstand                                  40.279311
# Windham Textile & History Museum                         29.933396
# Kettletown State Park                                    44.649313
# Tarrywile Park & Mansion                                 55.562933
# Lover's Leap State Park                                  46.413644
# Burr Pond State Park                                     21.347877
# Lake Compounce                                            24.31004
# Hill-Stead Museum                                        16.937335
#
# Locations                                   Phelps-Hatheway House & Garden  \
# Locations
# Connecticut State Capitol                                        14.984078
# Pratt & Whitney Stadium at Rentschler Field                       15.30149
# Talcott Mountain State Park                                      12.273853
# New England Air Museum                                            3.015383
# Phelps-Hatheway House & Garden                                         0.0
# Connecticut Trolley Museum                                        5.308687
# Shenipsit State Forest                                           12.642028
# University of Connecticut                                        23.746233
# Patriots Park                                                    23.115752
# Wadsworth Falls State Park                                       30.644581
# Hubbard Park                                                     31.287255
# Wharton Brook State Park                                         39.491005
# Yale University                                                   47.90075
# Sleeping Giant State Park                                        40.652518
# Boothe Memorial Park and Museum                                  56.603106
# Seaside Park                                                     62.947538
# The Maritime Aquarium                                            72.458748
# Stamford Museum & Nature Center                                  74.951411
# Bruce Museum                                                     83.236212
# Westport Country Playhouse                                       68.340569
# Fairfield Museum and History Center                              65.638918
# Pequonnock River Trail                                           54.499801
# Silver Sands State Park                                          57.959503
# Fort Trumbull State Park                                         52.572709
# Mystic Seaport Museum                                            55.625645
# Mohegan Park                                                     42.452652
# Rotary Park & Bandstand                                          38.446447
# Windham Textile & History Museum                                 29.612282
# Kettletown State Park                                            47.652598
# Tarrywile Park & Mansion                                         58.573104
# Lover's Leap State Park                                           49.37386
# Burr Pond State Park                                             23.913329
# Lake Compounce                                                   27.262282
# Hill-Stead Museum                                                19.816682
#
# Locations                                   Connecticut Trolley Museum  \
# Locations
# Connecticut State Capitol                                    12.426005
# Pratt & Whitney Stadium at Rentschler Field                  11.692456
# Talcott Mountain State Park                                  12.634645
# New England Air Museum                                        6.007109
# Phelps-Hatheway House & Garden                                5.308687
# Connecticut Trolley Museum                                         0.0
# Shenipsit State Forest                                        9.093944
# University of Connecticut                                    18.642831
# Patriots Park                                                17.830134
# Wadsworth Falls State Park                                   27.470621
# Hubbard Park                                                 29.319744
# Wharton Brook State Park                                     37.125062
# Yale University                                              45.734139
# Sleeping Giant State Park                                     38.64879
# Boothe Memorial Park and Museum                              55.086325
# Seaside Park                                                 61.539756
# The Maritime Aquarium                                        71.666303
# Stamford Museum & Nature Center                              74.618485
# Bruce Museum                                                 82.800901
# Westport Country Playhouse                                   67.467974
# Fairfield Museum and History Center                          64.398258
# Pequonnock River Trail                                       53.900459
# Silver Sands State Park                                      56.174175
# Fort Trumbull State Park                                     47.400232
# Mystic Seaport Museum                                        50.347769
# Mohegan Park                                                 37.144085
# Rotary Park & Bandstand                                       34.40587
# Windham Textile & History Museum                             24.331737
# Kettletown State Park                                        47.290921
# Tarrywile Park & Mansion                                     58.919391
# Lover's Leap State Park                                      50.433409
# Burr Pond State Park                                         26.790687
# Lake Compounce                                               26.556763
# Hill-Stead Museum                                            18.858902
#
# Locations                                   Shenipsit State Forest  \
# Locations
# Connecticut State Capitol                                19.631927
# Pratt & Whitney Stadium at Rentschler Field              17.648036
# Talcott Mountain State Park                              21.562537
# New England Air Museum                                   14.626535
# Phelps-Hatheway House & Garden                           12.642028
# Connecticut Trolley Museum                                9.093944
# Shenipsit State Forest                                         0.0
# University of Connecticut                                13.270304
# Patriots Park                                            14.405933
# Wadsworth Falls State Park                               32.639037
# Hubbard Park                                             36.095174
# Wharton Brook State Park                                  43.17895
# Yale University                                          51.881285
# Sleeping Giant State Park                                45.136678
# Boothe Memorial Park and Museum                          61.908741
# Seaside Park                                             68.426853
# The Maritime Aquarium                                    79.123152
# Stamford Museum & Nature Center                            82.4701
# Bruce Museum                                             90.537042
# Westport Country Playhouse                               74.870234
# Fairfield Museum and History Center                      71.446203
# Pequonnock River Trail                                   61.638842
# Silver Sands State Park                                  62.669583
# Fort Trumbull State Park                                 45.619142
# Mystic Seaport Museum                                    47.388765
# Mohegan Park                                             33.528545
# Rotary Park & Bandstand                                  25.805208
# Windham Textile & History Museum                         20.213876
# Kettletown State Park                                     55.27367
# Tarrywile Park & Mansion                                 67.321178
# Lover's Leap State Park                                  59.229245
# Burr Pond State Park                                     35.829887
# Lake Compounce                                           34.577182
# Hill-Stead Museum                                        26.945393
#
# Locations                                   University of Connecticut  \
# Locations
# Connecticut State Capitol                                   22.325602
# Pratt & Whitney Stadium at Rentschler Field                 19.119187
# Talcott Mountain State Park                                 27.782438
# New England Air Museum                                      24.550286
# Phelps-Hatheway House & Garden                              23.746233
# Connecticut Trolley Museum                                  18.642831
# Shenipsit State Forest                                      13.270304
# University of Connecticut                                         0.0
# Patriots Park                                                3.900541
# Wadsworth Falls State Park                                   29.14065
# Hubbard Park                                                35.042092
# Wharton Brook State Park                                    40.137614
# Yale University                                             48.479437
# Sleeping Giant State Park                                   42.769655
# Boothe Memorial Park and Museum                             59.411593
# Seaside Park                                                65.864999
# The Maritime Aquarium                                       77.595812
# Stamford Museum & Nature Center                              81.89738
# Bruce Museum                                                89.521377
# Westport Country Playhouse                                  73.301495
# Fairfield Museum and History Center                         69.150337
# Pequonnock River Trail                                      61.261512
# Silver Sands State Park                                     59.487223
# Fort Trumbull State Park                                    33.051451
# Mystic Seaport Museum                                        34.28481
# Mohegan Park                                                20.345424
# Rotary Park & Bandstand                                     19.232202
# Windham Textile & History Museum                             7.130304
# Kettletown State Park                                        55.77718
# Tarrywile Park & Mansion                                    68.754334
# Lover's Leap State Park                                     62.479506
# Burr Pond State Park                                        43.494408
# Lake Compounce                                              36.435284
# Hill-Stead Museum                                           29.863716
#
# Locations                                   Patriots Park  \
# Locations
# Connecticut State Capitol                       19.411611
# Pratt & Whitney Stadium at Rentschler Field     16.126857
# Talcott Mountain State Park                     25.447602
# New England Air Museum                          23.444868
# Phelps-Hatheway House & Garden                  23.115752
# Connecticut Trolley Museum                      17.830134
# Shenipsit State Forest                          14.405933
# University of Connecticut                        3.900541
# Patriots Park                                         0.0
# Wadsworth Falls State Park                      25.265137
# Hubbard Park                                    31.295876
# Wharton Brook State Park                        36.252544
# Yale University                                 44.580612
# Sleeping Giant State Park                       38.904819
# Boothe Memorial Park and Museum                 55.523338
# Seaside Park                                    61.972185
# The Maritime Aquarium                           73.728108
# Stamford Museum & Nature Center                 78.074416
# Bruce Museum                                    85.669351
# Westport Country Playhouse                      69.434812
# Fairfield Museum and History Center             65.262127
# Pequonnock River Trail                          57.477446
# Silver Sands State Park                         55.587708
# Fort Trumbull State Park                        31.213549
# Mystic Seaport Museum                           33.173663
# Mohegan Park                                    19.533032
# Rotary Park & Bandstand                         22.882345
# Windham Textile & History Museum                 6.503458
# Kettletown State Park                           52.082138
# Tarrywile Park & Mansion                        65.121358
# Lover's Leap State Park                          59.10451
# Burr Pond State Park                            41.196205
# Lake Compounce                                  33.027642
# Hill-Stead Museum                               26.743396
#
# Locations                                   Wadsworth Falls State Park  ...  \
# Locations                                                               ...
# Connecticut State Capitol                                    15.691763  ...
# Pratt & Whitney Stadium at Rentschler Field                  15.785157  ...
# Talcott Mountain State Park                                  21.310879  ...
# New England Air Museum                                       28.353311  ...
# Phelps-Hatheway House & Garden                               30.644581  ...
# Connecticut Trolley Museum                                   27.470621  ...
# Shenipsit State Forest                                       32.639037  ...
# University of Connecticut                                     29.14065  ...
# Patriots Park                                                25.265137  ...
# Wadsworth Falls State Park                                         0.0  ...
# Hubbard Park                                                  7.821177  ...
# Wharton Brook State Park                                     11.020041  ...
# Yale University                                              19.554366  ...
# Sleeping Giant State Park                                    13.654454  ...
# Boothe Memorial Park and Museum                              30.294587  ...
# Seaside Park                                                 36.775916  ...
# The Maritime Aquarium                                        48.465498  ...
# Stamford Museum & Nature Center                              52.937425  ...
# Bruce Museum                                                 60.432384  ...
# Westport Country Playhouse                                   44.173422  ...
# Fairfield Museum and History Center                          40.029762  ...
# Pequonnock River Trail                                       32.598199  ...
# Silver Sands State Park                                        30.5441  ...
# Fort Trumbull State Park                                     33.535845  ...
# Mystic Seaport Museum                                         39.40561  ...
# Mohegan Park                                                 32.070332  ...
# Rotary Park & Bandstand                                      47.890099  ...
# Windham Textile & History Museum                             27.623564  ...
# Kettletown State Park                                        27.934675  ...
# Tarrywile Park & Mansion                                     41.236093  ...
# Lover's Leap State Park                                      37.473439  ...
# Burr Pond State Park                                         31.178478  ...
# Lake Compounce                                               14.196553  ...
# Hill-Stead Museum                                            14.550841  ...
#
# Locations                                   Mystic Seaport Museum  \
# Locations
# Connecticut State Capitol                               46.475617
# Pratt & Whitney Stadium at Rentschler Field             43.687972
# Talcott Mountain State Park                             53.912339
# New England Air Museum                                  55.286493
# Phelps-Hatheway House & Garden                          55.625645
# Connecticut Trolley Museum                              50.347769
# Shenipsit State Forest                                  47.388765
# University of Connecticut                                34.28481
# Patriots Park                                           33.173663
# Wadsworth Falls State Park                               39.40561
# Hubbard Park                                            47.086624
# Wharton Brook State Park                                45.617874
# Yale University                                         49.943951
# Sleeping Giant State Park                               48.781516
# Boothe Memorial Park and Museum                         60.247428
# Seaside Park                                            65.216802
# The Maritime Aquarium                                   77.776562
# Stamford Museum & Nature Center                         83.961222
# Bruce Museum                                            89.628869
# Westport Country Playhouse                              73.981972
# Fairfield Museum and History Center                     68.613936
# Pequonnock River Trail                                   66.93928
# Silver Sands State Park                                 58.518609
# Fort Trumbull State Park                                 6.819643
# Mystic Seaport Museum                                         0.0
# Mohegan Park                                            13.977789
# Rotary Park & Bandstand                                 38.452949
# Windham Textile & History Museum                        27.197209
# Kettletown State Park                                   64.612223
# Tarrywile Park & Mansion                                77.384308
# Lover's Leap State Park                                 76.054872
# Burr Pond State Park                                    68.203365
# Lake Compounce                                          53.344849
# Hill-Stead Museum                                       50.916716
#
# Locations                                   Mohegan Park  \
# Locations
# Connecticut State Capitol                      35.133745
# Pratt & Whitney Stadium at Rentschler Field    32.043024
# Talcott Mountain State Park                     42.34241
# New England Air Museum                         42.428739
# Phelps-Hatheway House & Garden                 42.452652
# Connecticut Trolley Museum                     37.144085
# Shenipsit State Forest                         33.528545
# University of Connecticut                      20.345424
# Patriots Park                                  19.533032
# Wadsworth Falls State Park                     32.070332
# Hubbard Park                                   39.839382
# Wharton Brook State Park                       40.847544
# Yale University                                47.182425
# Sleeping Giant State Park                      44.036359
# Boothe Memorial Park and Museum                58.287167
# Seaside Park                                   64.075353
# The Maritime Aquarium                          76.652337
# Stamford Museum & Nature Center                 82.19676
# Bruce Museum                                   88.784587
# Westport Country Playhouse                     72.551421
# Fairfield Museum and History Center            67.537436
# Pequonnock River Trail                         63.235274
# Silver Sands State Park                        57.253092
# Fort Trumbull State Park                       14.128115
# Mystic Seaport Museum                          13.977789
# Mohegan Park                                         0.0
# Rotary Park & Bandstand                         26.71389
# Windham Textile & History Museum               13.317111
# Kettletown State Park                          59.562385
# Tarrywile Park & Mansion                       72.812068
# Lover's Leap State Park                        69.527733
# Burr Pond State Park                           57.480688
# Lake Compounce                                 44.746447
# Hill-Stead Museum                              40.783094
#
# Locations                                   Rotary Park & Bandstand  \
# Locations
# Connecticut State Capitol                                 41.174668
# Pratt & Whitney Stadium at Rentschler Field               38.089947
# Talcott Mountain State Park                               45.727951
# New England Air Museum                                    40.279311
# Phelps-Hatheway House & Garden                            38.446447
# Connecticut Trolley Museum                                 34.40587
# Shenipsit State Forest                                    25.805208
# University of Connecticut                                 19.232202
# Patriots Park                                             22.882345
# Wadsworth Falls State Park                                47.890099
# Hubbard Park                                              54.172349
# Wharton Brook State Park                                   58.74756
# Yale University                                           66.793284
# Sleeping Giant State Park                                 61.535755
# Boothe Memorial Park and Museum                           77.913203
# Seaside Park                                              84.273505
# The Maritime Aquarium                                      96.27661
# Stamford Museum & Nature Center                          100.820276
# Bruce Museum                                             108.298699
# Westport Country Playhouse                                91.995695
# Fairfield Museum and History Center                       87.628636
# Pequonnock River Trail                                    80.312762
# Silver Sands State Park                                   77.717474
# Fort Trumbull State Park                                  40.632265
# Mystic Seaport Museum                                     38.452949
# Mohegan Park                                               26.71389
# Rotary Park & Bandstand                                         0.0
# Windham Textile & History Museum                          20.822416
# Kettletown State Park                                     74.963849
# Tarrywile Park & Mansion                                  87.978657
# Lover's Leap State Park                                   81.614866
# Burr Pond State Park                                      61.009079
# Lake Compounce                                            55.619829
# Hill-Stead Museum                                          48.84115
#
# Locations                                   Windham Textile & History Museum  \
# Locations
# Connecticut State Capitol                                          24.910038
# Pratt & Whitney Stadium at Rentschler Field                        21.610488
# Talcott Mountain State Park                                        31.431509
# New England Air Museum                                             29.933396
# Phelps-Hatheway House & Garden                                     29.612282
# Connecticut Trolley Museum                                         24.331737
# Shenipsit State Forest                                             20.213876
# University of Connecticut                                           7.130304
# Patriots Park                                                       6.503458
# Wadsworth Falls State Park                                         27.623564
# Hubbard Park                                                       34.521822
# Wharton Brook State Park                                           38.236175
# Yale University                                                    46.083365
# Sleeping Giant State Park                                          41.142667
# Boothe Memorial Park and Museum                                    57.257852
# Seaside Park                                                       63.564039
# The Maritime Aquarium                                              75.692316
# Stamford Museum & Nature Center                                    80.456165
# Bruce Museum                                                       87.770232
# Westport Country Playhouse                                          71.42854
# Fairfield Museum and History Center                                 66.94364
# Pequonnock River Trail                                             60.221693
# Silver Sands State Park                                            56.958746
# Fort Trumbull State Park                                           25.968455
# Mystic Seaport Museum                                              27.197209
# Mohegan Park                                                       13.317111
# Rotary Park & Bandstand                                            20.822416
# Windham Textile & History Museum                                         0.0
# Kettletown State Park                                              55.330165
# Tarrywile Park & Mansion                                            68.55914
# Lover's Leap State Park                                            63.363884
# Burr Pond State Park                                               47.110882
# Lake Compounce                                                     37.406142
# Hill-Stead Museum                                                  31.801554
#
# Locations                                   Kettletown State Park  \
# Locations
# Connecticut State Capitol                               35.665304
# Pratt & Whitney Stadium at Rentschler Field             38.049175
# Talcott Mountain State Park                             35.383485
# New England Air Museum                                  44.649313
# Phelps-Hatheway House & Garden                          47.652598
# Connecticut Trolley Museum                              47.290921
# Shenipsit State Forest                                   55.27367
# University of Connecticut                                55.77718
# Patriots Park                                           52.082138
# Wadsworth Falls State Park                              27.934675
# Hubbard Park                                            20.844998
# Wharton Brook State Park                                19.039335
# Yale University                                         16.530154
# Sleeping Giant State Park                               15.845752
# Boothe Memorial Park and Museum                         14.138123
# Seaside Park                                            18.350614
# The Maritime Aquarium                                   25.074476
# Stamford Museum & Nature Center                         27.342132
# Bruce Museum                                            35.589154
# Westport Country Playhouse                              21.181421
# Fairfield Museum and History Center                      19.87884
# Pequonnock River Trail                                   7.112902
# Silver Sands State Park                                 17.191806
# Fort Trumbull State Park                                58.027402
# Mystic Seaport Museum                                   64.612223
# Mohegan Park                                            59.562385
# Rotary Park & Bandstand                                 74.963849
# Windham Textile & History Museum                        55.330165
# Kettletown State Park                                         0.0
# Tarrywile Park & Mansion                                13.305249
# Lover's Leap State Park                                 13.283974
# Burr Pond State Park                                     31.13395
# Lake Compounce                                          20.749427
# Hill-Stead Museum                                       28.448076
#
# Locations                                   Tarrywile Park & Mansion  \
# Locations
# Connecticut State Capitol                                  47.929578
# Pratt & Whitney Stadium at Rentschler Field                50.558272
# Talcott Mountain State Park                                46.517208
# New England Air Museum                                     55.562933
# Phelps-Hatheway House & Garden                             58.573104
# Connecticut Trolley Museum                                 58.919391
# Shenipsit State Forest                                     67.321178
# University of Connecticut                                  68.754334
# Patriots Park                                              65.121358
# Wadsworth Falls State Park                                 41.236093
# Hubbard Park                                               34.038248
# Wharton Brook State Park                                   32.092609
# Yale University                                            27.904255
# Sleeping Giant State Park                                  28.880456
# Boothe Memorial Park and Museum                            20.435024
# Seaside Park                                               20.385422
# The Maritime Aquarium                                      19.306262
# Stamford Museum & Nature Center                            18.153839
# Bruce Museum                                               26.376253
# Westport Country Playhouse                                 17.170181
# Fairfield Museum and History Center                        19.575541
# Pequonnock River Trail                                     11.035983
# Silver Sands State Park                                    23.533752
# Fort Trumbull State Park                                    70.70821
# Mystic Seaport Museum                                      77.384308
# Mohegan Park                                               72.812068
# Rotary Park & Bandstand                                    87.978657
# Windham Textile & History Museum                            68.55914
# Kettletown State Park                                      13.305249
# Tarrywile Park & Mansion                                         0.0
# Lover's Leap State Park                                    11.499626
# Burr Pond State Park                                       38.664395
# Lake Compounce                                             32.866298
# Hill-Stead Museum                                          40.389838
#
# Locations                                   Lover's Leap State Park  \
# Locations
# Connecticut State Capitol                                 40.582972
# Pratt & Whitney Stadium at Rentschler Field               43.554294
# Talcott Mountain State Park                               37.805346
# New England Air Museum                                    46.413644
# Phelps-Hatheway House & Garden                             49.37386
# Connecticut Trolley Museum                                50.433409
# Shenipsit State Forest                                    59.229245
# University of Connecticut                                 62.479506
# Patriots Park                                              59.10451
# Wadsworth Falls State Park                                37.473439
# Hubbard Park                                              29.688539
# Wharton Brook State Park                                  30.732539
# Yale University                                           29.712078
# Sleeping Giant State Park                                 27.748825
# Boothe Memorial Park and Museum                           26.324864
# Seaside Park                                              28.710645
# The Maritime Aquarium                                     30.493828
# Stamford Museum & Nature Center                            29.63451
# Bruce Museum                                              37.789603
# Westport Country Playhouse                                27.814956
# Fairfield Museum and History Center                       28.952372
# Pequonnock River Trail                                    16.826055
# Silver Sands State Park                                   29.552555
# Fort Trumbull State Park                                  69.676218
# Mystic Seaport Museum                                     76.054872
# Mohegan Park                                              69.527733
# Rotary Park & Bandstand                                   81.614866
# Windham Textile & History Museum                          63.363884
# Kettletown State Park                                     13.283974
# Tarrywile Park & Mansion                                  11.499626
# Lover's Leap State Park                                         0.0
# Burr Pond State Park                                      27.899607
# Lake Compounce                                            26.077891
# Hill-Stead Museum                                         32.867453
#
# Locations                                   Burr Pond State Park  \
# Locations
# Connecticut State Capitol                              22.414253
# Pratt & Whitney Stadium at Rentschler Field            25.632739
# Talcott Mountain State Park                            15.752389
# New England Air Museum                                 21.347877
# Phelps-Hatheway House & Garden                         23.913329
# Connecticut Trolley Museum                             26.790687
# Shenipsit State Forest                                 35.829887
# University of Connecticut                              43.494408
# Patriots Park                                          41.196205
# Wadsworth Falls State Park                             31.178478
# Hubbard Park                                           25.894224
# Wharton Brook State Park                               33.452558
# Yale University                                        39.250006
# Sleeping Giant State Park                              32.598981
# Boothe Memorial Park and Museum                        43.853344
# Seaside Park                                           49.174866
# The Maritime Aquarium                                  55.695583
# Stamford Museum & Nature Center                        56.493564
# Bruce Museum                                           64.849982
# Westport Country Playhouse                             52.080585
# Fairfield Museum and History Center                    50.983981
# Pequonnock River Trail                                 38.173692
# Silver Sands State Park                                46.266364
# Fort Trumbull State Park                               63.232979
# Mystic Seaport Museum                                  68.203365
# Mohegan Park                                           57.480688
# Rotary Park & Bandstand                                61.009079
# Windham Textile & History Museum                       47.110882
# Kettletown State Park                                   31.13395
# Tarrywile Park & Mansion                               38.664395
# Lover's Leap State Park                                27.899607
# Burr Pond State Park                                         0.0
# Lake Compounce                                         18.125546
# Hill-Stead Museum                                       17.38903
#
# Locations                                   Lake Compounce Hill-Stead Museum
# Locations
# Connecticut State Capitol                        15.066512           7.71563
# Pratt & Whitney Stadium at Rentschler Field       17.74258          10.76093
# Talcott Mountain State Park                      15.064613          7.980657
# New England Air Museum                            24.31004         16.937335
# Phelps-Hatheway House & Garden                   27.262282         19.816682
# Connecticut Trolley Museum                       26.556763         18.858902
# Shenipsit State Forest                           34.577182         26.945393
# University of Connecticut                        36.435284         29.863716
# Patriots Park                                    33.027642         26.743396
# Wadsworth Falls State Park                       14.196553         14.550841
# Hubbard Park                                      7.799715         12.021779
# Wharton Brook State Park                         15.523718         20.512715
# Yale University                                  22.392728         28.493615
# Sleeping Giant State Park                        15.219215         21.175062
# Boothe Memorial Park and Museum                  29.625963          36.79241
# Seaside Park                                     35.833838          43.13136
# The Maritime Aquarium                            45.239556         52.868338
# Stamford Museum & Nature Center                  48.062861          55.76322
# Bruce Museum                                     56.248811         63.942427
# Westport Country Playhouse                       41.094836         48.697298
# Fairfield Museum and History Center              38.423432         45.844706
# Pequonnock River Trail                           27.366626         35.047394
# Silver Sands State Park                          31.315143         38.219189
# Fort Trumbull State Park                         47.652371         45.850089
# Mystic Seaport Museum                            53.344849         50.916716
# Mohegan Park                                     44.746447         40.783094
# Rotary Park & Bandstand                          55.619829          48.84115
# Windham Textile & History Museum                 37.406142         31.801554
# Kettletown State Park                            20.749427         28.448076
# Tarrywile Park & Mansion                         32.866298         40.389838
# Lover's Leap State Park                          26.077891         32.867453
# Burr Pond State Park                             18.125546          17.38903
# Lake Compounce                                         0.0          7.700823
# Hill-Stead Museum                                 7.700823               0.0
#
# [34 rows x 34 columns]

# %%
# Create a distance matrix for charging station to charging station
charging_station_distance_matrix = pd.DataFrame(index=charging_stations_df["Charging Stations"], columns=charging_stations_df["Charging Stations"])

for idx1, row1 in charging_stations_df.iterrows():
    for idx2, row2 in charging_stations_df.iterrows():
        station1_coords = (row1["Latitude"], row1["Longitude"])
        station2_coords = (row2["Latitude"], row2["Longitude"])
        distance = geodesic(station1_coords, station2_coords).miles
        charging_station_distance_matrix.at[row1["Charging Stations"], row2["Charging Stations"]] = distance

print("Charging Station Distance Matrix:")
print(charging_station_distance_matrix)
# Out:
# Charging Station Distance Matrix:
# Charging Stations                                  BMW OF DARIEN, 138-142 Ledge Rd  \
# Charging Stations
# BMW OF DARIEN, 138-142 Ledge Rd                                                0.0
# Dunkin’ - Tesla Supercharger, 893 E Main St                              48.188174
# Town of Beacon Falls - Commuter Lot, 105 N Main St                       33.450536
# OLD SAYBROOK VW, 319 Middlesex Turnpike                                  59.331846
# Fairfield Rail Station, 80 Mill Plain Rd                                 12.078196
# ...                                                                            ...
# Lee Partyka Chevrolet Mazda Isuzu, 200 Skiff St                          36.054234
# 777 MAIN ST, 71 Asylum St                                                63.466218
# Norwich Public Utilities, 173 N Main St                                  79.945681
# Fairfield Plaza, 116 Danbury Rd                                          33.572752
# Eastern Connecticut State University - Shakespe...                       80.330801
#
# Charging Stations                                  Dunkin’ - Tesla Supercharger, 893 E Main St  \
# Charging Stations
# BMW OF DARIEN, 138-142 Ledge Rd                                                      48.188174
# Dunkin’ - Tesla Supercharger, 893 E Main St                                                0.0
# Town of Beacon Falls - Commuter Lot, 105 N Main St                                   16.177544
# OLD SAYBROOK VW, 319 Middlesex Turnpike                                              25.237495
# Fairfield Rail Station, 80 Mill Plain Rd                                             36.816182
# ...                                                                                        ...
# Lee Partyka Chevrolet Mazda Isuzu, 200 Skiff St                                      12.798008
# 777 MAIN ST, 71 Asylum St                                                            17.292436
# Norwich Public Utilities, 173 N Main St                                              36.818398
# Fairfield Plaza, 116 Danbury Rd                                                      33.462399
# Eastern Connecticut State University - Shakespe...                                   32.699785
#
# Charging Stations                                  Town of Beacon Falls - Commuter Lot, 105 N Main St  \
# Charging Stations
# BMW OF DARIEN, 138-142 Ledge Rd                                                             33.450536
# Dunkin’ - Tesla Supercharger, 893 E Main St                                                 16.177544
# Town of Beacon Falls - Commuter Lot, 105 N Main St                                                0.0
# OLD SAYBROOK VW, 319 Middlesex Turnpike                                                     36.711638
# Fairfield Rail Station, 80 Mill Plain Rd                                                    23.292811
# ...                                                                                               ...
# Lee Partyka Chevrolet Mazda Isuzu, 200 Skiff St                                              9.506218
# 777 MAIN ST, 71 Asylum St                                                                   30.029502
# Norwich Public Utilities, 173 N Main St                                                     52.307567
# Fairfield Plaza, 116 Danbury Rd                                                             19.829155
# Eastern Connecticut State University - Shakespe...                                          48.811658
#
# Charging Stations                                  OLD SAYBROOK VW, 319 Middlesex Turnpike  \
# Charging Stations
# BMW OF DARIEN, 138-142 Ledge Rd                                                  59.331846
# Dunkin’ - Tesla Supercharger, 893 E Main St                                      25.237495
# Town of Beacon Falls - Commuter Lot, 105 N Main St                               36.711638
# OLD SAYBROOK VW, 319 Middlesex Turnpike                                                0.0
# Fairfield Rail Station, 80 Mill Plain Rd                                         47.377848
# ...                                                                                    ...
# Lee Partyka Chevrolet Mazda Isuzu, 200 Skiff St                                   27.77401
# 777 MAIN ST, 71 Asylum St                                                        34.946338
# Norwich Public Utilities, 173 N Main St                                          22.348449
# Fairfield Plaza, 116 Danbury Rd                                                   56.39811
# Eastern Connecticut State University - Shakespe...                               30.911089
#
# Charging Stations                                  Fairfield Rail Station, 80 Mill Plain Rd  \
# Charging Stations
# BMW OF DARIEN, 138-142 Ledge Rd                                                   12.078196
# Dunkin’ - Tesla Supercharger, 893 E Main St                                       36.816182
# Town of Beacon Falls - Commuter Lot, 105 N Main St                                23.292811
# OLD SAYBROOK VW, 319 Middlesex Turnpike                                           47.377848
# Fairfield Rail Station, 80 Mill Plain Rd                                                0.0
# ...                                                                                     ...
# Lee Partyka Chevrolet Mazda Isuzu, 200 Skiff St                                   24.338645
# 777 MAIN ST, 71 Asylum St                                                         52.821901
# Norwich Public Utilities, 173 N Main St                                           67.867537
# Fairfield Plaza, 116 Danbury Rd                                                   29.673849
# Eastern Connecticut State University - Shakespe...                                68.540821
#
# Charging Stations                                  FOUNDRY66, 50 Franklin St  \
# Charging Stations
# BMW OF DARIEN, 138-142 Ledge Rd                                    79.385957
# Dunkin’ - Tesla Supercharger, 893 E Main St                        36.269289
# Town of Beacon Falls - Commuter Lot, 105 N Main St                 51.746722
# OLD SAYBROOK VW, 319 Middlesex Turnpike                            21.850775
# Fairfield Rail Station, 80 Mill Plain Rd                            67.30778
# ...                                                                      ...
# Lee Partyka Chevrolet Mazda Isuzu, 200 Skiff St                    44.661544
# 777 MAIN ST, 71 Asylum St                                          35.250081
# Norwich Public Utilities, 173 N Main St                             0.566395
# Fairfield Plaza, 116 Danbury Rd                                    69.693428
# Eastern Connecticut State University - Shakespe...                 16.253974
#
# Charging Stations                                  Corbins Corner Shopping Center - Tesla Supercharger, 1445 New Britain Ave.  \
# Charging Stations
# BMW OF DARIEN, 138-142 Ledge Rd                                                             58.292084
# Dunkin’ - Tesla Supercharger, 893 E Main St                                                 13.497435
# Town of Beacon Falls - Commuter Lot, 105 N Main St                                          24.841831
# OLD SAYBROOK VW, 319 Middlesex Turnpike                                                     34.536857
# Fairfield Rail Station, 80 Mill Plain Rd                                                    47.821584
# ...                                                                                               ...
# Lee Partyka Chevrolet Mazda Isuzu, 200 Skiff St                                             25.360344
# 777 MAIN ST, 71 Asylum St                                                                    5.351409
# Norwich Public Utilities, 173 N Main St                                                     38.482798
# Fairfield Plaza, 116 Danbury Rd                                                             35.920337
# Eastern Connecticut State University - Shakespe...                                          28.536636
#
# Charging Stations                                  GLASTONBURYEV, 2327-2333 Main St  \
# Charging Stations
# BMW OF DARIEN, 138-142 Ledge Rd                                           63.065821
# Dunkin’ - Tesla Supercharger, 893 E Main St                               15.319887
# Town of Beacon Falls - Commuter Lot, 105 N Main St                        29.969527
# OLD SAYBROOK VW, 319 Middlesex Turnpike                                   30.085921
# Fairfield Rail Station, 80 Mill Plain Rd                                  51.961804
# ...                                                                             ...
# Lee Partyka Chevrolet Mazda Isuzu, 200 Skiff St                            28.11788
# 777 MAIN ST, 71 Asylum St                                                  5.094399
# Norwich Public Utilities, 173 N Main St                                   30.960042
# Fairfield Plaza, 116 Danbury Rd                                           43.216815
# Eastern Connecticut State University - Shakespe...                        20.791613
#
# Charging Stations                                  Whole Foods Market, 150 Ledge Rd  \
# Charging Stations
# BMW OF DARIEN, 138-142 Ledge Rd                                            0.014828
# Dunkin’ - Tesla Supercharger, 893 E Main St                               48.175454
# Town of Beacon Falls - Commuter Lot, 105 N Main St                        33.439255
# OLD SAYBROOK VW, 319 Middlesex Turnpike                                   59.317113
# Fairfield Rail Station, 80 Mill Plain Rd                                  12.063798
# ...                                                                             ...
# Lee Partyka Chevrolet Mazda Isuzu, 200 Skiff St                           36.040832
# 777 MAIN ST, 71 Asylum St                                                 63.454748
# Norwich Public Utilities, 173 N Main St                                   79.931273
# Fairfield Plaza, 116 Danbury Rd                                           33.568885
# Eastern Connecticut State University - Shakespe...                        80.317405
#
# Charging Stations                                  Mystic Marriott Hotel and Spa, 625 North Rd  \
# Charging Stations
# BMW OF DARIEN, 138-142 Ledge Rd                                                       78.22834
# Dunkin’ - Tesla Supercharger, 893 E Main St                                          40.371304
# Town of Beacon Falls - Commuter Lot, 105 N Main St                                   54.283946
# OLD SAYBROOK VW, 319 Middlesex Turnpike                                              18.928622
# Fairfield Rail Station, 80 Mill Plain Rd                                             66.298499
# ...                                                                                        ...
# Lee Partyka Chevrolet Mazda Isuzu, 200 Skiff St                                      45.951086
# 777 MAIN ST, 71 Asylum St                                                            43.517647
# Norwich Public Utilities, 173 N Main St                                              11.320141
# Fairfield Plaza, 116 Danbury Rd                                                      73.432202
# Eastern Connecticut State University - Shakespe...                                   27.391197
#
# Charging Stations                                   ...  \
# Charging Stations                                   ...
# BMW OF DARIEN, 138-142 Ledge Rd                     ...
# Dunkin’ - Tesla Supercharger, 893 E Main St         ...
# Town of Beacon Falls - Commuter Lot, 105 N Main St  ...
# OLD SAYBROOK VW, 319 Middlesex Turnpike             ...
# Fairfield Rail Station, 80 Mill Plain Rd            ...
# ...                                                 ...
# Lee Partyka Chevrolet Mazda Isuzu, 200 Skiff St     ...
# 777 MAIN ST, 71 Asylum St                           ...
# Norwich Public Utilities, 173 N Main St             ...
# Fairfield Plaza, 116 Danbury Rd                     ...
# Eastern Connecticut State University - Shakespe...  ...
#
# Charging Stations                                  Grand Central Fashion Plaza Shopping Center - Tesla Supercharger, 1145 High Ridge Rd  \
# Charging Stations
# BMW OF DARIEN, 138-142 Ledge Rd                                                              4.376386
# Dunkin’ - Tesla Supercharger, 893 E Main St                                                 49.560177
# Town of Beacon Falls - Commuter Lot, 105 N Main St                                           34.20727
# OLD SAYBROOK VW, 319 Middlesex Turnpike                                                     62.250108
# Fairfield Rail Station, 80 Mill Plain Rd                                                    14.916272
# ...                                                                                               ...
# Lee Partyka Chevrolet Mazda Isuzu, 200 Skiff St                                             37.871723
# 777 MAIN ST, 71 Asylum St                                                                   64.178027
# Norwich Public Utilities, 173 N Main St                                                      82.41593
# Fairfield Plaza, 116 Danbury Rd                                                             31.744629
# Eastern Connecticut State University - Shakespe...                                           82.02569
#
# Charging Stations                                  University of Connecticut - North Parking Garage, 103 N Eagleville Rd  \
# Charging Stations
# BMW OF DARIEN, 138-142 Ledge Rd                                                             81.138359
# Dunkin’ - Tesla Supercharger, 893 E Main St                                                 33.000126
# Town of Beacon Falls - Commuter Lot, 105 N Main St                                          48.758827
# OLD SAYBROOK VW, 319 Middlesex Turnpike                                                     35.027094
# Fairfield Rail Station, 80 Mill Plain Rd                                                    69.570671
# ...                                                                                               ...
# Lee Partyka Chevrolet Mazda Isuzu, 200 Skiff St                                             45.236628
# 777 MAIN ST, 71 Asylum St                                                                   21.696116
# Norwich Public Utilities, 173 N Main St                                                     21.891919
# Fairfield Plaza, 116 Danbury Rd                                                             62.446376
# Eastern Connecticut State University - Shakespe...                                           5.517401
#
# Charging Stations                                  Fairfield SB - Tesla Supercharger, 267 Round Hill Road  \
# Charging Stations
# BMW OF DARIEN, 138-142 Ledge Rd                                                             12.642662
# Dunkin’ - Tesla Supercharger, 893 E Main St                                                 36.247379
# Town of Beacon Falls - Commuter Lot, 105 N Main St                                          22.781743
# OLD SAYBROOK VW, 319 Middlesex Turnpike                                                     46.841963
# Fairfield Rail Station, 80 Mill Plain Rd                                                     0.577778
# ...                                                                                               ...
# Lee Partyka Chevrolet Mazda Isuzu, 200 Skiff St                                              23.76276
# 777 MAIN ST, 71 Asylum St                                                                   52.274449
# Norwich Public Utilities, 173 N Main St                                                      67.30423
# Fairfield Plaza, 116 Danbury Rd                                                              29.47468
# Eastern Connecticut State University - Shakespe...                                          67.963129
#
# Charging Stations                                  Fairfield Woods Library, 1147 Fairfield Woods Rd  \
# Charging Stations
# BMW OF DARIEN, 138-142 Ledge Rd                                                           14.231711
# Dunkin’ - Tesla Supercharger, 893 E Main St                                               34.101628
# Town of Beacon Falls - Commuter Lot, 105 N Main St                                          20.2031
# OLD SAYBROOK VW, 319 Middlesex Turnpike                                                    45.96512
# Fairfield Rail Station, 80 Mill Plain Rd                                                    3.17782
# ...                                                                                             ...
# Lee Partyka Chevrolet Mazda Isuzu, 200 Skiff St                                           21.828441
# 777 MAIN ST, 71 Asylum St                                                                 49.878879
# Norwich Public Utilities, 173 N Main St                                                   65.996807
# Fairfield Plaza, 116 Danbury Rd                                                           26.946359
# Eastern Connecticut State University - Shakespe...                                        66.103845
#
# Charging Stations                                  Yankee Doodle, 10 Burnell Boulevard  \
# Charging Stations
# BMW OF DARIEN, 138-142 Ledge Rd                                                4.47507
# Dunkin’ - Tesla Supercharger, 893 E Main St                                  43.721308
# Town of Beacon Falls - Commuter Lot, 105 N Main St                           29.005936
# OLD SAYBROOK VW, 319 Middlesex Turnpike                                       55.41084
# Fairfield Rail Station, 80 Mill Plain Rd                                      8.037129
# ...                                                                                ...
# Lee Partyka Chevrolet Mazda Isuzu, 200 Skiff St                              31.640628
# 777 MAIN ST, 71 Asylum St                                                    59.010165
# Norwich Public Utilities, 173 N Main St                                      75.772182
# Fairfield Plaza, 116 Danbury Rd                                              30.317692
# Eastern Connecticut State University - Shakespe...                           75.912036
#
# Charging Stations                                  Lee Partyka Chevrolet Mazda Isuzu, 200 Skiff St  \
# Charging Stations
# BMW OF DARIEN, 138-142 Ledge Rd                                                          36.054234
# Dunkin’ - Tesla Supercharger, 893 E Main St                                              12.798008
# Town of Beacon Falls - Commuter Lot, 105 N Main St                                        9.506218
# OLD SAYBROOK VW, 319 Middlesex Turnpike                                                   27.77401
# Fairfield Rail Station, 80 Mill Plain Rd                                                 24.338645
# ...                                                                                            ...
# Lee Partyka Chevrolet Mazda Isuzu, 200 Skiff St                                                0.0
# 777 MAIN ST, 71 Asylum St                                                                29.786902
# Norwich Public Utilities, 173 N Main St                                                  45.227917
# Fairfield Plaza, 116 Danbury Rd                                                          29.261679
# Eastern Connecticut State University - Shakespe...                                         44.2766
#
# Charging Stations                                  777 MAIN ST, 71 Asylum St  \
# Charging Stations
# BMW OF DARIEN, 138-142 Ledge Rd                                    63.466218
# Dunkin’ - Tesla Supercharger, 893 E Main St                        17.292436
# Town of Beacon Falls - Commuter Lot, 105 N Main St                 30.029502
# OLD SAYBROOK VW, 319 Middlesex Turnpike                            34.946338
# Fairfield Rail Station, 80 Mill Plain Rd                           52.821901
# ...                                                                      ...
# Lee Partyka Chevrolet Mazda Isuzu, 200 Skiff St                    29.786902
# 777 MAIN ST, 71 Asylum St                                                0.0
# Norwich Public Utilities, 173 N Main St                            35.671445
# Fairfield Plaza, 116 Danbury Rd                                    41.084031
# Eastern Connecticut State University - Shakespe...                 24.177919
#
# Charging Stations                                  Norwich Public Utilities, 173 N Main St  \
# Charging Stations
# BMW OF DARIEN, 138-142 Ledge Rd                                                  79.945681
# Dunkin’ - Tesla Supercharger, 893 E Main St                                      36.818398
# Town of Beacon Falls - Commuter Lot, 105 N Main St                               52.307567
# OLD SAYBROOK VW, 319 Middlesex Turnpike                                          22.348449
# Fairfield Rail Station, 80 Mill Plain Rd                                         67.867537
# ...                                                                                    ...
# Lee Partyka Chevrolet Mazda Isuzu, 200 Skiff St                                  45.227917
# 777 MAIN ST, 71 Asylum St                                                        35.671445
# Norwich Public Utilities, 173 N Main St                                                0.0
# Fairfield Plaza, 116 Danbury Rd                                                  70.237719
# Eastern Connecticut State University - Shakespe...                               16.374851
#
# Charging Stations                                  Fairfield Plaza, 116 Danbury Rd  \
# Charging Stations
# BMW OF DARIEN, 138-142 Ledge Rd                                          33.572752
# Dunkin’ - Tesla Supercharger, 893 E Main St                              33.462399
# Town of Beacon Falls - Commuter Lot, 105 N Main St                       19.829155
# OLD SAYBROOK VW, 319 Middlesex Turnpike                                   56.39811
# Fairfield Rail Station, 80 Mill Plain Rd                                 29.673849
# ...                                                                            ...
# Lee Partyka Chevrolet Mazda Isuzu, 200 Skiff St                          29.261679
# 777 MAIN ST, 71 Asylum St                                                41.084031
# Norwich Public Utilities, 173 N Main St                                  70.237719
# Fairfield Plaza, 116 Danbury Rd                                                0.0
# Eastern Connecticut State University - Shakespe...                       63.844798
#
# Charging Stations                                  Eastern Connecticut State University - Shakespeare Parking Garage, 24 Charger Oak Dr
# Charging Stations
# BMW OF DARIEN, 138-142 Ledge Rd                                                             80.330801
# Dunkin’ - Tesla Supercharger, 893 E Main St                                                 32.699785
# Town of Beacon Falls - Commuter Lot, 105 N Main St                                          48.811658
# OLD SAYBROOK VW, 319 Middlesex Turnpike                                                     30.911089
# Fairfield Rail Station, 80 Mill Plain Rd                                                    68.540821
# ...                                                                                               ...
# Lee Partyka Chevrolet Mazda Isuzu, 200 Skiff St                                               44.2766
# 777 MAIN ST, 71 Asylum St                                                                   24.177919
# Norwich Public Utilities, 173 N Main St                                                     16.374851
# Fairfield Plaza, 116 Danbury Rd                                                             63.844798
# Eastern Connecticut State University - Shakespe...                                                0.0
#
# [385 rows x 385 columns]

# %% [markdown]
# ### NEAREST INSERTION ALGORITHM

# %%
def find_nearest_location(current_tour, location_distance_matrix, qualifying_distance_matrix, places_df, charging_stations_df):
    print("Finding nearest location...")
    nearest_location = None
    min_distance = float('inf')

    for location in places_df["Locations"]:
        if location not in current_tour:
            for city in current_tour:
                if city in places_df["Locations"].values:
                    distance = location_distance_matrix.at[city, location]
                elif city in charging_stations_df["Charging Stations"].values:
                    # Use qualifying_distance_matrix for charging stations
                    distance = qualifying_distance_matrix.at[city, location]
                else:
                    raise ValueError(f"Invalid city: {city}")
                if distance < min_distance:
                    nearest_location = location
                    min_distance = distance

    print("Nearest location found:", nearest_location)
    return nearest_location

def find_nearest_charging_station(current_tour, qualifying_distance_matrix, charging_station_distance_matrix, places_df, charging_stations_df):
    print("Finding nearest charging station...")
    nearest_station = None
    min_distance = float('inf')

    # This function finds the nearest unvisited charging station from the current tour.
    for station in qualifying_distance_matrix.index:
        if station not in current_tour:
            # For each unvisited charging station, it calculates the distance from each city in the current tour to that charging station.
            for city in current_tour:
                if city in places_df["Locations"].values:
                    # If the city in the current tour is a location, it uses the qualifying_distance_matrix to get the distance.
                    distance = qualifying_distance_matrix.at[station, city]
                elif city in charging_stations_df["Charging Stations"].values:
                    # If the city in the current tour is a charging station, it uses the charging_station_distance_matrix to get the distance.
                    distance = charging_station_distance_matrix.at[station, city]
                else:
                    raise ValueError(f"Invalid city: {city}")

                if distance < min_distance:
                    nearest_station = station
                    min_distance = distance

    # It keeps track of the charging station with the minimum distance from the current tour.
    # The function returns the nearest unvisited charging station.
    if nearest_station is not None:
        print("Nearest charging station found:", nearest_station)
    else:
        print("No suitable charging station found.")
    return nearest_station

# Note: The qualifying_distance_matrix has charging stations in its index position and locations in its column position.
# The charging_station_distance_matrix has distances between charging stations.

def insert_nearest_charging_station(nearest_station, current_tour, location_distance_matrix, qualifying_distance_matrix, charging_station_distance_matrix, places_df, charging_stations_df):
    print("Inserting nearest charging station...")
    best_insertion = None
    min_increase = float('inf')

    for i in range(len(current_tour)):
        prev_city = current_tour[i]
        next_i = (i + 1) % len(current_tour)
        next_city = current_tour[next_i]

        if prev_city in places_df["Locations"].values and next_city in places_df["Locations"].values:
            if nearest_station in qualifying_distance_matrix.index and prev_city in qualifying_distance_matrix.columns and next_city in qualifying_distance_matrix.columns:
                increase = qualifying_distance_matrix.at[nearest_station, prev_city] + \
                           qualifying_distance_matrix.at[nearest_station, next_city] - \
                           location_distance_matrix.at[prev_city, next_city]
            else:
                continue
        elif prev_city in places_df["Locations"].values and next_city in charging_stations_df["Charging Stations"].values:
            if nearest_station in charging_station_distance_matrix.index and prev_city in qualifying_distance_matrix.columns and next_city in charging_station_distance_matrix.columns:
                increase = qualifying_distance_matrix.at[nearest_station, prev_city] + \
                           charging_station_distance_matrix.at[nearest_station, next_city] - \
                           qualifying_distance_matrix.at[next_city, prev_city]
            else:
                continue
        elif prev_city in charging_stations_df["Charging Stations"].values and next_city in places_df["Locations"].values:
            if nearest_station in charging_station_distance_matrix.index and prev_city in charging_station_distance_matrix.columns and next_city in qualifying_distance_matrix.columns:
                increase = charging_station_distance_matrix.at[nearest_station, prev_city] + \
                           qualifying_distance_matrix.at[nearest_station, next_city] - \
                           qualifying_distance_matrix.at[prev_city, next_city]
            else:
                continue
        else:  # Both prev_city and next_city are charging stations
            if nearest_station in charging_station_distance_matrix.index and prev_city in charging_station_distance_matrix.columns and next_city in charging_station_distance_matrix.columns:
                increase = charging_station_distance_matrix.at[nearest_station, prev_city] + \
                           charging_station_distance_matrix.at[nearest_station, next_city] - \
                           charging_station_distance_matrix.at[prev_city, next_city]
            else:
                continue

        if increase < min_increase:
            min_increase = increase
            best_insertion = i + 1

    if best_insertion is not None:
        current_tour.insert(best_insertion, nearest_station)
        print("Nearest charging station inserted into the tour.")
    else:
        print("No suitable insertion point found for the nearest charging station.")

def insert_nearest_location(nearest_location, current_tour, location_distance_matrix, qualifying_distance_matrix, charging_station_distance_matrix, places_df, charging_stations_df):
    print("Inserting nearest location...")
    best_insertion = None
    min_increase = float('inf')

    for i in range(len(current_tour)):
        prev_city = current_tour[i]
        next_i = (i + 1) % len(current_tour)
        next_city = current_tour[next_i]

        if prev_city in places_df["Locations"].values and next_city in places_df["Locations"].values:
            increase = location_distance_matrix.at[prev_city, nearest_location] + \
                       location_distance_matrix.at[nearest_location, next_city] - \
                       location_distance_matrix.at[prev_city, next_city]
        elif prev_city in places_df["Locations"].values and next_city in charging_stations_df["Charging Stations"].values:
            # Use qualifying_distance_matrix with charging station as index and location as column
            increase = qualifying_distance_matrix.at[next_city, prev_city] + \
                       qualifying_distance_matrix.at[next_city, nearest_location] - \
                       qualifying_distance_matrix.at[next_city, prev_city]
        elif prev_city in charging_stations_df["Charging Stations"].values and next_city in places_df["Locations"].values:
            # Use qualifying_distance_matrix with charging station as index and location as column
            increase = qualifying_distance_matrix.at[prev_city, nearest_location] + \
                       qualifying_distance_matrix.at[prev_city, next_city] - \
                       qualifying_distance_matrix.at[prev_city, next_city]
        else:  # Both prev_city and next_city are charging stations
            if nearest_location in charging_station_distance_matrix.columns:
                increase = charging_station_distance_matrix.at[prev_city, nearest_location] + \
                           charging_station_distance_matrix.at[nearest_location, next_city] - \
                           charging_station_distance_matrix.at[prev_city, next_city]
            else:
                # If nearest_location is not in charging_station_distance_matrix, assign a large value to increase
                increase = float('inf')

        if increase < min_increase:
            min_increase = increase
            best_insertion = i + 1

    current_tour.insert(best_insertion, nearest_location)
    print("Nearest location inserted into the tour.")

def calculate_battery_discharge_rate(distance, speed, Cd, A, Crr, m, g, rho, lambda_, alpha):
    # Calculate the battery discharge rate based on vehicle parameters
    F_drag = 0.5 * rho * Cd * A * (speed ** 2)
    F_rolling = Crr * m * g
    F_total = F_drag + F_rolling
    P_total = F_total * speed
    P_regen = alpha * P_total
    P_net = P_total - P_regen
    energy_consumed = P_net * (distance / speed)
    discharge_rate = energy_consumed / 3600  # Convert from Joules to kWh
    return discharge_rate

def print_final_tour(tour, places_df, charging_stations_df, total_distance):
    print("Final Tour:")
    for city in tour:
        if city in places_df["Locations"].values:
            print(f"Nearest Location: {city}")
        else:
            print(f"Nearest Charging Station: {city}")
    print(f"Best Cost (Total Distance): {total_distance}")

def get_distance(city1, city2, location_distance_matrix, qualifying_distance_matrix, charging_station_distance_matrix, places_df, charging_stations_df):
    if city1 in places_df["Locations"].values and city2 in places_df["Locations"].values:
        return location_distance_matrix.at[city1, city2]
    elif city1 in places_df["Locations"].values and city2 in charging_stations_df["Charging Stations"].values:
        return qualifying_distance_matrix.at[city2, city1]
    elif city1 in charging_stations_df["Charging Stations"].values and city2 in places_df["Locations"].values:
        return qualifying_distance_matrix.at[city1, city2]
    elif city1 in charging_stations_df["Charging Stations"].values and city2 in charging_stations_df["Charging Stations"].values:
        return charging_station_distance_matrix.at[city1, city2]
    else:
        raise KeyError(f"Invalid cities: {city1}, {city2}")
def nearest_insertion_algorithm(location_distance_matrix, qualifying_distance_matrix, charging_station_distance_matrix, places_df, charging_stations_df, source_city, vehicle_params, charging_params, iteration_count=0):
    current_tour = [source_city]
    visited_cities = set(current_tour)
    current_charge = charging_params['max_charge']
    total_distance = 0
    speed_dict = {}

    Cd, A, Crr, m, g, rho, lambda_, alpha = vehicle_params.values()
    level2_charge_rate, dc_fast_charge_rate, min_charge, max_charge = charging_params.values()


    while len(set(current_tour) & set(places_df["Locations"])) < len(places_df["Locations"]):
        nearest_location = find_nearest_location(current_tour, location_distance_matrix, qualifying_distance_matrix, places_df, charging_stations_df)
        distance_to_next_location = location_distance_matrix.at[current_tour[-1], nearest_location]

        speed = random.randint(50, 80)  # Random speed between 50 and 80 miles/h
        speed_dict[(current_tour[-1], nearest_location)] = speed  # Store the speed in the speed_dict
        speed_dict[(nearest_location, current_tour[-1])] = speed  # Also store the speed for the reverse direction
        print(f"Speed stored in speed_dict: {current_tour[-1]} -> {nearest_location}: {speed} miles/h")
        print(f"Speed stored in speed_dict: {nearest_location} -> {current_tour[-1]}: {speed} miles/h")
        print(f"Speed stored in speed_dict: {current_tour[-1]} -> {nearest_location}: {speed} miles/h")
        discharge_rate = calculate_battery_discharge_rate(distance_to_next_location, speed, Cd, A, Crr, m, g, rho, lambda_, alpha)
        required_charge_to_next_location = discharge_rate

        print(f"Current charge: {current_charge}, Required charge to next location: {required_charge_to_next_location}")

        if current_charge - required_charge_to_next_location >= min_charge:
            insert_nearest_location(nearest_location, current_tour, location_distance_matrix, qualifying_distance_matrix, charging_station_distance_matrix, places_df, charging_stations_df)
            visited_cities.add(nearest_location)
            total_distance += distance_to_next_location
            current_charge -= required_charge_to_next_location

            print("Updated Tour:")
            for city in current_tour:
                print(f"Nearest Location: {city}")
            print(f"Total Distance: {total_distance}")
            print(f"Updated Charge: {current_charge}")
            print(f"Speed: {speed} miles/h")


            # Check if charge level is below 60% and find the nearest charging station
            if current_charge < max_charge * 0.6:
                print("Warning: Charge level below 60%. Looking for the nearest charging station.")
                nearest_station = find_nearest_charging_station(current_tour, qualifying_distance_matrix, charging_station_distance_matrix, places_df, charging_stations_df)

                if nearest_station is not None:
                    insert_nearest_charging_station(nearest_station, current_tour, location_distance_matrix, qualifying_distance_matrix, charging_station_distance_matrix, places_df, charging_stations_df)
                    visited_cities.add(nearest_station)
                    distance_to_station = get_distance(current_tour[-2], nearest_station, location_distance_matrix, qualifying_distance_matrix, charging_station_distance_matrix, places_df, charging_stations_df)
                    current_charge = max_charge
                    print("Total Distance After Charging Station Insertion:", total_distance)

        else:
            print(f"Impossible route encountered after {iteration_count} iterations. Restarting with a different source city.")
            new_source_city = places_df.loc[places_df["Locations"] != source_city, "Locations"].sample().values[0]
            return nearest_insertion_algorithm(location_distance_matrix, qualifying_distance_matrix, charging_station_distance_matrix, places_df, charging_stations_df, new_source_city, vehicle_params, charging_params, iteration_count + 1)

    print(f"Nearest Insertion Algorithm completed after {iteration_count} iterations.")
    print("Tour:")
    for city in current_tour:
        if city in places_df["Locations"].values:
            print(f"Nearest Location: {city}")
        else:
            print(f"Nearest Charging Station: {city}")

    if all(location in current_tour for location in places_df["Locations"]):
        print("Feasible route found.")
        print_final_tour(current_tour, places_df, charging_stations_df, total_distance)
        return current_tour, total_distance, speed_dict
    else:
        print(f"Impossible route encountered after {iteration_count} iterations. Restarting with a different source city.")
        new_source_city = places_df.loc[places_df["Locations"] != source_city, "Locations"].sample().values[0]
        return nearest_insertion_algorithm(location_distance_matrix, qualifying_distance_matrix, charging_station_distance_matrix, places_df, charging_stations_df, new_source_city, vehicle_params, charging_params, iteration_count + 1)

vehicle_params = {
    'Cd': 0.3,
    'A': 2.2,
    'Crr': 0.01,
    'm': 1500,
    'g': 9.81,
    'rho': 1.225,
    'lambda_': 0.80,
    'alpha': 0.25
}

charging_params = {
    'level2_charge_rate': 7,
    'dc_fast_charge_rate': 50,
    'min_charge': 20,  # 20% of 100 kWh battery capacity
    'max_charge': 90  # 90% of 100 kWh battery capacity
}

# %%
source_city = "Yale University"
tour, total_distance, speed_dict = nearest_insertion_algorithm(location_distance_matrix, qualifying_distance_matrix, charging_station_distance_matrix, places_df, charging_stations_df, source_city, vehicle_params, charging_params)
# Out:
# Finding nearest location...
# Nearest location found: Patriots Park
# Speed stored in speed_dict: University of Connecticut -> Patriots Park: 69 miles/h
# Speed stored in speed_dict: Patriots Park -> University of Connecticut: 69 miles/h
# Speed stored in speed_dict: University of Connecticut -> Patriots Park: 69 miles/h
# Current charge: 90, Required charge to next location: 1.6835583180503133
# Inserting nearest location...
# Nearest location inserted into the tour.
# Updated Tour:
# Nearest Location: University of Connecticut
# Nearest Location: Patriots Park
# Total Distance: 3.9005412492355336
# Updated Charge: 88.31644168194968
# Speed: 69 miles/h
# Finding nearest location...
# Nearest location found: Windham Textile & History Museum
# Speed stored in speed_dict: Patriots Park -> Windham Textile & History Museum: 71 miles/h
# Speed stored in speed_dict: Windham Textile & History Museum -> Patriots Park: 71 miles/h
# Speed stored in speed_dict: Patriots Park -> Windham Textile & History Museum: 71 miles/h
# Current charge: 88.31644168194968, Required charge to next location: 2.9603933911215488
# Inserting nearest location...
# Nearest location inserted into the tour.
# Updated Tour:
# Nearest Location: University of Connecticut
# Nearest Location: Windham Textile & History Museum
# Nearest Location: Patriots Park
# Total Distance: 10.403999254465313
# Updated Charge: 85.35604829082814
# Speed: 71 miles/h
# Finding nearest location...
# Nearest location found: Shenipsit State Forest
# Speed stored in speed_dict: Patriots Park -> Shenipsit State Forest: 55 miles/h
# Speed stored in speed_dict: Shenipsit State Forest -> Patriots Park: 55 miles/h
# Speed stored in speed_dict: Patriots Park -> Shenipsit State Forest: 55 miles/h
# Current charge: 85.35604829082814, Required charge to next location: 4.111712081404561
# Inserting nearest location...
# Nearest location inserted into the tour.
# Updated Tour:
# Nearest Location: University of Connecticut
# Nearest Location: Windham Textile & History Museum
# Nearest Location: Patriots Park
# Nearest Location: Shenipsit State Forest
# Total Distance: 24.809932067357146
# Updated Charge: 81.24433620942358
# Speed: 55 miles/h
# Finding nearest location...
# Nearest location found: Connecticut Trolley Museum
# Speed stored in speed_dict: Shenipsit State Forest -> Connecticut Trolley Museum: 53 miles/h
# Speed stored in speed_dict: Connecticut Trolley Museum -> Shenipsit State Forest: 53 miles/h
# Speed stored in speed_dict: Shenipsit State Forest -> Connecticut Trolley Museum: 53 miles/h
# Current charge: 81.24433620942358, Required charge to next location: 2.4301447629634776
# Inserting nearest location...
# Nearest location inserted into the tour.
# Updated Tour:
# Nearest Location: University of Connecticut
# Nearest Location: Windham Textile & History Museum
# Nearest Location: Patriots Park
# Nearest Location: Connecticut Trolley Museum
# Nearest Location: Shenipsit State Forest
# Total Distance: 33.903875870323056
# Updated Charge: 78.8141914464601
# Speed: 53 miles/h
# Finding nearest location...
# Nearest location found: Phelps-Hatheway House & Garden
# Speed stored in speed_dict: Shenipsit State Forest -> Phelps-Hatheway House & Garden: 65 miles/h
# Speed stored in speed_dict: Phelps-Hatheway House & Garden -> Shenipsit State Forest: 65 miles/h
# Speed stored in speed_dict: Shenipsit State Forest -> Phelps-Hatheway House & Garden: 65 miles/h
# Current charge: 78.8141914464601, Required charge to next location: 4.885896825110514
# Inserting nearest location...
# Nearest location inserted into the tour.
# Updated Tour:
# Nearest Location: University of Connecticut
# Nearest Location: Windham Textile & History Museum
# Nearest Location: Patriots Park
# Nearest Location: Connecticut Trolley Museum
# Nearest Location: Phelps-Hatheway House & Garden
# Nearest Location: Shenipsit State Forest
# Total Distance: 46.54590365742715
# Updated Charge: 73.92829462134958
# Speed: 65 miles/h
# Finding nearest location...
# Nearest location found: New England Air Museum
# Speed stored in speed_dict: Shenipsit State Forest -> New England Air Museum: 67 miles/h
# Speed stored in speed_dict: New England Air Museum -> Shenipsit State Forest: 67 miles/h
# Speed stored in speed_dict: Shenipsit State Forest -> New England Air Museum: 67 miles/h
# Current charge: 73.92829462134958, Required charge to next location: 5.9780727202705135
# Inserting nearest location...
# Nearest location inserted into the tour.
# Updated Tour:
# Nearest Location: University of Connecticut
# Nearest Location: Windham Textile & History Museum
# Nearest Location: Patriots Park
# Nearest Location: Connecticut Trolley Museum
# Nearest Location: New England Air Museum
# Nearest Location: Phelps-Hatheway House & Garden
# Nearest Location: Shenipsit State Forest
# Total Distance: 61.17243839985348
# Updated Charge: 67.95022190107906
# Speed: 67 miles/h
# Finding nearest location...
# Nearest location found: Talcott Mountain State Park
# Speed stored in speed_dict: Shenipsit State Forest -> Talcott Mountain State Park: 60 miles/h
# Speed stored in speed_dict: Talcott Mountain State Park -> Shenipsit State Forest: 60 miles/h
# Speed stored in speed_dict: Shenipsit State Forest -> Talcott Mountain State Park: 60 miles/h
# Current charge: 67.95022190107906, Required charge to next location: 7.198518327629592
# Inserting nearest location...
# Nearest location inserted into the tour.
# Updated Tour:
# Nearest Location: University of Connecticut
# Nearest Location: Windham Textile & History Museum
# Nearest Location: Patriots Park
# Nearest Location: Connecticut Trolley Museum
# Nearest Location: Talcott Mountain State Park
# Nearest Location: New England Air Museum
# Nearest Location: Phelps-Hatheway House & Garden
# Nearest Location: Shenipsit State Forest
# Total Distance: 82.73497574742879
# Updated Charge: 60.75170357344947
# Speed: 60 miles/h
# Finding nearest location...
# Nearest location found: Connecticut State Capitol
# Speed stored in speed_dict: Shenipsit State Forest -> Connecticut State Capitol: 78 miles/h
# Speed stored in speed_dict: Connecticut State Capitol -> Shenipsit State Forest: 78 miles/h
# Speed stored in speed_dict: Shenipsit State Forest -> Connecticut State Capitol: 78 miles/h
# Current charge: 60.75170357344947, Required charge to next location: 10.660983120489028
# Inserting nearest location...
# Nearest location inserted into the tour.
# Updated Tour:
# Nearest Location: University of Connecticut
# Nearest Location: Windham Textile & History Museum
# Nearest Location: Patriots Park
# Nearest Location: Connecticut Trolley Museum
# Nearest Location: Connecticut State Capitol
# Nearest Location: Talcott Mountain State Park
# Nearest Location: New England Air Museum
# Nearest Location: Phelps-Hatheway House & Garden
# Nearest Location: Shenipsit State Forest
# Total Distance: 102.36690299167671
# Updated Charge: 50.09072045296044
# Speed: 78 miles/h
# Warning: Charge level below 60%. Looking for the nearest charging station.
# Finding nearest charging station...
# Nearest charging station found: Connecticut State Capitol, 210 Capitol Ave
# Inserting nearest charging station...
# Nearest charging station inserted into the tour.
# Total Distance After Charging Station Insertion: 102.36690299167671
# Finding nearest location...
# Nearest location found: Pratt & Whitney Stadium at Rentschler Field
# Speed stored in speed_dict: Shenipsit State Forest -> Pratt & Whitney Stadium at Rentschler Field: 75 miles/h
# Speed stored in speed_dict: Pratt & Whitney Stadium at Rentschler Field -> Shenipsit State Forest: 75 miles/h
# Speed stored in speed_dict: Shenipsit State Forest -> Pratt & Whitney Stadium at Rentschler Field: 75 miles/h
# Current charge: 90, Required charge to next location: 8.901434853169038
# Inserting nearest location...
# Nearest location inserted into the tour.
# Updated Tour:
# Nearest Location: University of Connecticut
# Nearest Location: Windham Textile & History Museum
# Nearest Location: Patriots Park
# Nearest Location: Connecticut Trolley Museum
# Nearest Location: Pratt & Whitney Stadium at Rentschler Field
# Nearest Location: Connecticut State Capitol
# Nearest Location: Connecticut State Capitol, 210 Capitol Ave
# Nearest Location: Talcott Mountain State Park
# Nearest Location: New England Air Museum
# Nearest Location: Phelps-Hatheway House & Garden
# Nearest Location: Shenipsit State Forest
# Total Distance: 120.01493875921057
# Updated Charge: 81.09856514683096
# Speed: 75 miles/h
# Finding nearest location...
# Nearest location found: Hill-Stead Museum
# Speed stored in speed_dict: Shenipsit State Forest -> Hill-Stead Museum: 54 miles/h
# Speed stored in speed_dict: Hill-Stead Museum -> Shenipsit State Forest: 54 miles/h
# Speed stored in speed_dict: Shenipsit State Forest -> Hill-Stead Museum: 54 miles/h
# Current charge: 81.09856514683096, Required charge to next location: 7.443344805188529
# Inserting nearest location...
# Nearest location inserted into the tour.
# Updated Tour:
# Nearest Location: University of Connecticut
# Nearest Location: Windham Textile & History Museum
# Nearest Location: Patriots Park
# Nearest Location: Connecticut Trolley Museum
# Nearest Location: Pratt & Whitney Stadium at Rentschler Field
# Nearest Location: Connecticut State Capitol
# Nearest Location: Hill-Stead Museum
# Nearest Location: Connecticut State Capitol, 210 Capitol Ave
# Nearest Location: Talcott Mountain State Park
# Nearest Location: New England Air Museum
# Nearest Location: Phelps-Hatheway House & Garden
# Nearest Location: Shenipsit State Forest
# Total Distance: 146.96033163424738
# Updated Charge: 73.65522034164243
# Speed: 54 miles/h
# Finding nearest location...
# Nearest location found: Lake Compounce
# Speed stored in speed_dict: Shenipsit State Forest -> Lake Compounce: 65 miles/h
# Speed stored in speed_dict: Lake Compounce -> Shenipsit State Forest: 65 miles/h
# Speed stored in speed_dict: Shenipsit State Forest -> Lake Compounce: 65 miles/h
# Current charge: 73.65522034164243, Required charge to next location: 13.363405652010444
# Inserting nearest location...
# Nearest location inserted into the tour.
# Updated Tour:
# Nearest Location: University of Connecticut
# Nearest Location: Windham Textile & History Museum
# Nearest Location: Patriots Park
# Nearest Location: Connecticut Trolley Museum
# Nearest Location: Pratt & Whitney Stadium at Rentschler Field
# Nearest Location: Connecticut State Capitol
# Nearest Location: Lake Compounce
# Nearest Location: Hill-Stead Museum
# Nearest Location: Connecticut State Capitol, 210 Capitol Ave
# Nearest Location: Talcott Mountain State Park
# Nearest Location: New England Air Museum
# Nearest Location: Phelps-Hatheway House & Garden
# Nearest Location: Shenipsit State Forest
# Total Distance: 181.5375140083837
# Updated Charge: 60.29181468963199
# Speed: 65 miles/h
# Finding nearest location...
# Nearest location found: Hubbard Park
# Speed stored in speed_dict: Shenipsit State Forest -> Hubbard Park: 56 miles/h
# Speed stored in speed_dict: Hubbard Park -> Shenipsit State Forest: 56 miles/h
# Speed stored in speed_dict: Shenipsit State Forest -> Hubbard Park: 56 miles/h
# Current charge: 60.29181468963199, Required charge to next location: 10.63963908873725
# Inserting nearest location...
# Nearest location inserted into the tour.
# Updated Tour:
# Nearest Location: University of Connecticut
# Nearest Location: Windham Textile & History Museum
# Nearest Location: Patriots Park
# Nearest Location: Connecticut Trolley Museum
# Nearest Location: Pratt & Whitney Stadium at Rentschler Field
# Nearest Location: Connecticut State Capitol
# Nearest Location: Hubbard Park
# Nearest Location: Lake Compounce
# Nearest Location: Hill-Stead Museum
# Nearest Location: Connecticut State Capitol, 210 Capitol Ave
# Nearest Location: Talcott Mountain State Park
# Nearest Location: New England Air Museum
# Nearest Location: Phelps-Hatheway House & Garden
# Nearest Location: Shenipsit State Forest
# Total Distance: 217.63268802758452
# Updated Charge: 49.65217560089474
# Speed: 56 miles/h
# Warning: Charge level below 60%. Looking for the nearest charging station.
# Finding nearest charging station...
# Nearest charging station found: Greater Hartford Transit District - Spruce Street Lot, 1 Union Pl
# Inserting nearest charging station...
# Nearest charging station inserted into the tour.
# Total Distance After Charging Station Insertion: 217.63268802758452
# Finding nearest location...
# Nearest location found: Wadsworth Falls State Park
# Speed stored in speed_dict: Shenipsit State Forest -> Wadsworth Falls State Park: 54 miles/h
# Speed stored in speed_dict: Wadsworth Falls State Park -> Shenipsit State Forest: 54 miles/h
# Speed stored in speed_dict: Shenipsit State Forest -> Wadsworth Falls State Park: 54 miles/h
# Current charge: 90, Required charge to next location: 9.016146361942694
# Inserting nearest location...
# Nearest location inserted into the tour.
# Updated Tour:
# Nearest Location: University of Connecticut
# Nearest Location: Windham Textile & History Museum
# Nearest Location: Patriots Park
# Nearest Location: Connecticut Trolley Museum
# Nearest Location: Pratt & Whitney Stadium at Rentschler Field
# Nearest Location: Connecticut State Capitol
# Nearest Location: Wadsworth Falls State Park
# Nearest Location: Hubbard Park
# Nearest Location: Lake Compounce
# Nearest Location: Hill-Stead Museum
# Nearest Location: Connecticut State Capitol, 210 Capitol Ave
# Nearest Location: Greater Hartford Transit District - Spruce Street Lot, 1 Union Pl
# Nearest Location: Talcott Mountain State Park
# Nearest Location: New England Air Museum
# Nearest Location: Phelps-Hatheway House & Garden
# Nearest Location: Shenipsit State Forest
# Total Distance: 250.27172495249374
# Updated Charge: 80.98385363805731
# Speed: 54 miles/h
# Finding nearest location...
# Nearest location found: Wharton Brook State Park
# Speed stored in speed_dict: Shenipsit State Forest -> Wharton Brook State Park: 79 miles/h
# Speed stored in speed_dict: Wharton Brook State Park -> Shenipsit State Forest: 79 miles/h
# Speed stored in speed_dict: Shenipsit State Forest -> Wharton Brook State Park: 79 miles/h
# Current charge: 80.98385363805731, Required charge to next location: 24.018958616640084
# Inserting nearest location...
# Nearest location inserted into the tour.
# Updated Tour:
# Nearest Location: University of Connecticut
# Nearest Location: Windham Textile & History Museum
# Nearest Location: Patriots Park
# Nearest Location: Connecticut Trolley Museum
# Nearest Location: Pratt & Whitney Stadium at Rentschler Field
# Nearest Location: Connecticut State Capitol
# Nearest Location: Wadsworth Falls State Park
# Nearest Location: Wharton Brook State Park
# Nearest Location: Hubbard Park
# Nearest Location: Lake Compounce
# Nearest Location: Hill-Stead Museum
# Nearest Location: Connecticut State Capitol, 210 Capitol Ave
# Nearest Location: Greater Hartford Transit District - Spruce Street Lot, 1 Union Pl
# Nearest Location: Talcott Mountain State Park
# Nearest Location: New England Air Museum
# Nearest Location: Phelps-Hatheway House & Garden
# Nearest Location: Shenipsit State Forest
# Total Distance: 293.4506745116202
# Updated Charge: 56.96489502141723
# Speed: 79 miles/h
# Finding nearest location...
# Nearest location found: Sleeping Giant State Park
# Speed stored in speed_dict: Shenipsit State Forest -> Sleeping Giant State Park: 56 miles/h
# Speed stored in speed_dict: Sleeping Giant State Park -> Shenipsit State Forest: 56 miles/h
# Speed stored in speed_dict: Shenipsit State Forest -> Sleeping Giant State Park: 56 miles/h
# Current charge: 56.96489502141723, Required charge to next location: 13.304769311723216
# Inserting nearest location...
# Nearest location inserted into the tour.
# Updated Tour:
# Nearest Location: University of Connecticut
# Nearest Location: Windham Textile & History Museum
# Nearest Location: Patriots Park
# Nearest Location: Connecticut Trolley Museum
# Nearest Location: Pratt & Whitney Stadium at Rentschler Field
# Nearest Location: Connecticut State Capitol
# Nearest Location: Wadsworth Falls State Park
# Nearest Location: Wharton Brook State Park
# Nearest Location: Sleeping Giant State Park
# Nearest Location: Hubbard Park
# Nearest Location: Lake Compounce
# Nearest Location: Hill-Stead Museum
# Nearest Location: Connecticut State Capitol, 210 Capitol Ave
# Nearest Location: Greater Hartford Transit District - Spruce Street Lot, 1 Union Pl
# Nearest Location: Talcott Mountain State Park
# Nearest Location: New England Air Museum
# Nearest Location: Phelps-Hatheway House & Garden
# Nearest Location: Shenipsit State Forest
# Total Distance: 338.5873525123181
# Updated Charge: 43.660125709694015
# Speed: 56 miles/h
# Warning: Charge level below 60%. Looking for the nearest charging station.
# Finding nearest charging station...
# Nearest charging station found: Windham Municipal Parking Lot, 48 Church St
# Inserting nearest charging station...
# Nearest charging station inserted into the tour.
# Total Distance After Charging Station Insertion: 338.5873525123181
# Finding nearest location...
# Nearest location found: Yale University
# Speed stored in speed_dict: Shenipsit State Forest -> Yale University: 71 miles/h
# Speed stored in speed_dict: Yale University -> Shenipsit State Forest: 71 miles/h
# Speed stored in speed_dict: Shenipsit State Forest -> Yale University: 71 miles/h
# Current charge: 90, Required charge to next location: 23.616514785713484
# Inserting nearest location...
# Nearest location inserted into the tour.
# Updated Tour:
# Nearest Location: University of Connecticut
# Nearest Location: Windham Textile & History Museum
# Nearest Location: Windham Municipal Parking Lot, 48 Church St
# Nearest Location: Patriots Park
# Nearest Location: Connecticut Trolley Museum
# Nearest Location: Pratt & Whitney Stadium at Rentschler Field
# Nearest Location: Connecticut State Capitol
# Nearest Location: Wadsworth Falls State Park
# Nearest Location: Wharton Brook State Park
# Nearest Location: Yale University
# Nearest Location: Sleeping Giant State Park
# Nearest Location: Hubbard Park
# Nearest Location: Lake Compounce
# Nearest Location: Hill-Stead Museum
# Nearest Location: Connecticut State Capitol, 210 Capitol Ave
# Nearest Location: Greater Hartford Transit District - Spruce Street Lot, 1 Union Pl
# Nearest Location: Talcott Mountain State Park
# Nearest Location: New England Air Museum
# Nearest Location: Phelps-Hatheway House & Garden
# Nearest Location: Shenipsit State Forest
# Total Distance: 390.4686371413817
# Updated Charge: 66.38348521428651
# Speed: 71 miles/h
# Finding nearest location...
# Nearest location found: Silver Sands State Park
# Speed stored in speed_dict: Shenipsit State Forest -> Silver Sands State Park: 80 miles/h
# Speed stored in speed_dict: Silver Sands State Park -> Shenipsit State Forest: 80 miles/h
# Speed stored in speed_dict: Shenipsit State Forest -> Silver Sands State Park: 80 miles/h
# Current charge: 66.38348521428651, Required charge to next location: 35.700119893750305
# Inserting nearest location...
# Nearest location inserted into the tour.
# Updated Tour:
# Nearest Location: University of Connecticut
# Nearest Location: Windham Textile & History Museum
# Nearest Location: Windham Municipal Parking Lot, 48 Church St
# Nearest Location: Patriots Park
# Nearest Location: Connecticut Trolley Museum
# Nearest Location: Pratt & Whitney Stadium at Rentschler Field
# Nearest Location: Connecticut State Capitol
# Nearest Location: Wadsworth Falls State Park
# Nearest Location: Wharton Brook State Park
# Nearest Location: Yale University
# Nearest Location: Silver Sands State Park
# Nearest Location: Sleeping Giant State Park
# Nearest Location: Hubbard Park
# Nearest Location: Lake Compounce
# Nearest Location: Hill-Stead Museum
# Nearest Location: Connecticut State Capitol, 210 Capitol Ave
# Nearest Location: Greater Hartford Transit District - Spruce Street Lot, 1 Union Pl
# Nearest Location: Talcott Mountain State Park
# Nearest Location: New England Air Museum
# Nearest Location: Phelps-Hatheway House & Garden
# Nearest Location: Shenipsit State Forest
# Total Distance: 453.13822058534515
# Updated Charge: 30.683365320536204
# Speed: 80 miles/h
# Warning: Charge level below 60%. Looking for the nearest charging station.
# Finding nearest charging station...
# Nearest charging station found: Windham Town Hall, 979 Main St
# Inserting nearest charging station...
# Nearest charging station inserted into the tour.
# Total Distance After Charging Station Insertion: 453.13822058534515
# Finding nearest location...
# Nearest location found: Boothe Memorial Park and Museum
# Speed stored in speed_dict: Shenipsit State Forest -> Boothe Memorial Park and Museum: 53 miles/h
# Speed stored in speed_dict: Boothe Memorial Park and Museum -> Shenipsit State Forest: 53 miles/h
# Speed stored in speed_dict: Shenipsit State Forest -> Boothe Memorial Park and Museum: 53 miles/h
# Current charge: 90, Required charge to next location: 16.543669638112696
# Inserting nearest location...
# Nearest location inserted into the tour.
# Updated Tour:
# Nearest Location: University of Connecticut
# Nearest Location: Windham Textile & History Museum
# Nearest Location: Windham Municipal Parking Lot, 48 Church St
# Nearest Location: Windham Town Hall, 979 Main St
# Nearest Location: Patriots Park
# Nearest Location: Connecticut Trolley Museum
# Nearest Location: Pratt & Whitney Stadium at Rentschler Field
# Nearest Location: Connecticut State Capitol
# Nearest Location: Wadsworth Falls State Park
# Nearest Location: Wharton Brook State Park
# Nearest Location: Yale University
# Nearest Location: Silver Sands State Park
# Nearest Location: Boothe Memorial Park and Museum
# Nearest Location: Sleeping Giant State Park
# Nearest Location: Hubbard Park
# Nearest Location: Lake Compounce
# Nearest Location: Hill-Stead Museum
# Nearest Location: Connecticut State Capitol, 210 Capitol Ave
# Nearest Location: Greater Hartford Transit District - Spruce Street Lot, 1 Union Pl
# Nearest Location: Talcott Mountain State Park
# Nearest Location: New England Air Museum
# Nearest Location: Phelps-Hatheway House & Garden
# Nearest Location: Shenipsit State Forest
# Total Distance: 515.0469612812554
# Updated Charge: 73.4563303618873
# Speed: 53 miles/h
# Finding nearest location...
# Nearest location found: Seaside Park
# Speed stored in speed_dict: Shenipsit State Forest -> Seaside Park: 78 miles/h
# Speed stored in speed_dict: Seaside Park -> Shenipsit State Forest: 78 miles/h
# Speed stored in speed_dict: Shenipsit State Forest -> Seaside Park: 78 miles/h
# Current charge: 73.4563303618873, Required charge to next location: 37.15873214324392
# Inserting nearest location...
# Nearest location inserted into the tour.
# Updated Tour:
# Nearest Location: University of Connecticut
# Nearest Location: Windham Textile & History Museum
# Nearest Location: Windham Municipal Parking Lot, 48 Church St
# Nearest Location: Windham Town Hall, 979 Main St
# Nearest Location: Patriots Park
# Nearest Location: Connecticut Trolley Museum
# Nearest Location: Pratt & Whitney Stadium at Rentschler Field
# Nearest Location: Connecticut State Capitol
# Nearest Location: Wadsworth Falls State Park
# Nearest Location: Wharton Brook State Park
# Nearest Location: Yale University
# Nearest Location: Silver Sands State Park
# Nearest Location: Seaside Park
# Nearest Location: Boothe Memorial Park and Museum
# Nearest Location: Sleeping Giant State Park
# Nearest Location: Hubbard Park
# Nearest Location: Lake Compounce
# Nearest Location: Hill-Stead Museum
# Nearest Location: Connecticut State Capitol, 210 Capitol Ave
# Nearest Location: Greater Hartford Transit District - Spruce Street Lot, 1 Union Pl
# Nearest Location: Talcott Mountain State Park
# Nearest Location: New England Air Museum
# Nearest Location: Phelps-Hatheway House & Garden
# Nearest Location: Shenipsit State Forest
# Total Distance: 583.4738143847616
# Updated Charge: 36.29759821864338
# Speed: 78 miles/h
# Warning: Charge level below 60%. Looking for the nearest charging station.
# Finding nearest charging station...
# Nearest charging station found: 777 MAIN ST, 71 Asylum St
# Inserting nearest charging station...
# Nearest charging station inserted into the tour.
# Total Distance After Charging Station Insertion: 583.4738143847616
# Finding nearest location...
# Nearest location found: Fairfield Museum and History Center
# Speed stored in speed_dict: Shenipsit State Forest -> Fairfield Museum and History Center: 77 miles/h
# Speed stored in speed_dict: Fairfield Museum and History Center -> Shenipsit State Forest: 77 miles/h
# Speed stored in speed_dict: Shenipsit State Forest -> Fairfield Museum and History Center: 77 miles/h
# Current charge: 90, Required charge to next location: 37.86571728101313
# Inserting nearest location...
# Nearest location inserted into the tour.
# Updated Tour:
# Nearest Location: University of Connecticut
# Nearest Location: Windham Textile & History Museum
# Nearest Location: Windham Municipal Parking Lot, 48 Church St
# Nearest Location: Windham Town Hall, 979 Main St
# Nearest Location: Patriots Park
# Nearest Location: Connecticut Trolley Museum
# Nearest Location: Pratt & Whitney Stadium at Rentschler Field
# Nearest Location: 777 MAIN ST, 71 Asylum St
# Nearest Location: Connecticut State Capitol
# Nearest Location: Wadsworth Falls State Park
# Nearest Location: Wharton Brook State Park
# Nearest Location: Yale University
# Nearest Location: Silver Sands State Park
# Nearest Location: Seaside Park
# Nearest Location: Fairfield Museum and History Center
# Nearest Location: Boothe Memorial Park and Museum
# Nearest Location: Sleeping Giant State Park
# Nearest Location: Hubbard Park
# Nearest Location: Lake Compounce
# Nearest Location: Hill-Stead Museum
# Nearest Location: Connecticut State Capitol, 210 Capitol Ave
# Nearest Location: Greater Hartford Transit District - Spruce Street Lot, 1 Union Pl
# Nearest Location: Talcott Mountain State Park
# Nearest Location: New England Air Museum
# Nearest Location: Phelps-Hatheway House & Garden
# Nearest Location: Shenipsit State Forest
# Total Distance: 654.920017328891
# Updated Charge: 52.13428271898687
# Speed: 77 miles/h
# Warning: Charge level below 60%. Looking for the nearest charging station.
# Finding nearest charging station...
# Nearest charging station found: 777 Main Street - Tesla Supercharger, 777 Main Street
# Inserting nearest charging station...
# Nearest charging station inserted into the tour.
# Total Distance After Charging Station Insertion: 654.920017328891
# Finding nearest location...
# Nearest location found: Westport Country Playhouse
# Speed stored in speed_dict: Shenipsit State Forest -> Westport Country Playhouse: 52 miles/h
# Speed stored in speed_dict: Westport Country Playhouse -> Shenipsit State Forest: 52 miles/h
# Speed stored in speed_dict: Shenipsit State Forest -> Westport Country Playhouse: 52 miles/h
# Current charge: 90, Required charge to next location: 19.345251708947362
# Inserting nearest location...
# Nearest location inserted into the tour.
# Updated Tour:
# Nearest Location: University of Connecticut
# Nearest Location: Windham Textile & History Museum
# Nearest Location: Windham Municipal Parking Lot, 48 Church St
# Nearest Location: Windham Town Hall, 979 Main St
# Nearest Location: Patriots Park
# Nearest Location: Connecticut Trolley Museum
# Nearest Location: Pratt & Whitney Stadium at Rentschler Field
# Nearest Location: 777 Main Street - Tesla Supercharger, 777 Main Street
# Nearest Location: 777 MAIN ST, 71 Asylum St
# Nearest Location: Connecticut State Capitol
# Nearest Location: Wadsworth Falls State Park
# Nearest Location: Wharton Brook State Park
# Nearest Location: Yale University
# Nearest Location: Silver Sands State Park
# Nearest Location: Seaside Park
# Nearest Location: Fairfield Museum and History Center
# Nearest Location: Westport Country Playhouse
# Nearest Location: Boothe Memorial Park and Museum
# Nearest Location: Sleeping Giant State Park
# Nearest Location: Hubbard Park
# Nearest Location: Lake Compounce
# Nearest Location: Hill-Stead Museum
# Nearest Location: Connecticut State Capitol, 210 Capitol Ave
# Nearest Location: Greater Hartford Transit District - Spruce Street Lot, 1 Union Pl
# Nearest Location: Talcott Mountain State Park
# Nearest Location: New England Air Museum
# Nearest Location: Phelps-Hatheway House & Garden
# Nearest Location: Shenipsit State Forest
# Total Distance: 729.7902508824615
# Updated Charge: 70.65474829105264
# Speed: 52 miles/h
# Finding nearest location...
# Nearest location found: The Maritime Aquarium
# Speed stored in speed_dict: Shenipsit State Forest -> The Maritime Aquarium: 68 miles/h
# Speed stored in speed_dict: The Maritime Aquarium -> Shenipsit State Forest: 68 miles/h
# Speed stored in speed_dict: Shenipsit State Forest -> The Maritime Aquarium: 68 miles/h
# Current charge: 70.65474829105264, Required charge to next location: 33.23835030910177
# Inserting nearest location...
# Nearest location inserted into the tour.
# Updated Tour:
# Nearest Location: University of Connecticut
# Nearest Location: Windham Textile & History Museum
# Nearest Location: Windham Municipal Parking Lot, 48 Church St
# Nearest Location: Windham Town Hall, 979 Main St
# Nearest Location: Patriots Park
# Nearest Location: Connecticut Trolley Museum
# Nearest Location: Pratt & Whitney Stadium at Rentschler Field
# Nearest Location: 777 Main Street - Tesla Supercharger, 777 Main Street
# Nearest Location: 777 MAIN ST, 71 Asylum St
# Nearest Location: Connecticut State Capitol
# Nearest Location: Wadsworth Falls State Park
# Nearest Location: Wharton Brook State Park
# Nearest Location: Yale University
# Nearest Location: Silver Sands State Park
# Nearest Location: Seaside Park
# Nearest Location: Fairfield Museum and History Center
# Nearest Location: The Maritime Aquarium
# Nearest Location: Westport Country Playhouse
# Nearest Location: Boothe Memorial Park and Museum
# Nearest Location: Sleeping Giant State Park
# Nearest Location: Hubbard Park
# Nearest Location: Lake Compounce
# Nearest Location: Hill-Stead Museum
# Nearest Location: Connecticut State Capitol, 210 Capitol Ave
# Nearest Location: Greater Hartford Transit District - Spruce Street Lot, 1 Union Pl
# Nearest Location: Talcott Mountain State Park
# Nearest Location: New England Air Museum
# Nearest Location: Phelps-Hatheway House & Garden
# Nearest Location: Shenipsit State Forest
# Total Distance: 808.913402656606
# Updated Charge: 37.41639798195087
# Speed: 68 miles/h
# Warning: Charge level below 60%. Looking for the nearest charging station.
# Finding nearest charging station...
# Nearest charging station found: SPIREP, 1 N Water St
# Inserting nearest charging station...
# Nearest charging station inserted into the tour.
# Total Distance After Charging Station Insertion: 808.913402656606
# Finding nearest location...
# Nearest location found: Stamford Museum & Nature Center
# Speed stored in speed_dict: Shenipsit State Forest -> Stamford Museum & Nature Center: 51 miles/h
# Speed stored in speed_dict: Stamford Museum & Nature Center -> Shenipsit State Forest: 51 miles/h
# Speed stored in speed_dict: Shenipsit State Forest -> Stamford Museum & Nature Center: 51 miles/h
# Current charge: 90, Required charge to next location: 20.593544279580758
# Inserting nearest location...
# Nearest location inserted into the tour.
# Updated Tour:
# Nearest Location: University of Connecticut
# Nearest Location: Windham Textile & History Museum
# Nearest Location: Windham Municipal Parking Lot, 48 Church St
# Nearest Location: Windham Town Hall, 979 Main St
# Nearest Location: Patriots Park
# Nearest Location: Connecticut Trolley Museum
# Nearest Location: Pratt & Whitney Stadium at Rentschler Field
# Nearest Location: 777 Main Street - Tesla Supercharger, 777 Main Street
# Nearest Location: 777 MAIN ST, 71 Asylum St
# Nearest Location: Connecticut State Capitol
# Nearest Location: Wadsworth Falls State Park
# Nearest Location: Wharton Brook State Park
# Nearest Location: Yale University
# Nearest Location: Silver Sands State Park
# Nearest Location: Seaside Park
# Nearest Location: Fairfield Museum and History Center
# Nearest Location: SPIREP, 1 N Water St
# Nearest Location: Stamford Museum & Nature Center
# Nearest Location: The Maritime Aquarium
# Nearest Location: Westport Country Playhouse
# Nearest Location: Boothe Memorial Park and Museum
# Nearest Location: Sleeping Giant State Park
# Nearest Location: Hubbard Park
# Nearest Location: Lake Compounce
# Nearest Location: Hill-Stead Museum
# Nearest Location: Connecticut State Capitol, 210 Capitol Ave
# Nearest Location: Greater Hartford Transit District - Spruce Street Lot, 1 Union Pl
# Nearest Location: Talcott Mountain State Park
# Nearest Location: New England Air Museum
# Nearest Location: Phelps-Hatheway House & Garden
# Nearest Location: Shenipsit State Forest
# Total Distance: 891.3835028101701
# Updated Charge: 69.40645572041925
# Speed: 51 miles/h
# Finding nearest location...
# Nearest location found: Bruce Museum
# Speed stored in speed_dict: Shenipsit State Forest -> Bruce Museum: 57 miles/h
# Speed stored in speed_dict: Bruce Museum -> Shenipsit State Forest: 57 miles/h
# Speed stored in speed_dict: Shenipsit State Forest -> Bruce Museum: 57 miles/h
# Current charge: 69.40645572041925, Required charge to next location: 27.54888006665837
# Inserting nearest location...
# Nearest location inserted into the tour.
# Updated Tour:
# Nearest Location: University of Connecticut
# Nearest Location: Windham Textile & History Museum
# Nearest Location: Windham Municipal Parking Lot, 48 Church St
# Nearest Location: Windham Town Hall, 979 Main St
# Nearest Location: Patriots Park
# Nearest Location: Connecticut Trolley Museum
# Nearest Location: Pratt & Whitney Stadium at Rentschler Field
# Nearest Location: 777 Main Street - Tesla Supercharger, 777 Main Street
# Nearest Location: 777 MAIN ST, 71 Asylum St
# Nearest Location: Connecticut State Capitol
# Nearest Location: Wadsworth Falls State Park
# Nearest Location: Wharton Brook State Park
# Nearest Location: Yale University
# Nearest Location: Silver Sands State Park
# Nearest Location: Seaside Park
# Nearest Location: Fairfield Museum and History Center
# Nearest Location: Bruce Museum
# Nearest Location: SPIREP, 1 N Water St
# Nearest Location: Stamford Museum & Nature Center
# Nearest Location: The Maritime Aquarium
# Nearest Location: Westport Country Playhouse
# Nearest Location: Boothe Memorial Park and Museum
# Nearest Location: Sleeping Giant State Park
# Nearest Location: Hubbard Park
# Nearest Location: Lake Compounce
# Nearest Location: Hill-Stead Museum
# Nearest Location: Connecticut State Capitol, 210 Capitol Ave
# Nearest Location: Greater Hartford Transit District - Spruce Street Lot, 1 Union Pl
# Nearest Location: Talcott Mountain State Park
# Nearest Location: New England Air Museum
# Nearest Location: Phelps-Hatheway House & Garden
# Nearest Location: Shenipsit State Forest
# Total Distance: 981.9205452868807
# Updated Charge: 41.857575653760875
# Speed: 57 miles/h
# Warning: Charge level below 60%. Looking for the nearest charging station.
# Finding nearest charging station...
# Nearest charging station found: Delamar Greenwich Harbor - Tesla Destination, 500 Steamboat Rd
# Inserting nearest charging station...
# Nearest charging station inserted into the tour.
# Total Distance After Charging Station Insertion: 981.9205452868807
# Finding nearest location...
# Nearest location found: Pequonnock River Trail
# Speed stored in speed_dict: Shenipsit State Forest -> Pequonnock River Trail: 74 miles/h
# Speed stored in speed_dict: Pequonnock River Trail -> Shenipsit State Forest: 74 miles/h
# Speed stored in speed_dict: Shenipsit State Forest -> Pequonnock River Trail: 74 miles/h
# Current charge: 90, Required charge to next location: 30.316332416970237
# Inserting nearest location...
# Nearest location inserted into the tour.
# Updated Tour:
# Nearest Location: University of Connecticut
# Nearest Location: Windham Textile & History Museum
# Nearest Location: Windham Municipal Parking Lot, 48 Church St
# Nearest Location: Windham Town Hall, 979 Main St
# Nearest Location: Patriots Park
# Nearest Location: Connecticut Trolley Museum
# Nearest Location: Pratt & Whitney Stadium at Rentschler Field
# Nearest Location: 777 Main Street - Tesla Supercharger, 777 Main Street
# Nearest Location: 777 MAIN ST, 71 Asylum St
# Nearest Location: Connecticut State Capitol
# Nearest Location: Wadsworth Falls State Park
# Nearest Location: Wharton Brook State Park
# Nearest Location: Yale University
# Nearest Location: Silver Sands State Park
# Nearest Location: Seaside Park
# Nearest Location: Fairfield Museum and History Center
# Nearest Location: Delamar Greenwich Harbor - Tesla Destination, 500 Steamboat Rd
# Nearest Location: Bruce Museum
# Nearest Location: SPIREP, 1 N Water St
# Nearest Location: Stamford Museum & Nature Center
# Nearest Location: The Maritime Aquarium
# Nearest Location: Westport Country Playhouse
# Nearest Location: Pequonnock River Trail
# Nearest Location: Boothe Memorial Park and Museum
# Nearest Location: Sleeping Giant State Park
# Nearest Location: Hubbard Park
# Nearest Location: Lake Compounce
# Nearest Location: Hill-Stead Museum
# Nearest Location: Connecticut State Capitol, 210 Capitol Ave
# Nearest Location: Greater Hartford Transit District - Spruce Street Lot, 1 Union Pl
# Nearest Location: Talcott Mountain State Park
# Nearest Location: New England Air Museum
# Nearest Location: Phelps-Hatheway House & Garden
# Nearest Location: Shenipsit State Forest
# Total Distance: 1043.5593871659446
# Updated Charge: 59.68366758302976
# Speed: 74 miles/h
# Finding nearest location...
# Nearest location found: Kettletown State Park
# Speed stored in speed_dict: Shenipsit State Forest -> Kettletown State Park: 62 miles/h
# Speed stored in speed_dict: Kettletown State Park -> Shenipsit State Forest: 62 miles/h
# Speed stored in speed_dict: Shenipsit State Forest -> Kettletown State Park: 62 miles/h
# Current charge: 59.68366758302976, Required charge to next location: 19.58860879610639
# Inserting nearest location...
# Nearest location inserted into the tour.
# Updated Tour:
# Nearest Location: University of Connecticut
# Nearest Location: Windham Textile & History Museum
# Nearest Location: Windham Municipal Parking Lot, 48 Church St
# Nearest Location: Windham Town Hall, 979 Main St
# Nearest Location: Patriots Park
# Nearest Location: Connecticut Trolley Museum
# Nearest Location: Pratt & Whitney Stadium at Rentschler Field
# Nearest Location: 777 Main Street - Tesla Supercharger, 777 Main Street
# Nearest Location: 777 MAIN ST, 71 Asylum St
# Nearest Location: Connecticut State Capitol
# Nearest Location: Wadsworth Falls State Park
# Nearest Location: Wharton Brook State Park
# Nearest Location: Yale University
# Nearest Location: Silver Sands State Park
# Nearest Location: Seaside Park
# Nearest Location: Fairfield Museum and History Center
# Nearest Location: Delamar Greenwich Harbor - Tesla Destination, 500 Steamboat Rd
# Nearest Location: Bruce Museum
# Nearest Location: SPIREP, 1 N Water St
# Nearest Location: Stamford Museum & Nature Center
# Nearest Location: The Maritime Aquarium
# Nearest Location: Westport Country Playhouse
# Nearest Location: Pequonnock River Trail
# Nearest Location: Kettletown State Park
# Nearest Location: Boothe Memorial Park and Museum
# Nearest Location: Sleeping Giant State Park
# Nearest Location: Hubbard Park
# Nearest Location: Lake Compounce
# Nearest Location: Hill-Stead Museum
# Nearest Location: Connecticut State Capitol, 210 Capitol Ave
# Nearest Location: Greater Hartford Transit District - Spruce Street Lot, 1 Union Pl
# Nearest Location: Talcott Mountain State Park
# Nearest Location: New England Air Museum
# Nearest Location: Phelps-Hatheway House & Garden
# Nearest Location: Shenipsit State Forest
# Total Distance: 1098.8330576021485
# Updated Charge: 40.095058786923374
# Speed: 62 miles/h
# Warning: Charge level below 60%. Looking for the nearest charging station.
# Finding nearest charging station...
# Nearest charging station found: State House Square, 10-90 State House Square
# Inserting nearest charging station...
# Nearest charging station inserted into the tour.
# Total Distance After Charging Station Insertion: 1098.8330576021485
# Finding nearest location...
# Nearest location found: Tarrywile Park & Mansion
# Speed stored in speed_dict: Shenipsit State Forest -> Tarrywile Park & Mansion: 72 miles/h
# Speed stored in speed_dict: Tarrywile Park & Mansion -> Shenipsit State Forest: 72 miles/h
# Speed stored in speed_dict: Shenipsit State Forest -> Tarrywile Park & Mansion: 72 miles/h
# Current charge: 90, Required charge to next location: 31.455567924134396
# Inserting nearest location...
# Nearest location inserted into the tour.
# Updated Tour:
# Nearest Location: University of Connecticut
# Nearest Location: Windham Textile & History Museum
# Nearest Location: Windham Municipal Parking Lot, 48 Church St
# Nearest Location: Windham Town Hall, 979 Main St
# Nearest Location: Patriots Park
# Nearest Location: Connecticut Trolley Museum
# Nearest Location: Pratt & Whitney Stadium at Rentschler Field
# Nearest Location: State House Square, 10-90 State House Square
# Nearest Location: 777 Main Street - Tesla Supercharger, 777 Main Street
# Nearest Location: 777 MAIN ST, 71 Asylum St
# Nearest Location: Connecticut State Capitol
# Nearest Location: Wadsworth Falls State Park
# Nearest Location: Wharton Brook State Park
# Nearest Location: Yale University
# Nearest Location: Silver Sands State Park
# Nearest Location: Seaside Park
# Nearest Location: Fairfield Museum and History Center
# Nearest Location: Delamar Greenwich Harbor - Tesla Destination, 500 Steamboat Rd
# Nearest Location: Bruce Museum
# Nearest Location: SPIREP, 1 N Water St
# Nearest Location: Stamford Museum & Nature Center
# Nearest Location: The Maritime Aquarium
# Nearest Location: Westport Country Playhouse
# Nearest Location: Tarrywile Park & Mansion
# Nearest Location: Pequonnock River Trail
# Nearest Location: Kettletown State Park
# Nearest Location: Boothe Memorial Park and Museum
# Nearest Location: Sleeping Giant State Park
# Nearest Location: Hubbard Park
# Nearest Location: Lake Compounce
# Nearest Location: Hill-Stead Museum
# Nearest Location: Connecticut State Capitol, 210 Capitol Ave
# Nearest Location: Greater Hartford Transit District - Spruce Street Lot, 1 Union Pl
# Nearest Location: Talcott Mountain State Park
# Nearest Location: New England Air Museum
# Nearest Location: Phelps-Hatheway House & Garden
# Nearest Location: Shenipsit State Forest
# Total Distance: 1166.1542355123713
# Updated Charge: 58.5444320758656
# Speed: 72 miles/h
# Finding nearest location...
# Nearest location found: Lover's Leap State Park
# Speed stored in speed_dict: Shenipsit State Forest -> Lover's Leap State Park: 58 miles/h
# Speed stored in speed_dict: Lover's Leap State Park -> Shenipsit State Forest: 58 miles/h
# Speed stored in speed_dict: Shenipsit State Forest -> Lover's Leap State Park: 58 miles/h
# Current charge: 58.5444320758656, Required charge to next location: 18.596095062606118
# Inserting nearest location...
# Nearest location inserted into the tour.
# Updated Tour:
# Nearest Location: University of Connecticut
# Nearest Location: Windham Textile & History Museum
# Nearest Location: Windham Municipal Parking Lot, 48 Church St
# Nearest Location: Windham Town Hall, 979 Main St
# Nearest Location: Patriots Park
# Nearest Location: Connecticut Trolley Museum
# Nearest Location: Pratt & Whitney Stadium at Rentschler Field
# Nearest Location: State House Square, 10-90 State House Square
# Nearest Location: 777 Main Street - Tesla Supercharger, 777 Main Street
# Nearest Location: 777 MAIN ST, 71 Asylum St
# Nearest Location: Connecticut State Capitol
# Nearest Location: Wadsworth Falls State Park
# Nearest Location: Wharton Brook State Park
# Nearest Location: Yale University
# Nearest Location: Silver Sands State Park
# Nearest Location: Seaside Park
# Nearest Location: Fairfield Museum and History Center
# Nearest Location: Delamar Greenwich Harbor - Tesla Destination, 500 Steamboat Rd
# Nearest Location: Bruce Museum
# Nearest Location: SPIREP, 1 N Water St
# Nearest Location: Stamford Museum & Nature Center
# Nearest Location: The Maritime Aquarium
# Nearest Location: Westport Country Playhouse
# Nearest Location: Tarrywile Park & Mansion
# Nearest Location: Lover's Leap State Park
# Nearest Location: Pequonnock River Trail
# Nearest Location: Kettletown State Park
# Nearest Location: Boothe Memorial Park and Museum
# Nearest Location: Sleeping Giant State Park
# Nearest Location: Hubbard Park
# Nearest Location: Lake Compounce
# Nearest Location: Hill-Stead Museum
# Nearest Location: Connecticut State Capitol, 210 Capitol Ave
# Nearest Location: Greater Hartford Transit District - Spruce Street Lot, 1 Union Pl
# Nearest Location: Talcott Mountain State Park
# Nearest Location: New England Air Museum
# Nearest Location: Phelps-Hatheway House & Garden
# Nearest Location: Shenipsit State Forest
# Total Distance: 1225.3834807187313
# Updated Charge: 39.94833701325948
# Speed: 58 miles/h
# Warning: Charge level below 60%. Looking for the nearest charging station.
# Finding nearest charging station...
# Nearest charging station found: Constitution Plaza - South, 109 Constitution Plaza
# Inserting nearest charging station...
# Nearest charging station inserted into the tour.
# Total Distance After Charging Station Insertion: 1225.3834807187313
# Finding nearest location...
# Nearest location found: Mohegan Park
# Speed stored in speed_dict: Shenipsit State Forest -> Mohegan Park: 74 miles/h
# Speed stored in speed_dict: Mohegan Park -> Shenipsit State Forest: 74 miles/h
# Speed stored in speed_dict: Shenipsit State Forest -> Mohegan Park: 74 miles/h
# Current charge: 90, Required charge to next location: 16.49061677572601
# Inserting nearest location...
# Nearest location inserted into the tour.
# Updated Tour:
# Nearest Location: University of Connecticut
# Nearest Location: Windham Textile & History Museum
# Nearest Location: Mohegan Park
# Nearest Location: Windham Municipal Parking Lot, 48 Church St
# Nearest Location: Windham Town Hall, 979 Main St
# Nearest Location: Patriots Park
# Nearest Location: Connecticut Trolley Museum
# Nearest Location: Pratt & Whitney Stadium at Rentschler Field
# Nearest Location: Constitution Plaza - South, 109 Constitution Plaza
# Nearest Location: State House Square, 10-90 State House Square
# Nearest Location: 777 Main Street - Tesla Supercharger, 777 Main Street
# Nearest Location: 777 MAIN ST, 71 Asylum St
# Nearest Location: Connecticut State Capitol
# Nearest Location: Wadsworth Falls State Park
# Nearest Location: Wharton Brook State Park
# Nearest Location: Yale University
# Nearest Location: Silver Sands State Park
# Nearest Location: Seaside Park
# Nearest Location: Fairfield Museum and History Center
# Nearest Location: Delamar Greenwich Harbor - Tesla Destination, 500 Steamboat Rd
# Nearest Location: Bruce Museum
# Nearest Location: SPIREP, 1 N Water St
# Nearest Location: Stamford Museum & Nature Center
# Nearest Location: The Maritime Aquarium
# Nearest Location: Westport Country Playhouse
# Nearest Location: Tarrywile Park & Mansion
# Nearest Location: Lover's Leap State Park
# Nearest Location: Pequonnock River Trail
# Nearest Location: Kettletown State Park
# Nearest Location: Boothe Memorial Park and Museum
# Nearest Location: Sleeping Giant State Park
# Nearest Location: Hubbard Park
# Nearest Location: Lake Compounce
# Nearest Location: Hill-Stead Museum
# Nearest Location: Connecticut State Capitol, 210 Capitol Ave
# Nearest Location: Greater Hartford Transit District - Spruce Street Lot, 1 Union Pl
# Nearest Location: Talcott Mountain State Park
# Nearest Location: New England Air Museum
# Nearest Location: Phelps-Hatheway House & Garden
# Nearest Location: Shenipsit State Forest
# Total Distance: 1258.9120258589155
# Updated Charge: 73.50938322427399
# Speed: 74 miles/h
# Finding nearest location...
# Nearest location found: Mystic Seaport Museum
# Speed stored in speed_dict: Shenipsit State Forest -> Mystic Seaport Museum: 80 miles/h
# Speed stored in speed_dict: Mystic Seaport Museum -> Shenipsit State Forest: 80 miles/h
# Speed stored in speed_dict: Shenipsit State Forest -> Mystic Seaport Museum: 80 miles/h
# Current charge: 73.50938322427399, Required charge to next location: 26.995305987732294
# Inserting nearest location...
# Nearest location inserted into the tour.
# Updated Tour:
# Nearest Location: University of Connecticut
# Nearest Location: Windham Textile & History Museum
# Nearest Location: Mohegan Park
# Nearest Location: Mystic Seaport Museum
# Nearest Location: Windham Municipal Parking Lot, 48 Church St
# Nearest Location: Windham Town Hall, 979 Main St
# Nearest Location: Patriots Park
# Nearest Location: Connecticut Trolley Museum
# Nearest Location: Pratt & Whitney Stadium at Rentschler Field
# Nearest Location: Constitution Plaza - South, 109 Constitution Plaza
# Nearest Location: State House Square, 10-90 State House Square
# Nearest Location: 777 Main Street - Tesla Supercharger, 777 Main Street
# Nearest Location: 777 MAIN ST, 71 Asylum St
# Nearest Location: Connecticut State Capitol
# Nearest Location: Wadsworth Falls State Park
# Nearest Location: Wharton Brook State Park
# Nearest Location: Yale University
# Nearest Location: Silver Sands State Park
# Nearest Location: Seaside Park
# Nearest Location: Fairfield Museum and History Center
# Nearest Location: Delamar Greenwich Harbor - Tesla Destination, 500 Steamboat Rd
# Nearest Location: Bruce Museum
# Nearest Location: SPIREP, 1 N Water St
# Nearest Location: Stamford Museum & Nature Center
# Nearest Location: The Maritime Aquarium
# Nearest Location: Westport Country Playhouse
# Nearest Location: Tarrywile Park & Mansion
# Nearest Location: Lover's Leap State Park
# Nearest Location: Pequonnock River Trail
# Nearest Location: Kettletown State Park
# Nearest Location: Boothe Memorial Park and Museum
# Nearest Location: Sleeping Giant State Park
# Nearest Location: Hubbard Park
# Nearest Location: Lake Compounce
# Nearest Location: Hill-Stead Museum
# Nearest Location: Connecticut State Capitol, 210 Capitol Ave
# Nearest Location: Greater Hartford Transit District - Spruce Street Lot, 1 Union Pl
# Nearest Location: Talcott Mountain State Park
# Nearest Location: New England Air Museum
# Nearest Location: Phelps-Hatheway House & Garden
# Nearest Location: Shenipsit State Forest
# Total Distance: 1306.3007905529435
# Updated Charge: 46.514077236541695
# Speed: 80 miles/h
# Warning: Charge level below 60%. Looking for the nearest charging station.
# Finding nearest charging station...
# Nearest charging station found: Morgan Street Garage, 155 Morgan St
# Inserting nearest charging station...
# Nearest charging station inserted into the tour.
# Total Distance After Charging Station Insertion: 1306.3007905529435
# Finding nearest location...
# Nearest location found: Fort Trumbull State Park
# Speed stored in speed_dict: Shenipsit State Forest -> Fort Trumbull State Park: 71 miles/h
# Speed stored in speed_dict: Fort Trumbull State Park -> Shenipsit State Forest: 71 miles/h
# Speed stored in speed_dict: Shenipsit State Forest -> Fort Trumbull State Park: 71 miles/h
# Current charge: 90, Required charge to next location: 20.76596906558362
# Inserting nearest location...
# Nearest location inserted into the tour.
# Updated Tour:
# Nearest Location: University of Connecticut
# Nearest Location: Windham Textile & History Museum
# Nearest Location: Mohegan Park
# Nearest Location: Fort Trumbull State Park
# Nearest Location: Mystic Seaport Museum
# Nearest Location: Windham Municipal Parking Lot, 48 Church St
# Nearest Location: Windham Town Hall, 979 Main St
# Nearest Location: Patriots Park
# Nearest Location: Connecticut Trolley Museum
# Nearest Location: Pratt & Whitney Stadium at Rentschler Field
# Nearest Location: Constitution Plaza - South, 109 Constitution Plaza
# Nearest Location: State House Square, 10-90 State House Square
# Nearest Location: Morgan Street Garage, 155 Morgan St
# Nearest Location: 777 Main Street - Tesla Supercharger, 777 Main Street
# Nearest Location: 777 MAIN ST, 71 Asylum St
# Nearest Location: Connecticut State Capitol
# Nearest Location: Wadsworth Falls State Park
# Nearest Location: Wharton Brook State Park
# Nearest Location: Yale University
# Nearest Location: Silver Sands State Park
# Nearest Location: Seaside Park
# Nearest Location: Fairfield Museum and History Center
# Nearest Location: Delamar Greenwich Harbor - Tesla Destination, 500 Steamboat Rd
# Nearest Location: Bruce Museum
# Nearest Location: SPIREP, 1 N Water St
# Nearest Location: Stamford Museum & Nature Center
# Nearest Location: The Maritime Aquarium
# Nearest Location: Westport Country Playhouse
# Nearest Location: Tarrywile Park & Mansion
# Nearest Location: Lover's Leap State Park
# Nearest Location: Pequonnock River Trail
# Nearest Location: Kettletown State Park
# Nearest Location: Boothe Memorial Park and Museum
# Nearest Location: Sleeping Giant State Park
# Nearest Location: Hubbard Park
# Nearest Location: Lake Compounce
# Nearest Location: Hill-Stead Museum
# Nearest Location: Connecticut State Capitol, 210 Capitol Ave
# Nearest Location: Greater Hartford Transit District - Spruce Street Lot, 1 Union Pl
# Nearest Location: Talcott Mountain State Park
# Nearest Location: New England Air Museum
# Nearest Location: Phelps-Hatheway House & Garden
# Nearest Location: Shenipsit State Forest
# Total Distance: 1351.9199329821054
# Updated Charge: 69.23403093441638
# Speed: 71 miles/h
# Finding nearest location...
# Nearest location found: Burr Pond State Park
# Speed stored in speed_dict: Shenipsit State Forest -> Burr Pond State Park: 68 miles/h
# Speed stored in speed_dict: Burr Pond State Park -> Shenipsit State Forest: 68 miles/h
# Speed stored in speed_dict: Shenipsit State Forest -> Burr Pond State Park: 68 miles/h
# Current charge: 69.23403093441638, Required charge to next location: 15.051553259557334
# Inserting nearest location...
# Nearest location inserted into the tour.
# Updated Tour:
# Nearest Location: University of Connecticut
# Nearest Location: Windham Textile & History Museum
# Nearest Location: Mohegan Park
# Nearest Location: Fort Trumbull State Park
# Nearest Location: Mystic Seaport Museum
# Nearest Location: Windham Municipal Parking Lot, 48 Church St
# Nearest Location: Windham Town Hall, 979 Main St
# Nearest Location: Patriots Park
# Nearest Location: Connecticut Trolley Museum
# Nearest Location: Pratt & Whitney Stadium at Rentschler Field
# Nearest Location: Constitution Plaza - South, 109 Constitution Plaza
# Nearest Location: State House Square, 10-90 State House Square
# Nearest Location: Morgan Street Garage, 155 Morgan St
# Nearest Location: 777 Main Street - Tesla Supercharger, 777 Main Street
# Nearest Location: 777 MAIN ST, 71 Asylum St
# Nearest Location: Connecticut State Capitol
# Nearest Location: Wadsworth Falls State Park
# Nearest Location: Wharton Brook State Park
# Nearest Location: Yale University
# Nearest Location: Silver Sands State Park
# Nearest Location: Seaside Park
# Nearest Location: Fairfield Museum and History Center
# Nearest Location: Delamar Greenwich Harbor - Tesla Destination, 500 Steamboat Rd
# Nearest Location: Bruce Museum
# Nearest Location: SPIREP, 1 N Water St
# Nearest Location: Stamford Museum & Nature Center
# Nearest Location: The Maritime Aquarium
# Nearest Location: Westport Country Playhouse
# Nearest Location: Tarrywile Park & Mansion
# Nearest Location: Lover's Leap State Park
# Nearest Location: Pequonnock River Trail
# Nearest Location: Kettletown State Park
# Nearest Location: Boothe Memorial Park and Museum
# Nearest Location: Sleeping Giant State Park
# Nearest Location: Hubbard Park
# Nearest Location: Lake Compounce
# Nearest Location: Hill-Stead Museum
# Nearest Location: Connecticut State Capitol, 210 Capitol Ave
# Nearest Location: Greater Hartford Transit District - Spruce Street Lot, 1 Union Pl
# Nearest Location: Burr Pond State Park
# Nearest Location: Talcott Mountain State Park
# Nearest Location: New England Air Museum
# Nearest Location: Phelps-Hatheway House & Garden
# Nearest Location: Shenipsit State Forest
# Total Distance: 1387.7498199024096
# Updated Charge: 54.182477674859044
# Speed: 68 miles/h
# Finding nearest location...
# Nearest location found: Rotary Park & Bandstand
# Speed stored in speed_dict: Shenipsit State Forest -> Rotary Park & Bandstand: 64 miles/h
# Speed stored in speed_dict: Rotary Park & Bandstand -> Shenipsit State Forest: 64 miles/h
# Speed stored in speed_dict: Shenipsit State Forest -> Rotary Park & Bandstand: 64 miles/h
# Current charge: 54.182477674859044, Required charge to next location: 9.692855428732958
# Inserting nearest location...
# Nearest location inserted into the tour.
# Updated Tour:
# Nearest Location: University of Connecticut
# Nearest Location: Windham Textile & History Museum
# Nearest Location: Mohegan Park
# Nearest Location: Fort Trumbull State Park
# Nearest Location: Mystic Seaport Museum
# Nearest Location: Rotary Park & Bandstand
# Nearest Location: Windham Municipal Parking Lot, 48 Church St
# Nearest Location: Windham Town Hall, 979 Main St
# Nearest Location: Patriots Park
# Nearest Location: Connecticut Trolley Museum
# Nearest Location: Pratt & Whitney Stadium at Rentschler Field
# Nearest Location: Constitution Plaza - South, 109 Constitution Plaza
# Nearest Location: State House Square, 10-90 State House Square
# Nearest Location: Morgan Street Garage, 155 Morgan St
# Nearest Location: 777 Main Street - Tesla Supercharger, 777 Main Street
# Nearest Location: 777 MAIN ST, 71 Asylum St
# Nearest Location: Connecticut State Capitol
# Nearest Location: Wadsworth Falls State Park
# Nearest Location: Wharton Brook State Park
# Nearest Location: Yale University
# Nearest Location: Silver Sands State Park
# Nearest Location: Seaside Park
# Nearest Location: Fairfield Museum and History Center
# Nearest Location: Delamar Greenwich Harbor - Tesla Destination, 500 Steamboat Rd
# Nearest Location: Bruce Museum
# Nearest Location: SPIREP, 1 N Water St
# Nearest Location: Stamford Museum & Nature Center
# Nearest Location: The Maritime Aquarium
# Nearest Location: Westport Country Playhouse
# Nearest Location: Tarrywile Park & Mansion
# Nearest Location: Lover's Leap State Park
# Nearest Location: Pequonnock River Trail
# Nearest Location: Kettletown State Park
# Nearest Location: Boothe Memorial Park and Museum
# Nearest Location: Sleeping Giant State Park
# Nearest Location: Hubbard Park
# Nearest Location: Lake Compounce
# Nearest Location: Hill-Stead Museum
# Nearest Location: Connecticut State Capitol, 210 Capitol Ave
# Nearest Location: Greater Hartford Transit District - Spruce Street Lot, 1 Union Pl
# Nearest Location: Burr Pond State Park
# Nearest Location: Talcott Mountain State Park
# Nearest Location: New England Air Museum
# Nearest Location: Phelps-Hatheway House & Garden
# Nearest Location: Shenipsit State Forest
# Total Distance: 1413.5550278206852
# Updated Charge: 44.48962224612609
# Speed: 64 miles/h
# Warning: Charge level below 60%. Looking for the nearest charging station.
# Finding nearest charging station...
# Nearest charging station found: Cargill Chevrolet, 23 Livery St
# Inserting nearest charging station...
# Nearest charging station inserted into the tour.
# Total Distance After Charging Station Insertion: 1413.5550278206852
# Nearest Insertion Algorithm completed after 0 iterations.
# Tour:
# Nearest Location: University of Connecticut
# Nearest Location: Windham Textile & History Museum
# Nearest Location: Mohegan Park
# Nearest Location: Fort Trumbull State Park
# Nearest Location: Mystic Seaport Museum
# Nearest Charging Station: Cargill Chevrolet, 23 Livery St
# Nearest Location: Rotary Park & Bandstand
# Nearest Charging Station: Windham Municipal Parking Lot, 48 Church St
# Nearest Charging Station: Windham Town Hall, 979 Main St
# Nearest Location: Patriots Park
# Nearest Location: Connecticut Trolley Museum
# Nearest Location: Pratt & Whitney Stadium at Rentschler Field
# Nearest Charging Station: Constitution Plaza - South, 109 Constitution Plaza
# Nearest Charging Station: State House Square, 10-90 State House Square
# Nearest Charging Station: Morgan Street Garage, 155 Morgan St
# Nearest Charging Station: 777 Main Street - Tesla Supercharger, 777 Main Street
# Nearest Charging Station: 777 MAIN ST, 71 Asylum St
# Nearest Location: Connecticut State Capitol
# Nearest Location: Wadsworth Falls State Park
# Nearest Location: Wharton Brook State Park
# Nearest Location: Yale University
# Nearest Location: Silver Sands State Park
# Nearest Location: Seaside Park
# Nearest Location: Fairfield Museum and History Center
# Nearest Charging Station: Delamar Greenwich Harbor - Tesla Destination, 500 Steamboat Rd
# Nearest Location: Bruce Museum
# Nearest Charging Station: SPIREP, 1 N Water St
# Nearest Location: Stamford Museum & Nature Center
# Nearest Location: The Maritime Aquarium
# Nearest Location: Westport Country Playhouse
# Nearest Location: Tarrywile Park & Mansion
# Nearest Location: Lover's Leap State Park
# Nearest Location: Pequonnock River Trail
# Nearest Location: Kettletown State Park
# Nearest Location: Boothe Memorial Park and Museum
# Nearest Location: Sleeping Giant State Park
# Nearest Location: Hubbard Park
# Nearest Location: Lake Compounce
# Nearest Location: Hill-Stead Museum
# Nearest Charging Station: Connecticut State Capitol, 210 Capitol Ave
# Nearest Charging Station: Greater Hartford Transit District - Spruce Street Lot, 1 Union Pl
# Nearest Location: Burr Pond State Park
# Nearest Location: Talcott Mountain State Park
# Nearest Location: New England Air Museum
# Nearest Location: Phelps-Hatheway House & Garden
# Nearest Location: Shenipsit State Forest
# Feasible route found.
# Final Tour:
# Nearest Location: University of Connecticut
# Nearest Location: Windham Textile & History Museum
# Nearest Location: Mohegan Park
# Nearest Location: Fort Trumbull State Park
# Nearest Location: Mystic Seaport Museum
# Nearest Charging Station: Cargill Chevrolet, 23 Livery St
# Nearest Location: Rotary Park & Bandstand
# Nearest Charging Station: Windham Municipal Parking Lot, 48 Church St
# Nearest Charging Station: Windham Town Hall, 979 Main St
# Nearest Location: Patriots Park
# Nearest Location: Connecticut Trolley Museum
# Nearest Location: Pratt & Whitney Stadium at Rentschler Field
# Nearest Charging Station: Constitution Plaza - South, 109 Constitution Plaza
# Nearest Charging Station: State House Square, 10-90 State House Square
# Nearest Charging Station: Morgan Street Garage, 155 Morgan St
# Nearest Charging Station: 777 Main Street - Tesla Supercharger, 777 Main Street
# Nearest Charging Station: 777 MAIN ST, 71 Asylum St
# Nearest Location: Connecticut State Capitol
# Nearest Location: Wadsworth Falls State Park
# Nearest Location: Wharton Brook State Park
# Nearest Location: Yale University
# Nearest Location: Silver Sands State Park
# Nearest Location: Seaside Park
# Nearest Location: Fairfield Museum and History Center
# Nearest Charging Station: Delamar Greenwich Harbor - Tesla Destination, 500 Steamboat Rd
# Nearest Location: Bruce Museum
# Nearest Charging Station: SPIREP, 1 N Water St
# Nearest Location: Stamford Museum & Nature Center
# Nearest Location: The Maritime Aquarium
# Nearest Location: Westport Country Playhouse
# Nearest Location: Tarrywile Park & Mansion
# Nearest Location: Lover's Leap State Park
# Nearest Location: Pequonnock River Trail
# Nearest Location: Kettletown State Park
# Nearest Location: Boothe Memorial Park and Museum
# Nearest Location: Sleeping Giant State Park
# Nearest Location: Hubbard Park
# Nearest Location: Lake Compounce
# Nearest Location: Hill-Stead Museum
# Nearest Charging Station: Connecticut State Capitol, 210 Capitol Ave
# Nearest Charging Station: Greater Hartford Transit District - Spruce Street Lot, 1 Union Pl
# Nearest Location: Burr Pond State Park
# Nearest Location: Talcott Mountain State Park
# Nearest Location: New England Air Museum
# Nearest Location: Phelps-Hatheway House & Garden
# Nearest Location: Shenipsit State Forest
# Best Cost (Total Distance): 1413.5550278206852

# %%
def remove_redundant_charging_stations(final_tour, places_df, charging_stations_df, vehicle_params, charging_params, speed_dict):
    filtered_tour = []
    current_charge = charging_params['max_charge']
    total_distance = 0
    Cd, A, Crr, m, g, rho, lambda_, alpha = vehicle_params.values()
    level2_charge_rate, dc_fast_charge_rate, min_charge, max_charge = charging_params.values()
    default_speed = 60  # Assume a default speed of 60 miles/h if speed is not found in speed_dict

    # Calculate the maximum range based on vehicle parameters and charging parameters
    max_range = (max_charge - min_charge) / (0.5 * rho * Cd * A * (default_speed / 0.6213711922) ** 2 + Crr * m * g) * 3600  # in miles

    for i, city in enumerate(final_tour):
        if city in places_df["Locations"].values:
            filtered_tour.append(city)
            if i < len(final_tour) - 1:  # Check if there is a next city in the tour
                next_city = final_tour[i + 1]
                distance_to_next_location = get_distance(city, next_city, location_distance_matrix,
                                                         qualifying_distance_matrix, charging_station_distance_matrix,
                                                         places_df, charging_stations_df)

                # Check for both orders of the cities in the speed_dict
                if (city, next_city) in speed_dict:
                    speed = speed_dict[(city, next_city)]
                elif (next_city, city) in speed_dict:
                    speed = speed_dict[(next_city, city)]
                else:
                    # If speed is not found in speed_dict, use the default speed
                    speed = default_speed
                    print(f"Warning: Speed not found for the path between {city} and {next_city}. Using default speed of {default_speed} miles/h.")

                discharge_rate = calculate_battery_discharge_rate(distance_to_next_location, speed, Cd, A, Crr, m, g,
                                                                  rho, lambda_, alpha)
                current_charge -= discharge_rate
                print(f"Charge level after visiting {city}: {current_charge:.2f} (Lost {discharge_rate:.2f})")

                # Check if the current charge falls below 60% of the maximum charge
                if current_charge < 0.6 * max_charge:
                    # Check if the next city is a charging station in the final_tour
                    if next_city in charging_stations_df["Charging Stations"].values and next_city in final_tour:
                        # Include the charging station in the filtered_tour
                        filtered_tour.append(next_city)
                        current_charge = max_charge
                        print(f"Charge level after visiting {next_city}: {current_charge:.2f} (Added {max_charge - current_charge:.2f})")

            total_distance += distance_to_next_location

        elif city in charging_stations_df["Charging Stations"].values:
            # Check if the charging station needs to be removed
            if i < len(final_tour) - 1:
                next_city = final_tour[i + 1]
                distance_to_next_location = get_distance(city, next_city, location_distance_matrix,
                                                         qualifying_distance_matrix, charging_station_distance_matrix,
                                                         places_df, charging_stations_df)

                # Check for both orders of the cities in the speed_dict
                if (city, next_city) in speed_dict:
                    speed = speed_dict[(city, next_city)]
                elif (next_city, city) in speed_dict:
                    speed = speed_dict[(next_city, city)]
                else:
                    # If speed is not found in speed_dict, use the default speed
                    speed = default_speed
                    print(f"Warning: Speed not found for the path between {city} and {next_city}. Using default speed of {default_speed} miles/h.")

                discharge_rate = calculate_battery_discharge_rate(distance_to_next_location, speed, Cd, A, Crr, m, g,
                                                                  rho, lambda_, alpha)
                remaining_charge = current_charge - discharge_rate

                # Check if the remaining charge is below 60% of the maximum charge
                if remaining_charge < 0.6 * max_charge:
                    # The charging station is needed, so include it in the filtered_tour
                    filtered_tour.append(city)
                    current_charge = max_charge
                    print(f"Charge level after visiting {city}: {current_charge:.2f} (Added {max_charge - remaining_charge:.2f})")

            # If the charging station is the last city in the tour, include it in the filtered_tour
            if i == len(final_tour) - 1:
                filtered_tour.append(city)

    print("Optimized Final Tour:")
    for city in filtered_tour:
        if city in places_df["Locations"].values:
            print(f"Nearest Location: {city}")
        else:
            print(f"Nearest Charging Station: {city}")
    print(f"Best Cost (Total Distance): {total_distance}")

    return filtered_tour

# %%
# Call the function with the optimized tour
filtered_tour = remove_redundant_charging_stations(tour, places_df, charging_stations_df, vehicle_params, charging_params, speed_dict)
# Out:
# Warning: Speed not found for the path between University of Connecticut and Windham Textile & History Museum. Using default speed of 60 miles/h.
# Charge level after visiting University of Connecticut: 87.62 (Lost 2.38)
# Warning: Speed not found for the path between Windham Textile & History Museum and Mohegan Park. Using default speed of 60 miles/h.
# Charge level after visiting Windham Textile & History Museum: 83.17 (Lost 4.45)
# Warning: Speed not found for the path between Mohegan Park and Fort Trumbull State Park. Using default speed of 60 miles/h.
# Charge level after visiting Mohegan Park: 78.46 (Lost 4.72)
# Warning: Speed not found for the path between Fort Trumbull State Park and Mystic Seaport Museum. Using default speed of 60 miles/h.
# Charge level after visiting Fort Trumbull State Park: 76.18 (Lost 2.28)
# Warning: Speed not found for the path between Mystic Seaport Museum and Cargill Chevrolet, 23 Livery St. Using default speed of 60 miles/h.
# Charge level after visiting Mystic Seaport Museum: 63.36 (Lost 12.82)
# Warning: Speed not found for the path between Cargill Chevrolet, 23 Livery St and Rotary Park & Bandstand. Using default speed of 60 miles/h.
# Warning: Speed not found for the path between Rotary Park & Bandstand and Windham Municipal Parking Lot, 48 Church St. Using default speed of 60 miles/h.
# Charge level after visiting Rotary Park & Bandstand: 56.35 (Lost 7.00)
# Warning: Speed not found for the path between Windham Municipal Parking Lot, 48 Church St and Windham Town Hall, 979 Main St. Using default speed of 60 miles/h.
# Warning: Speed not found for the path between Windham Town Hall, 979 Main St and Patriots Park. Using default speed of 60 miles/h.
# Warning: Speed not found for the path between Patriots Park and Connecticut Trolley Museum. Using default speed of 60 miles/h.
# Charge level after visiting Patriots Park: 50.40 (Lost 5.95)
# Warning: Speed not found for the path between Connecticut Trolley Museum and Pratt & Whitney Stadium at Rentschler Field. Using default speed of 60 miles/h.
# Charge level after visiting Connecticut Trolley Museum: 46.50 (Lost 3.90)
# Warning: Speed not found for the path between Pratt & Whitney Stadium at Rentschler Field and Constitution Plaza - South, 109 Constitution Plaza. Using default speed of 60 miles/h.
# Charge level after visiting Pratt & Whitney Stadium at Rentschler Field: 45.60 (Lost 0.90)
# Charge level after visiting Constitution Plaza - South, 109 Constitution Plaza: 90.00 (Added 0.00)
# Warning: Speed not found for the path between Constitution Plaza - South, 109 Constitution Plaza and State House Square, 10-90 State House Square. Using default speed of 60 miles/h.
# Warning: Speed not found for the path between State House Square, 10-90 State House Square and Morgan Street Garage, 155 Morgan St. Using default speed of 60 miles/h.
# Warning: Speed not found for the path between Morgan Street Garage, 155 Morgan St and 777 Main Street - Tesla Supercharger, 777 Main Street. Using default speed of 60 miles/h.
# Warning: Speed not found for the path between 777 Main Street - Tesla Supercharger, 777 Main Street and 777 MAIN ST, 71 Asylum St. Using default speed of 60 miles/h.
# Warning: Speed not found for the path between 777 MAIN ST, 71 Asylum St and Connecticut State Capitol. Using default speed of 60 miles/h.
# Warning: Speed not found for the path between Connecticut State Capitol and Wadsworth Falls State Park. Using default speed of 60 miles/h.
# Charge level after visiting Connecticut State Capitol: 84.76 (Lost 5.24)
# Warning: Speed not found for the path between Wadsworth Falls State Park and Wharton Brook State Park. Using default speed of 60 miles/h.
# Charge level after visiting Wadsworth Falls State Park: 81.08 (Lost 3.68)
# Warning: Speed not found for the path between Wharton Brook State Park and Yale University. Using default speed of 60 miles/h.
# Charge level after visiting Wharton Brook State Park: 78.18 (Lost 2.91)
# Warning: Speed not found for the path between Yale University and Silver Sands State Park. Using default speed of 60 miles/h.
# Charge level after visiting Yale University: 74.50 (Lost 3.68)
# Warning: Speed not found for the path between Silver Sands State Park and Seaside Park. Using default speed of 60 miles/h.
# Charge level after visiting Silver Sands State Park: 72.22 (Lost 2.28)
# Warning: Speed not found for the path between Seaside Park and Fairfield Museum and History Center. Using default speed of 60 miles/h.
# Charge level after visiting Seaside Park: 71.07 (Lost 1.16)
# Warning: Speed not found for the path between Fairfield Museum and History Center and Delamar Greenwich Harbor - Tesla Destination, 500 Steamboat Rd. Using default speed of 60 miles/h.
# Charge level after visiting Fairfield Museum and History Center: 63.94 (Lost 7.13)
# Warning: Speed not found for the path between Delamar Greenwich Harbor - Tesla Destination, 500 Steamboat Rd and Bruce Museum. Using default speed of 60 miles/h.
# Warning: Speed not found for the path between Bruce Museum and SPIREP, 1 N Water St. Using default speed of 60 miles/h.
# Charge level after visiting Bruce Museum: 59.90 (Lost 4.04)
# Warning: Speed not found for the path between SPIREP, 1 N Water St and Stamford Museum & Nature Center. Using default speed of 60 miles/h.
# Warning: Speed not found for the path between Stamford Museum & Nature Center and The Maritime Aquarium. Using default speed of 60 miles/h.
# Charge level after visiting Stamford Museum & Nature Center: 57.58 (Lost 2.32)
# Warning: Speed not found for the path between The Maritime Aquarium and Westport Country Playhouse. Using default speed of 60 miles/h.
# Charge level after visiting The Maritime Aquarium: 56.14 (Lost 1.43)
# Warning: Speed not found for the path between Westport Country Playhouse and Tarrywile Park & Mansion. Using default speed of 60 miles/h.
# Charge level after visiting Westport Country Playhouse: 50.41 (Lost 5.73)
# Warning: Speed not found for the path between Tarrywile Park & Mansion and Lover's Leap State Park. Using default speed of 60 miles/h.
# Charge level after visiting Tarrywile Park & Mansion: 46.57 (Lost 3.84)
# Warning: Speed not found for the path between Lover's Leap State Park and Pequonnock River Trail. Using default speed of 60 miles/h.
# Charge level after visiting Lover's Leap State Park: 40.95 (Lost 5.62)
# Warning: Speed not found for the path between Pequonnock River Trail and Kettletown State Park. Using default speed of 60 miles/h.
# Charge level after visiting Pequonnock River Trail: 38.58 (Lost 2.37)
# Warning: Speed not found for the path between Kettletown State Park and Boothe Memorial Park and Museum. Using default speed of 60 miles/h.
# Charge level after visiting Kettletown State Park: 33.86 (Lost 4.72)
# Warning: Speed not found for the path between Boothe Memorial Park and Museum and Sleeping Giant State Park. Using default speed of 60 miles/h.
# Charge level after visiting Boothe Memorial Park and Museum: 28.24 (Lost 5.63)
# Warning: Speed not found for the path between Sleeping Giant State Park and Hubbard Park. Using default speed of 60 miles/h.
# Charge level after visiting Sleeping Giant State Park: 25.11 (Lost 3.13)
# Warning: Speed not found for the path between Hubbard Park and Lake Compounce. Using default speed of 60 miles/h.
# Charge level after visiting Hubbard Park: 22.50 (Lost 2.60)
# Warning: Speed not found for the path between Lake Compounce and Hill-Stead Museum. Using default speed of 60 miles/h.
# Charge level after visiting Lake Compounce: 19.93 (Lost 2.57)
# Warning: Speed not found for the path between Hill-Stead Museum and Connecticut State Capitol, 210 Capitol Ave. Using default speed of 60 miles/h.
# Charge level after visiting Hill-Stead Museum: 17.36 (Lost 2.57)
# Charge level after visiting Connecticut State Capitol, 210 Capitol Ave: 90.00 (Added 0.00)
# Warning: Speed not found for the path between Connecticut State Capitol, 210 Capitol Ave and Greater Hartford Transit District - Spruce Street Lot, 1 Union Pl. Using default speed of 60 miles/h.
# Warning: Speed not found for the path between Greater Hartford Transit District - Spruce Street Lot, 1 Union Pl and Burr Pond State Park. Using default speed of 60 miles/h.
# Warning: Speed not found for the path between Burr Pond State Park and Talcott Mountain State Park. Using default speed of 60 miles/h.
# Charge level after visiting Burr Pond State Park: 84.74 (Lost 5.26)
# Warning: Speed not found for the path between Talcott Mountain State Park and New England Air Museum. Using default speed of 60 miles/h.
# Charge level after visiting Talcott Mountain State Park: 81.64 (Lost 3.10)
# Warning: Speed not found for the path between New England Air Museum and Phelps-Hatheway House & Garden. Using default speed of 60 miles/h.
# Charge level after visiting New England Air Museum: 80.64 (Lost 1.01)
# Charge level after visiting Phelps-Hatheway House & Garden: 75.75 (Lost 4.89)
# Optimized Final Tour:
# Nearest Location: University of Connecticut
# Nearest Location: Windham Textile & History Museum
# Nearest Location: Mohegan Park
# Nearest Location: Fort Trumbull State Park
# Nearest Location: Mystic Seaport Museum
# Nearest Location: Rotary Park & Bandstand
# Nearest Location: Patriots Park
# Nearest Location: Connecticut Trolley Museum
# Nearest Location: Pratt & Whitney Stadium at Rentschler Field
# Nearest Charging Station: Constitution Plaza - South, 109 Constitution Plaza
# Nearest Location: Connecticut State Capitol
# Nearest Location: Wadsworth Falls State Park
# Nearest Location: Wharton Brook State Park
# Nearest Location: Yale University
# Nearest Location: Silver Sands State Park
# Nearest Location: Seaside Park
# Nearest Location: Fairfield Museum and History Center
# Nearest Location: Bruce Museum
# Nearest Location: Stamford Museum & Nature Center
# Nearest Location: The Maritime Aquarium
# Nearest Location: Westport Country Playhouse
# Nearest Location: Tarrywile Park & Mansion
# Nearest Location: Lover's Leap State Park
# Nearest Location: Pequonnock River Trail
# Nearest Location: Kettletown State Park
# Nearest Location: Boothe Memorial Park and Museum
# Nearest Location: Sleeping Giant State Park
# Nearest Location: Hubbard Park
# Nearest Location: Lake Compounce
# Nearest Location: Hill-Stead Museum
# Nearest Charging Station: Connecticut State Capitol, 210 Capitol Ave
# Nearest Location: Burr Pond State Park
# Nearest Location: Talcott Mountain State Park
# Nearest Location: New England Air Museum
# Nearest Location: Phelps-Hatheway House & Garden
# Nearest Location: Shenipsit State Forest
# Best Cost (Total Distance): 403.9317172573058

# %%
def create_folium_graph(filtered_tour, places_df, charging_stations_df):
    # Create a map centered on the mean latitude and longitude of all locations
    map_center = (places_df["Latitude"].mean(), places_df["Longitude"].mean())
    folium_map = folium.Map(location=map_center, zoom_start=8)

    # Add markers for each location in the optimized tour
    for city in filtered_tour:
        if city in places_df["Locations"].values:
            location_info = places_df[places_df["Locations"] == city]
            folium.Marker(
                location=[location_info["Latitude"].values[0], location_info["Longitude"].values[0]],
                popup=city,
                icon=folium.Icon(color='blue', icon='info-sign')
            ).add_to(folium_map)
        else:
            station_info = charging_stations_df[charging_stations_df["Charging Stations"] == city]
            folium.Marker(
                location=[station_info["Latitude"].values[0], station_info["Longitude"].values[0]],
                popup=city,
                icon=folium.Icon(color='green', icon='info-sign')
            ).add_to(folium_map)

    # Connect the locations and charging stations in the order of the optimized tour
    locations = []
    for city in filtered_tour:
        if city in places_df["Locations"].values:
            location_info = places_df[places_df["Locations"] == city]
            locations.append([location_info["Latitude"].values[0], location_info["Longitude"].values[0]])
        else:
            station_info = charging_stations_df[charging_stations_df["Charging Stations"] == city]
            locations.append([station_info["Latitude"].values[0], station_info["Longitude"].values[0]])

    # Add the first location again to complete the cycle
    locations.append(locations[0])

    folium.PolyLine(
        locations=locations,
        color='red',
        weight=2,
        opacity=1
    ).add_to(folium_map)

    return folium_map

# Call the function with the optimized tour
#optimized_tour = remove_redundant_charging_stations(tour, places_df, charging_stations_df, vehicle_params, charging_params)

# %%
optimized_folium_map = create_folium_graph(filtered_tour, places_df, charging_stations_df)
optimized_folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1d5f0668914185f49d3cfd115283800d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1d5f0668914185f49d3cfd115283800d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1d5f0668914185f49d3cfd115283800d = L.map(
#                 &quot;map_1d5f0668914185f49d3cfd115283800d&quot;,
#                 {
#                     center: [41.52708516764705, -72.82677768529413],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ee712e2e99839f6419a96c6c7402f05f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ee712e2e99839f6419a96c6c7402f05f.addTo(map_1d5f0668914185f49d3cfd115283800d);
#
#
#             var marker_2a9f3e926da361432f6b3655c42df488 = L.marker(
#                 [41.8077414, -72.2539805],
#                 {}
#             ).addTo(map_1d5f0668914185f49d3cfd115283800d);
#
#
#             var icon_ddcb6e1d74360166572b71c43fa72138 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2a9f3e926da361432f6b3655c42df488.setIcon(icon_ddcb6e1d74360166572b71c43fa72138);
#
#
#         var popup_e1d0b9842df14990f912e8433ff50b78 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f7bb35f07b21f1152b0e8177e26587da = $(`&lt;div id=&quot;html_f7bb35f07b21f1152b0e8177e26587da&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;University of Connecticut&lt;/div&gt;`)[0];
#                 popup_e1d0b9842df14990f912e8433ff50b78.setContent(html_f7bb35f07b21f1152b0e8177e26587da);
#
#
#
#         marker_2a9f3e926da361432f6b3655c42df488.bindPopup(popup_e1d0b9842df14990f912e8433ff50b78)
#         ;
#
#
#
#
#             var marker_381e58f07efdd45f7ba0b0155fc581e6 = L.marker(
#                 [41.7109653, -72.2056691],
#                 {}
#             ).addTo(map_1d5f0668914185f49d3cfd115283800d);
#
#
#             var icon_7f49e279311d4485e29af1f526289e16 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_381e58f07efdd45f7ba0b0155fc581e6.setIcon(icon_7f49e279311d4485e29af1f526289e16);
#
#
#         var popup_52a734cd8102759f09212f2f34a65add = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d05089a56a8e7f11c51ae7dbe3c25cb8 = $(`&lt;div id=&quot;html_d05089a56a8e7f11c51ae7dbe3c25cb8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Windham Textile &amp; History Museum&lt;/div&gt;`)[0];
#                 popup_52a734cd8102759f09212f2f34a65add.setContent(html_d05089a56a8e7f11c51ae7dbe3c25cb8);
#
#
#
#         marker_381e58f07efdd45f7ba0b0155fc581e6.bindPopup(popup_52a734cd8102759f09212f2f34a65add)
#         ;
#
#
#
#
#             var marker_91b4f68f46366511f7e51a6e23e37198 = L.marker(
#                 [41.5481266, -72.0676761],
#                 {}
#             ).addTo(map_1d5f0668914185f49d3cfd115283800d);
#
#
#             var icon_987af6af454364386d6515ea1c6944ed = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_91b4f68f46366511f7e51a6e23e37198.setIcon(icon_987af6af454364386d6515ea1c6944ed);
#
#
#         var popup_dcda9364193f14fbc0cfe2f961c451e2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1bed745702575851febcebd2e8ed5e94 = $(`&lt;div id=&quot;html_1bed745702575851febcebd2e8ed5e94&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Mohegan Park&lt;/div&gt;`)[0];
#                 popup_dcda9364193f14fbc0cfe2f961c451e2.setContent(html_1bed745702575851febcebd2e8ed5e94);
#
#
#
#         marker_91b4f68f46366511f7e51a6e23e37198.bindPopup(popup_dcda9364193f14fbc0cfe2f961c451e2)
#         ;
#
#
#
#
#             var marker_1d19e43f4f1542203362c1c1d0c988eb = L.marker(
#                 [41.3443022, -72.0931336],
#                 {}
#             ).addTo(map_1d5f0668914185f49d3cfd115283800d);
#
#
#             var icon_9c7fba360d2358dc81f9d490ac6c9002 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sig

# %% [markdown]
# These values represent various parameters and coefficients used in vehicle dynamics and aerodynamics calculations. Let's go through each one:
#
# 1. 'Cd': 0.3 stands for the coefficient of drag, which is a dimensionless quantity that represents the aerodynamic drag of an object.
# 2. 'A': 2.2 represents the frontal area of the vehicle in square meters (m^2).
# 3. 'Crr': 0.01 stands for the coefficient of rolling resistance, which is a dimensionless quantity that represents the resistance to motion of the vehicle due to friction between the tires and the road surface.
# 4. 'm': 1500 represents the mass of the vehicle in kilograms (kg).
# 5. 'g': 9.81 represents the acceleration due to gravity in meters per second squared (m/s^2).
# 6. 'rho': 1.225 represents the density of air in kilograms per cubic meter (kg/m^3).
# 7. 'lambda_': 0.80 is a coefficient related to the efficiency of the vehicle's powertrain.
# 8. 'alpha': 0.25 is a coefficient related to the road gradient or slope.

# %%
import folium

def create_html_graph(optimized_tour, places_df, charging_stations_df):
    # Create a map centered on the mean latitude and longitude of all locations
    map_center = (places_df["Latitude"].mean(), places_df["Longitude"].mean())
    folium_map = folium.Map(location=map_center, zoom_start=8)

    # Add markers for each location in the optimized tour
    for city in filtered_tour:
        if city in places_df["Locations"].values:
            location_info = places_df[places_df["Locations"] == city]
            folium.Marker(
                location=[location_info["Latitude"].values[0], location_info["Longitude"].values[0]],
                popup=city,
                icon=folium.Icon(color='blue', icon='info-sign')
            ).add_to(folium_map)
        else:
            station_info = charging_stations_df[charging_stations_df["Charging Stations"] == city]
            folium.Marker(
                location=[station_info["Latitude"].values[0], station_info["Longitude"].values[0]],
                popup=city,
                icon=folium.Icon(color='green', icon='info-sign')
            ).add_to(folium_map)

    # Connect the locations and charging stations in the order of the optimized tour
    locations = []
    for city in filtered_tour:
        if city in places_df["Locations"].values:
            location_info = places_df[places_df["Locations"] == city]
            locations.append([location_info["Latitude"].values[0], location_info["Longitude"].values[0]])
        else:
            station_info = charging_stations_df[charging_stations_df["Charging Stations"] == city]
            locations.append([station_info["Latitude"].values[0], station_info["Longitude"].values[0]])

    # Add the first location again to complete the cycle
    locations.append(locations[0])

    folium.PolyLine(
        locations=locations,
        color='red',
        weight=2,
        opacity=1
    ).add_to(folium_map)

    # Save the map as an HTML file
    folium_map.save("optimized_tour.html")

# Call the function with the optimized tour
create_html_graph(filtered_tour, places_df, charging_stations_df)

# %% [markdown]
# ### Nearest Neighbor Algorithm

# %%
import random

def calculate_battery_discharge_rate(distance, speed, Cd, A, Crr, m, g, rho, lambda_, alpha):
    # Calculate the battery discharge rate based on vehicle parameters
    F_drag = 0.5 * rho * Cd * A * (speed ** 2)
    F_rolling = Crr * m * g
    F_total = F_drag + F_rolling
    P_total = F_total * speed
    P_regen = alpha * P_total
    P_net = P_total - P_regen
    energy_consumed = P_net * (distance / speed)
    discharge_rate = energy_consumed / 3600  # Convert from Joules to kWh
    return discharge_rate

def print_final_tour(tour, places_df, charging_stations_df, total_distance):
    print("Final Tour:")
    for city in tour:
        if city in places_df["Locations"].values:
            print(f"Nearest Location: {city}")
        else:
            print(f"Nearest Charging Station: {city}")
    print(f"Best Cost (Total Distance): {total_distance}")

def get_distance(city1, city2, location_distance_matrix, qualifying_distance_matrix, charging_station_distance_matrix, places_df, charging_stations_df):
    if city1 in places_df["Locations"].values and city2 in places_df["Locations"].values:
        return location_distance_matrix.at[city1, city2]
    elif city1 in places_df["Locations"].values and city2 in charging_stations_df["Charging Stations"].values:
        if city2 in qualifying_distance_matrix.index:
            return qualifying_distance_matrix.at[city2, city1]
        else:
            return float('inf')
    elif city1 in charging_stations_df["Charging Stations"].values and city2 in places_df["Locations"].values:
        if city1 in qualifying_distance_matrix.index:
            return qualifying_distance_matrix.at[city1, city2]
        else:
            return float('inf')
    elif city1 in charging_stations_df["Charging Stations"].values and city2 in charging_stations_df["Charging Stations"].values:
        if city1 in charging_station_distance_matrix.index and city2 in charging_station_distance_matrix.columns:
            return charging_station_distance_matrix.at[city1, city2]
        else:
            return float('inf')
    else:
        raise KeyError(f"Invalid cities: {city1}, {city2}")

# %%
def nearest_neighbor_algorithm(location_distance_matrix, qualifying_distance_matrix, charging_station_distance_matrix, places_df, charging_stations_df, source_city, vehicle_params, charging_params, speed_dict, iteration_count=0):
    current_tour = [source_city]
    visited_cities = set(current_tour)
    current_charge = charging_params['max_charge']
    total_distance = 0

    Cd, A, Crr, m, g, rho, lambda_, alpha = vehicle_params.values()
    level2_charge_rate, dc_fast_charge_rate, min_charge, max_charge = charging_params.values()

    while len(visited_cities) < len(places_df["Locations"]):
        nearest_location = None
        min_distance = float('inf')

        for location in places_df["Locations"]:
            if location not in visited_cities:
                distance = get_distance(current_tour[-1], location, location_distance_matrix, qualifying_distance_matrix, charging_station_distance_matrix, places_df, charging_stations_df)
                if distance < min_distance:
                    nearest_location = location
                    min_distance = distance

        distance_to_next_location = min_distance

        speed = random.randint(50, 80)  # Generate random speed between 50 and 80 miles/h
        speed_dict[(current_tour[-1], nearest_location)] = speed  # Store the speed in the speed_dict
        speed_dict[(nearest_location, current_tour[-1])] = speed  # Also store the speed for the reverse direction
        print(f"Speed from speed_dict: {current_tour[-1]} -> {nearest_location}: {speed} miles/h")
        discharge_rate = calculate_battery_discharge_rate(distance_to_next_location, speed, Cd, A, Crr, m, g, rho, lambda_, alpha)
        required_charge_to_next_location = discharge_rate

        print(f"Current charge: {current_charge}, Required charge to next location: {required_charge_to_next_location}")

        if current_charge - required_charge_to_next_location >= min_charge:
            current_tour.append(nearest_location)
            visited_cities.add(nearest_location)
            total_distance += distance_to_next_location
            current_charge -= required_charge_to_next_location

            print("Updated Tour:")
            for city in current_tour:
                print(f"Nearest Location: {city}")
            print(f"Total Distance: {total_distance}")
            print(f"Updated Charge: {current_charge}")
            print(f"Speed: {speed} miles/h")


            # Check if charge level is below 60% and find the nearest charging station
            if current_charge < max_charge * 0.6:
                print("Warning: Charge level below 60%. Looking for the nearest charging station.")
                nearest_station = None
                min_distance = float('inf')

                for station in charging_stations_df["Charging Stations"]:
                    if station not in visited_cities:
                        distance = get_distance(current_tour[-1], station, location_distance_matrix, qualifying_distance_matrix, charging_station_distance_matrix, places_df, charging_stations_df)
                        if distance < min_distance:
                            nearest_station = station
                            min_distance = distance

                if nearest_station is not None:
                    current_tour.append(nearest_station)
                    visited_cities.add(nearest_station)
                    distance_to_station = get_distance(current_tour[-2], nearest_station, location_distance_matrix, qualifying_distance_matrix, charging_station_distance_matrix, places_df, charging_stations_df)
                    total_distance += distance_to_station
                    current_charge = max_charge
                    print("Total Distance After Charging Station Insertion:", total_distance)

        else:
            print(f"Impossible route encountered after {iteration_count} iterations. Restarting with a different source city.")
            new_source_city = places_df.loc[places_df["Locations"] != source_city, "Locations"].sample().values[0]
            return nearest_neighbor_algorithm(location_distance_matrix, qualifying_distance_matrix, charging_station_distance_matrix, places_df, charging_stations_df, new_source_city, vehicle_params, charging_params, speed_dict, iteration_count + 1)

    # Check if the EV has enough charge to return to the source city
    distance_to_source_city = get_distance(current_tour[-1], source_city, location_distance_matrix, qualifying_distance_matrix, charging_station_distance_matrix, places_df, charging_stations_df)
    speed_to_source_city = random.randint(50, 80)  # Generate random speed for the return trip
    discharge_rate_to_source_city = calculate_battery_discharge_rate(distance_to_source_city, speed_to_source_city, Cd, A, Crr, m, g, rho, lambda_, alpha)
    required_charge_to_source_city = discharge_rate_to_source_city

    if current_charge - required_charge_to_source_city >= min_charge:
        current_tour.append(source_city)
        total_distance += distance_to_source_city
        current_charge -= required_charge_to_source_city
        print(f"Returning to Source City: {source_city}")
        print(f"Total Distance After Returning to Source City: {total_distance}")
        print(f"Final Charge Level: {current_charge}")
    else:
        print("Warning: Insufficient charge to return to the source city. Looking for the nearest charging station.")
        nearest_station = None
        min_distance = float('inf')

        for station in charging_stations_df["Charging Stations"]:
            if station not in visited_cities:
                distance = get_distance(current_tour[-1], station, location_distance_matrix, qualifying_distance_matrix, charging_station_distance_matrix, places_df, charging_stations_df)
                if distance < min_distance:
                    nearest_station = station
                    min_distance = distance

        if nearest_station is not None:
            current_tour.append(nearest_station)
            visited_cities.add(nearest_station)
            distance_to_station = get_distance(current_tour[-2], nearest_station, location_distance_matrix, qualifying_distance_matrix, charging_station_distance_matrix, places_df, charging_stations_df)
            total_distance += distance_to_station
            current_charge = max_charge
            print("Total Distance After Charging Station Insertion:", total_distance)

            # Retry returning to the source city after charging
            current_tour.append(source_city)
            total_distance += distance_to_source_city
            current_charge -= required_charge_to_source_city
            print(f"Returning to Source City: {source_city}")
            print(f"Total Distance After Returning to Source City: {total_distance}")
            print(f"Final Charge Level: {current_charge}")
        else:
            print("Warning: No suitable charging station found to return to the source city.")

    print(f"Nearest Neighbor Algorithm completed after {iteration_count} iterations.")
    print("Final Tour:")
    for city in current_tour:
        if city in places_df["Locations"].values:
            print(f"Nearest Location: {city}")
        else:
            print(f"Nearest Charging Station: {city}")
    print(f"Total Distance: {total_distance}")

    return current_tour, total_distance, speed_dict
vehicle_params = {
    'Cd': 0.3,
    'A': 2.2,
    'Crr': 0.01,
    'm': 1500,
    'g': 9.81,
    'rho': 1.225,
    'lambda_': 0.80,
    'alpha': 0.25
}

charging_params = {
    'level2_charge_rate': 7,
    'dc_fast_charge_rate': 50,
    'min_charge': 20,  # 20% of 100 kWh battery capacity
    'max_charge': 90  # 90% of 100 kWh battery capacity
}

source_city = "Yale University"
speed_dict = {}  # Initialize an empty speed_dict
tour, total_distance, speed_dict = nearest_neighbor_algorithm(location_distance_matrix, qualifying_distance_matrix, charging_station_distance_matrix, places_df, charging_stations_df, source_city, vehicle_params, charging_params, speed_dict)
# Out:
# Speed from speed_dict: Yale University -> Sleeping Giant State Park: 54 miles/h
# Current charge: 90, Required charge to next location: 2.0222730246869913
# Updated Tour:
# Nearest Location: Yale University
# Nearest Location: Sleeping Giant State Park
# Total Distance: 7.320760031537976
# Updated Charge: 87.977726975313
# Speed: 54 miles/h
# Speed from speed_dict: Sleeping Giant State Park -> Wharton Brook State Park: 66 miles/h
# Current charge: 87.977726975313, Required charge to next location: 1.2768988418581502
# Updated Tour:
# Nearest Location: Yale University
# Nearest Location: Sleeping Giant State Park
# Nearest Location: Wharton Brook State Park
# Total Distance: 10.532978098194643
# Updated Charge: 86.70082813345485
# Speed: 66 miles/h
# Speed from speed_dict: Wharton Brook State Park -> Hubbard Park: 61 miles/h
# Current charge: 86.70082813345485, Required charge to next location: 2.9240589361674854
# Updated Tour:
# Nearest Location: Yale University
# Nearest Location: Sleeping Giant State Park
# Nearest Location: Wharton Brook State Park
# Nearest Location: Hubbard Park
# Total Distance: 19.0323039698816
# Updated Charge: 83.77676919728736
# Speed: 61 miles/h
# Speed from speed_dict: Hubbard Park -> Lake Compounce: 55 miles/h
# Current charge: 83.77676919728736, Required charge to next location: 2.2261786926768714
# Updated Tour:
# Nearest Location: Yale University
# Nearest Location: Sleeping Giant State Park
# Nearest Location: Wharton Brook State Park
# Nearest Location: Hubbard Park
# Nearest Location: Lake Compounce
# Total Distance: 26.83201855136543
# Updated Charge: 81.5505905046105
# Speed: 55 miles/h
# Speed from speed_dict: Lake Compounce -> Hill-Stead Museum: 62 miles/h
# Current charge: 81.5505905046105, Required charge to next location: 2.7291189049258144
# Updated Tour:
# Nearest Location: Yale University
# Nearest Location: Sleeping Giant State Park
# Nearest Location: Wharton Brook State Park
# Nearest Location: Hubbard Park
# Nearest Location: Lake Compounce
# Nearest Location: Hill-Stead Museum
# Total Distance: 34.53284205048329
# Updated Charge: 78.82147159968468
# Speed: 62 miles/h
# Speed from speed_dict: Hill-Stead Museum -> Connecticut State Capitol: 66 miles/h
# Current charge: 78.82147159968468, Required charge to next location: 3.0670641315689458
# Updated Tour:
# Nearest Location: Yale University
# Nearest Location: Sleeping Giant State Park
# Nearest Location: Wharton Brook State Park
# Nearest Location: Hubbard Park
# Nearest Location: Lake Compounce
# Nearest Location: Hill-Stead Museum
# Nearest Location: Connecticut State Capitol
# Total Distance: 42.24847189684105
# Updated Charge: 75.75440746811574
# Speed: 66 miles/h
# Speed from speed_dict: Connecticut State Capitol -> Pratt & Whitney Stadium at Rentschler Field: 66 miles/h
# Current charge: 75.75440746811574, Required charge to next location: 1.3139846339233618
# Updated Tour:
# Nearest Location: Yale University
# Nearest Location: Sleeping Giant State Park
# Nearest Location: Wharton Brook State Park
# Nearest Location: Hubbard Park
# Nearest Location: Lake Compounce
# Nearest Location: Hill-Stead Museum
# Nearest Location: Connecticut State Capitol
# Nearest Location: Pratt & Whitney Stadium at Rentschler Field
# Total Distance: 45.55398447311979
# Updated Charge: 74.44042283419238
# Speed: 66 miles/h
# Speed from speed_dict: Pratt & Whitney Stadium at Rentschler Field -> Talcott Mountain State Park: 55 miles/h
# Current charge: 74.44042283419238, Required charge to next location: 2.943718410071983
# Updated Tour:
# Nearest Location: Yale University
# Nearest Location: Sleeping Giant State Park
# Nearest Location: Wharton Brook State Park
# Nearest Location: Hubbard Park
# Nearest Location: Lake Compounce
# Nearest Location: Hill-Stead Museum
# Nearest Location: Connecticut State Capitol
# Nearest Location: Pratt & Whitney Stadium at Rentschler Field
# Nearest Location: Talcott Mountain State Park
# Total Distance: 55.86769535461797
# Updated Charge: 71.4967044241204
# Speed: 55 miles/h
# Speed from speed_dict: Talcott Mountain State Park -> New England Air Museum: 66 miles/h
# Current charge: 71.4967044241204, Required charge to next location: 3.690073513708858
# Updated Tour:
# Nearest Location: Yale University
# Nearest Location: Sleeping Giant State Park
# Nearest Location: Wharton Brook State Park
# Nearest Location: Hubbard Park
# Nearest Location: Lake Compounce
# Nearest Location: Hill-Stead Museum
# Nearest Location: Connecticut State Capitol
# Nearest Location: Pratt & Whitney Stadium at Rentschler Field
# Nearest Location: Talcott Mountain State Park
# Nearest Location: New England Air Museum
# Total Distance: 65.15059265193075
# Updated Charge: 67.80663091041154
# Speed: 66 miles/h
# Speed from speed_dict: New England Air Museum -> Phelps-Hatheway House & Garden: 63 miles/h
# Current charge: 67.80663091041154, Required charge to next location: 1.100374829021042
# Updated Tour:
# Nearest Location: Yale University
# Nearest Location: Sleeping Giant State Park
# Nearest Location: Wharton Brook State Park
# Nearest Location: Hubbard Park
# Nearest Location: Lake Compounce
# Nearest Location: Hill-Stead Museum
# Nearest Location: Connecticut State Capitol
# Nearest Location: Pratt & Whitney Stadium at Rentschler Field
# Nearest Location: Talcott Mountain State Park
# Nearest Location: New England Air Museum
# Nearest Location: Phelps-Hatheway House & Garden
# Total Distance: 68.16597524417138
# Updated Charge: 66.7062560813905
# Speed: 63 miles/h
# Speed from speed_dict: Phelps-Hatheway House & Garden -> Connecticut Trolley Museum: 59 miles/h
# Current charge: 66.7062560813905, Required charge to next location: 1.7190681767095153
# Updated Tour:
# Nearest Location: Yale University
# Nearest Location: Sleeping Giant State Park
# Nearest Location: Wharton Brook State Park
# Nearest Location: Hubbard Park
# Nearest Location: Lake Compounce
# Nearest Location: Hill-Stead Museum
# Nearest Location: Connecticut State Capitol
# Nearest Location: Pratt & Whitney Stadium at Rentschler Field
# Nearest Location: Talcott Mountain State Park
# Nearest Location: New England Air Museum
# Nearest Location: Phelps-Hatheway House & Garden
# Nearest Location: Connecticut Trolley Museum
# Total Distance: 73.47466233083553
# Updated Charge: 64.987187904681
# Speed: 59 miles/h
# Speed from speed_dict: Connecticut Trolley Museum -> Shenipsit State Forest: 77 miles/h
# Current charge: 64.987187904681, Required charge to next location: 4.819692171490307
# Updated Tour:
# Nearest Location: Yale University
# Nearest Location: Sleeping Giant State Park
# Nearest Location: Wharton Brook State Park
# Nearest Location: Hubbard Park
# Nearest Location: Lake Compounce
# Nearest Location: Hill-Stead Museum
# Nearest Location: Connecticut State Capitol
# Nearest Location: Pratt & Whitney Stadium at Rentschler Field
# Nearest Location: Talcott Mountain State Park
# Nearest Location: New England Air Museum
# Nearest Location: Phelps-Hatheway House & Garden
# Nearest Location: Connecticut Trolley Museum
# Nearest Location: Shenipsit State Forest
# Total Distance: 82.56860613380144
# Updated Charge: 60.167495733190684
# Speed: 77 miles/h
# Speed from speed_dict: Shenipsit State Forest -> University of Connecticut: 61 miles/h
# Current charge: 60.167495733190684, Required charge to next location: 4.565438730799627
# Updated Tour:
# Nearest Location: Yale University
# Nearest Location: Sleeping Giant State Park
# Nearest Location: Wharton Brook State Park
# Nearest Location: Hubbard Park
# Nearest Location: Lake Compounce
# Nearest Location: Hill-Stead Museum
# Nearest Location: Connecticut State Capitol
# Nearest Location: Pratt & Whitney Stadium at Rentschler Field
# Nearest Location: Talcott Mountain State Park
# Nearest Location: New England Air Museum
# Nearest Location: Phelps-Hatheway House & Garden
# Nearest Location: Connecticut Trolley Museum
# Nearest Location: Shenipsit State Forest
# Nearest Location: University of Connecticut
# Total Distance: 95.83891031280871
# Updated Charge: 55.60205700239106
# Speed: 61 miles/h
# Speed from speed_dict: University of Connecticut -> Patriots Park: 76 miles/h
# Current charge: 55.60205700239106, Required charge to next location: 2.0169845070093793
# Updated Tour:
# Nearest Location: Yale University
# Nearest Location: Sleeping Giant State Park
# Nearest Location: Wharton Brook State Park
# Nearest Location: Hubbard Park
# Nearest Location: Lake Compounce
# Nearest Location: Hill-Stead Museum
# Nearest Location: Connecticut State Capitol
# Nearest Location: Pratt & Whitney Stadium at Rentschler Field
# Nearest Location: Talcott Mountain State Park
# Nearest Location: New England Air Museum
# Nearest Location: Phelps-Hatheway House & Garden
# Nearest Location: Connecticut Trolley Museum
# Nearest Location: Shenipsit State Forest
# Nearest Location: University of Connecticut
# Nearest Location: Patriots Park
# Total Distance: 99.73945156204424
# Updated Charge: 53.58507249538168
# Speed: 76 miles/h
# Warning: Charge level below 60%. Looking for the nearest charging station.
# Total Distance After Charging Station Insertion: 100.67395243484329
# Speed from speed_dict: Coventry Town Hall, 1712 Main St -> Windham Textile & History Museum: 71 miles/h
# Current charge: 90, Required charge to next location: 3.3180338758538457
# Updated Tour:
# Nearest Location: Yale University
# Nearest Location: Sleeping Giant State Park
# Nearest Location: Wharton Brook State Park
# Nearest Location: Hubbard Park
# Nearest Location: Lake Compounce
# Nearest Location: Hill-Stead Museum
# Nearest Location: Connecticut State Capitol
# Nearest Location: Pratt & Whitney Stadium at Rentschler Field
# Nearest Location: Talcott Mountain State Park
# Nearest Location: New England Air Museum
# Nearest Location: Phelps-Hatheway House & Garden
# Nearest Location: Connecticut Trolley Museum
# Nearest Location: Shenipsit State Forest
# Nearest Location: University of Connecticut
# Nearest Location: Patriots Park
# Nearest Location: Coventry Town Hall, 1712 Main St
# Nearest Location: Windham Textile & History Museum
# Total Distance: 107.96308300656442
# Updated Charge: 86.68196612414616
# Speed: 71 miles/h
# Speed from speed_dict: Windham Textile & History Museum -> Mohegan Park: 71 miles/h
# Current charge: 86.68196612414616, Required charge to next location: 6.06198825537607
# Updated Tour:
# Nearest Location: Yale University
# Nearest Location: Sleeping Giant State Park
# Nearest Location: Wharton Brook State Park
# Nearest Location: Hubbard Park
# Nearest Location: Lake Compounce
# Nearest Location: Hill-Stead Museum
# Nearest Location: Connecticut State Capitol
# Nearest Location: Pratt & Whitney Stadium at Rentschler Field
# Nearest Location: Talcott Mountain State Park
# Nearest Location: New England Air Museum
# Nearest Location: Phelps-Hatheway House & Garden
# Nearest Location: Connecticut Trolley Museum
# Nearest Location: Shenipsit State Forest
# Nearest Location: University of Connecticut
# Nearest Location: Patriots Park
# Nearest Location: Coventry Town Hall, 1712 Main St
# Nearest Location: Windham Textile & History Museum
# Nearest Location: Mohegan Park
# Total Distance: 121.28019355182835
# Updated Charge: 80.61997786877009
# Speed: 71 miles/h
# Speed from speed_dict: Mohegan Park -> Mystic Seaport Museum: 62 miles/h
# Current charge: 80.61997786877009, Required charge to next location: 4.953632335734015
# Updated Tour:
# Nearest Location: Yale University
# Nearest Location: Sleeping Giant State Park
# Nearest Location: Wharton Brook State Park
# Nearest Location: Hubbard Park
# Nearest Location: Lake Compounce
# Nearest Location: Hill-Stead Museum
# Nearest Location: Connecticut State Capitol
# Nearest Location: Pratt & Whitney Stadium at Rentschler Field
# Nearest Location: Talcott Mountain State Park
# Nearest Location: New England Air Museum
# Nearest Location: Phelps-Hatheway House & Garden
# Nearest Location: Connecticut Trolley Museum
# Nearest Location: Shenipsit State Forest
# Nearest Location: University of Connecticut
# Nearest Location: Patriots Park
# Nearest Location: Coventry Town Hall, 1712 Main St
# Nearest Location: Windham Textile & History Museum
# Nearest Location: Mohegan Park
# Nearest Location: Mystic Seaport Museum
# Total Distance: 135.25798258409023
# Updated Charge: 75.66634553303608
# Speed: 62 miles/h
# Speed from speed_dict: Mystic Seaport Museum -> Fort Trumbull State Park: 66 miles/h
# Current charge: 75.66634553303608, Required charge to next location: 2.7108977727505783
# Updated Tour:
# Nearest Location: Yale University
# Nearest Location: Sleeping Giant State Park
# Nearest Location: Wharton Brook State Park
# Nearest Location: Hubbard Park
# Nearest Location: Lake Compounce
# Nearest Location: Hill-Stead Museum
# Nearest Location: Connecticut State Capitol
# Nearest Location: Pratt & Whitney Stadium at Rentschler Field
# Nearest Location: Talcott Mountain State Park
# Nearest Location: New England Air Museum
# Nearest Location: Phelps-Hatheway House & Garden
# Nearest Location: Connecticut Trolley Museum
# Nearest Location: Shenipsit State Forest
# Nearest Location: University of Connecticut
# Nearest Location: Patriots Park
# Nearest Location: Coventry Town Hall, 1712 Main St
# Nearest Location: Windham Textile & History Museum
# Nearest Location: Mohegan Park
# Nearest Location: Mystic Seaport Museum
# Nearest Location: Fort Trumbull State Park
# Total Distance: 142.07762601787766
# Updated Charge: 72.9554477602855
# Speed: 66 miles/h
# Speed from speed_dict: Fort Trumbull State Park -> Wadsworth Falls State Park: 80 miles/h
# Current charge: 72.9554477602855, Required charge to next location: 19.103903467255012
# Updated Tour:
# Nearest Location: Yale University
# Nearest Location: Sleeping Giant State Park
# Nearest Location: Wharton Brook State Park
# Nearest Location: Hubbard Park
# Nearest Location: Lake Compounce
# Nearest Location: Hill-Stead Museum
# Nearest Location: Connecticut State Capitol
# Nearest Location: Pratt & Whitney Stadium at Rentschler Field
# Nearest Location: Talcott Mountain State Park
# Nearest Location: New England Air Museum
# Nearest Location: Phelps-Hatheway House & Garden
# Nearest Location: Connecticut Trolley Museum
# Nearest Location: Shenipsit State Forest
# Nearest Location: University of Connecticut
# Nearest Location: Patriots Park
# Nearest Location: Coventry Town Hall, 1712 Main St
# Nearest Location: Windham Textile & History Museum
# Nearest Location: Mohegan Park
# Nearest Location: Mystic Seaport Museum
# Nearest Location: Fort Trumbull State Park
# Nearest Location: Wadsworth Falls State Park
# Total Distance: 175.61347060354666
# Updated Charge: 53.851544293030486
# Speed: 80 miles/h
# Warning: Charge level below 60%. Looking for the nearest charging station.
# Total Distance After Charging Station Insertion: 177.18068269596296
# Speed from speed_dict: Wesleyan University, 161 Cross St -> Kettletown State Park: 62 miles/h
# Current charge: 90, Required charge to next location: 10.415373002673366
# Updated Tour:
# Nearest Location: Yale University
# Nearest Location: Sleeping Giant State Park
# Nearest Location: Wharton Brook State Park
# Nearest Location: Hubbard Park
# Nearest Location: Lake Compounce
# Nearest Location: Hill-Stead Museum
# Nearest Location: Connecticut State Capitol
# Nearest Location: Pratt & Whitney Stadium at Rentschler Field
# Nearest Location: Talcott Mountain State Park
# Nearest Location: New England Air Museum
# Nearest Location: Phelps-Hatheway House & Garden
# Nearest Location: Connecticut Trolley Museum
# Nearest Location: Shenipsit State Forest
# Nearest Location: University of Connecticut
# Nearest Location: Patriots Park
# Nearest Location: Coventry Town Hall, 1712 Main St
# Nearest Location: Windham Textile & History Museum
# Nearest Location: Mohegan Park
# Nearest Location: Mystic Seaport Museum
# Nearest Location: Fort Trumbull State Park
# Nearest Location: Wadsworth Falls State Park
# Nearest Location: Wesleyan University, 161 Cross St
# Nearest Location: Kettletown State Park
# Total Distance: 206.57000282646314
# Updated Charge: 79.58462699732664
# Speed: 62 miles/h
# Speed from speed_dict: Kettletown State Park -> Pequonnock River Trail: 64 miles/h
# Current charge: 79.58462699732664, Required charge to next location: 2.671721585106373
# Updated Tour:
# Nearest Location: Yale University
# Nearest Location: Sleeping Giant State Park
# Nearest Location: Wharton Brook State Park
# Nearest Location: Hubbard Park
# Nearest Location: Lake Compounce
# Nearest Location: Hill-Stead Museum
# Nearest Location: Connecticut State Capitol
# Nearest Location: Pratt & Whitney Stadium at Rentschler Field
# Nearest Location: Talcott Mountain State Park
# Nearest Location: New England Air Museum
# Nearest Location: Phelps-Hatheway House & Garden
# Nearest Location: Connecticut Trolley Museum
# Nearest Location: Shenipsit State Forest
# Nearest Location: University of Connecticut
# Nearest Location: Patriots Park
# Nearest Location: Coventry Town Hall, 1712 Main St
# Nearest Location: Windham Textile & History Museum
# Nearest Location: Mohegan Park
# Nearest Location: Mystic Seaport Museum
# Nearest Location: Fort Trumbull State Park
# Nearest Location: Wadsworth Falls State Park
# Nearest Location: Wesleyan University, 161 Cross St
# Nearest Location: Kettletown State Park
# Nearest Location: Pequonnock River Trail
# Total Distance: 213.68290485108633
# Updated Charge: 76.91290541222027
# Speed: 64 miles/h
# Speed from speed_dict: Pequonnock River Trail -> Boothe Memorial Park and Museum: 60 miles/h
# Current charge: 76.91290541222027, Required charge to next location: 3.2856860625904742
# Updated Tour:
# Nearest Location: Yale University
# Nearest Location: Sleeping Giant State Park
# Nearest Location: Wharton Brook State Park
# Nearest Location: Hubbard Park
# Nearest Location: Lake Compounce
# Nearest Location: Hill-Stead Museum
# Nearest Location: Connecticut State Capitol
# Nearest Location: Pratt & Whitney Stadium at Rentschler Field
# Nearest Location: Talcott Mountain State Park
# Nearest Location: New England Air Museum
# Nearest Location: Phelps-Hatheway House & Garden
# Nearest Location: Connecticut Trolley Museum
# Nearest Location: Shenipsit State Forest
# Nearest Location: University of Connecticut
# Nearest Location: Patriots Park
# Nearest Location: Coventry Town Hall, 1712 Main St
# Nearest Location: Windham Textile & History Museum
# Nearest Location: Mohegan Park
# Nearest Location: Mystic Seaport Museum
# Nearest Location: Fort Trumbull State Park
# Nearest Location: Wadsworth Falls State Park
# Nearest Location: Wesleyan University, 161 Cross St
# Nearest Location: Kettletown State Park
# Nearest Location: Pequonnock River Trail
# Nearest Location: Boothe Memorial Park and Museum
# Total Distance: 223.52489249527758
# Updated Charge: 73.6272193496298
# Speed: 60 miles/h
# Speed from speed_dict: Boothe Memorial Park and Museum -> Silver Sands State Park: 55 miles/h
# Current charge: 73.6272193496298, Required charge to next location: 0.9258798649398636
# Updated Tour:
# Nearest Location: Yale University
# Nearest Location: Sleeping Giant State Park
# Nearest Location: Wharton Brook State Park
# Nearest Location: Hubbard Park
# Nearest Location: Lake Compounce
# Nearest Location: Hill-Stead Museum
# Nearest Location: Connecticut State Capitol
# Nearest Location: Pratt & Whitney Stadium at Rentschler Field
# Nearest Location: Talcott Mountain State Park
# Nearest Location: New England Air Museum
# Nearest Location: Phelps-Hatheway House & Garden
# Nearest Location: Connecticut Trolley Museum
# Nearest Location: Shenipsit State Forest
# Nearest Location: University of Connecticut
# Nearest Location: Patriots Park
# Nearest Location: Coventry Town Hall, 1712 Main St
# Nearest Location: Windham Textile & History Museum
# Nearest Location: Mohegan Park
# Nearest Location: Mystic Seaport Museum
# Nearest Location: Fort Trumbull State Park
# Nearest Location: Wadsworth Falls State Park
# Nearest Location: Wesleyan University, 161 Cross St
# Nearest Location: Kettletown State Park
# Nearest Location: Pequonnock River Trail
# Nearest Location: Boothe Memorial Park and Museum
# Nearest Location: Silver Sands State Park
# Total Distance: 226.76883634714784
# Updated Charge: 72.70133948468994
# Speed: 55 miles/h
# Speed from speed_dict: Silver Sands State Park -> Seaside Park: 56 miles/h
# Current charge: 72.70133948468994, Required charge to next location: 2.0121469214566434
# Updated Tour:
# Nearest Location: Yale University
# Nearest Location: Sleeping Giant State Park
# Nearest Location: Wharton Brook State Park
# Nearest Location: Hubbard Park
# Nearest Location: Lake Compounce
# Nearest Location: Hill-Stead Museum
# Nearest Location: Connecticut State Capitol
# Nearest Location: Pratt & Whitney Stadium at Rentschler Field
# Nearest Location: Talcott Mountain State Park
# Nearest Location: New England Air Museum
# Nearest Location: Phelps-Hatheway House & Garden
# Nearest Location: Connecticut Trolley Museum
# Nearest Location: Shenipsit State Forest
# Nearest Location: University of Connecticut
# Nearest Location: Patriots Park
# Nearest Location: Coventry Town Hall, 1712 Main St
# Nearest Location: Windham Textile & History Museum
# Nearest Location: Mohegan Park
# Nearest Location: Mystic Seaport Museum
# Nearest Location: Fort Trumbull State Park
# Nearest Location: Wadsworth Falls State Park
# Nearest Location: Wesleyan University, 161 Cross St
# Nearest Location: Kettletown State Park
# Nearest Location: Pequonnock River Trail
# Nearest Location: Boothe Memorial Park and Museum
# Nearest Location: Silver Sands State Park
# Nearest Location: Seaside Park
# Total Distance: 233.59508230121023
# Updated Charge: 70.68919256323329
# Speed: 56 miles/h
# Speed from speed_dict: Seaside Park -> Fairfield Museum and History Center: 65 miles/h
# Current charge: 70.68919256323329, Required charge to next location: 1.3381943802335592
# Updated Tour:
# Nearest Location: Yale University
# Nearest Location: Sleeping Giant State Park
# Nearest Location: Wharton Brook State Park
# Nearest Location: Hubbard Park
# Nearest Location: Lake Compounce
# Nearest Location: Hill-Stead Museum
# Nearest Location: Connecticut State Capitol
# Nearest Location: Pratt & Whitney Stadium at Rentschler Field
# Nearest Location: Talcott Mountain State Park
# Nearest Location: New England Air Museum
# Nearest Location: Phelps-Hatheway House & Garden
# Nearest Location: Connecticut Trolley Museum
# Nearest Location: Shenipsit State Forest
# Nearest Location: University of Connecticut
# Nearest Location: Patriots Park
# Nearest Location: Coventry Town Hall, 1712 Main St
# Nearest Location: Windham Textile & History Museum
# Nearest Location: Mohegan Park
# Nearest Location: Mystic Seaport Museum
# Nearest Location: Fort Trumbull State Park
# Nearest Location: Wadsworth Falls State Park
# Nearest Location: Wesleyan University, 161 Cross St
# Nearest Location: Kettletown State Park
# Nearest Location: Pequonnock River Trail
# Nearest Location: Boothe Memorial Park and Museum
# Nearest Location: Silver Sands State Park
# Nearest Location: Seaside Park
# Nearest Location: Fairfield Museum and History Center
# Total Distance: 237.05759719765948
# Updated Charge: 69.35099818299973
# Speed: 65 miles/h
# Speed from speed_dict: Fairfield Museum and History Center -> Westport Country Playhouse: 57 miles/h
# Current charge: 69.35099818299973, Required charge to next location: 1.678702427869646
# Updated Tour:
# Nearest Location: Yale University
# Nearest Location: Sleeping Giant State Park
# Nearest Location: Wharton Brook State Park
# Nearest Location: Hubbard Park
# Nearest Location: Lake Compounce
# Nearest Location: Hill-Stead Museum
# Nearest Location: Connecticut State Capitol
# Nearest Location: Pratt & Whitney Stadium at Rentschler Field
# Nearest Location: Talcott Mountain State Park
# Nearest Location: New England Air Museum
# Nearest Location: Phelps-Hatheway House & Garden
# Nearest Location: Connecticut Trolley Museum
# Nearest Location: Shenipsit State Forest
# Nearest Location: University of Connecticut
# Nearest Location: Patriots Park
# Nearest Location: Coventry Town Hall, 1712 Main St
# Nearest Location: Windham Textile & History Museum
# Nearest Location: Mohegan Park
# Nearest Location: Mystic Seaport Museum
# Nearest Location: Fort Trumbull State Park
# Nearest Location: Wadsworth Falls State Park
# Nearest Location: Wesleyan University, 161 Cross St
# Nearest Location: Kettletown State Park
# Nearest Location: Pequonnock River Trail
# Nearest Location: Boothe Memorial Park and Museum
# Nearest Location: Silver Sands State Park
# Nearest Location: Seaside Park
# Nearest Location: Fairfield Museum and History Center
# Nearest Location: Westport Country Playhouse
# Total Distance: 242.57450941514503
# Updated Charge: 67.67229575513008
# Speed: 57 miles/h
# Speed from speed_dict: Westport Country Playhouse -> The Maritime Aquarium: 65 miles/h
# Current charge: 67.67229575513008, Required charge to next location: 1.6604614643895048
# Updated Tour:
# Nearest Location: Yale University
# Nearest Location: Sleeping Giant State Park
# Nearest Location: Wharton Brook State Park
# Nearest Location: Hubbard Park
# Nearest Location: Lake Compounce
# Nearest Location: Hill-Stead Museum
# Nearest Location: Connecticut State Capitol
# Nearest Location: Pratt & Whitney Stadium at Rentschler Field
# Nearest Location: Talcott Mountain State Park
# Nearest Location: New England Air Museum
# Nearest Location: Phelps-Hatheway House & Garden
# Nearest Location: Connecticut Trolley Museum
# Nearest Location: Shenipsit State Forest
# Nearest Location: University of Connecticut
# Nearest Location: Patriots Park
# Nearest Location: Coventry Town Hall, 1712 Main St
# Nearest Location: Windham Textile & History Museum
# Nearest Location: Mohegan Park
# Nearest Location: Mystic Seaport Museum
# Nearest Location: Fort Trumbull State Park
# Nearest Location: Wadsworth Falls State Park
# Nearest Location: Wesleyan University, 161 Cross St
# Nearest Location: Kettletown State Park
# Nearest Location: Pequonnock River Trail
# Nearest Location: Boothe Memorial Park and Museum
# Nearest Location: Silver Sands State Park
# Nearest Location: Seaside Park
# Nearest Location: Fairfield Museum and History Center
# Nearest Location: Westport Country Playhouse
# Nearest Location: The Maritime Aquarium
# Total Distance: 246.87087520501265
# Updated Charge: 66.01183429074058
# Speed: 65 miles/h
# Speed from speed_dict: The Maritime Aquarium -> Stamford Museum & Nature Center: 64 miles/h
# Current charge: 66.01183429074058, Required charge to next location: 2.6092388943728584
# Updated Tour:
# Nearest Location: Yale University
# Nearest Location: Sleeping Giant State Park
# Nearest Location: Wharton Brook State Park
# Nearest Location: Hubbard Park
# Nearest Location: Lake Compounce
# Nearest Location: Hill-Stead Museum
# Nearest Location: Connecticut State Capitol
# Nearest Location: Pratt & Whitney Stadium at Rentschler Field
# Nearest Location: Talcott Mountain State Park
# Nearest Location: New England Air Museum
# Nearest Location: Phelps-Hatheway House & Garden
# Nearest Location: Connecticut Trolley Museum
# Nearest Location: Shenipsit State Forest
# Nearest Location: University of Connecticut
# Nearest Location: Patriots Park
# Nearest Location: Coventry Town Hall, 1712 Main St
# Nearest Location: Windham Textile & History Museum
# Nearest Location: Mohegan Park
# Nearest Location: Mystic Seaport Museum
# Nearest Location: Fort Trumbull State Park
# Nearest Location: Wadsworth Falls State Park
# Nearest Location: Wesleyan University, 161 Cross St
# Nearest Location: Kettletown State Park
# Nearest Location: Pequonnock River Trail
# Nearest Location: Boothe Memorial Park and Museum
# Nearest Location: Silver Sands State Park
# Nearest Location: Seaside Park
# Nearest Location: Fairfield Museum and History Center
# Nearest Location: Westport Country Playhouse
# Nearest Location: The Maritime Aquarium
# Nearest Location: Stamford Museum & Nature Center
# Total Distance: 253.81743008482113
# Updated Charge: 63.40259539636772
# Speed: 64 miles/h
# Speed from speed_dict: Stamford Museum & Nature Center -> Bruce Museum: 60 miles/h
# Current charge: 63.40259539636772, Required charge to next location: 2.796926638365989
# Updated Tour:
# Nearest Location: Yale University
# Nearest Location: Sleeping Giant State Park
# Nearest Location: Wharton Brook State Park
# Nearest Location: Hubbard Park
# Nearest Location: Lake Compounce
# Nearest Location: Hill-Stead Museum
# Nearest Location: Connecticut State Capitol
# Nearest Location: Pratt & Whitney Stadium at Rentschler Field
# Nearest Location: Talcott Mountain State Park
# Nearest Location: New England Air Museum
# Nearest Location: Phelps-Hatheway House & Garden
# Nearest Location: Connecticut Trolley Museum
# Nearest Location: Shenipsit State Forest
# Nearest Location: University of Connecticut
# Nearest Location: Patriots Park
# Nearest Location: Coventry Town Hall, 1712 Main St
# Nearest Location: Windham Textile & History Museum
# Nearest Location: Mohegan Park
# Nearest Location: Mystic Seaport Museum
# Nearest Location: Fort Trumbull State Park
# Nearest Location: Wadsworth Falls State Park
# Nearest Location: Wesleyan University, 161 Cross St
# Nearest Location: Kettletown State Park
# Nearest Location: Pequonnock River Trail
# Nearest Location: Boothe Memorial Park and Museum
# Nearest Location: Silver Sands State Park
# Nearest Location: Seaside Park
# Nearest Location: Fairfield Museum and History Center
# Nearest Location: Westport Country Playhouse
# Nearest Location: The Maritime Aquarium
# Nearest Location: Stamford Museum & Nature Center
# Nearest Location: Bruce Museum
# Total Distance: 262.1953812621788
# Updated Charge: 60.605668758001734
# Speed: 60 miles/h
# Speed from speed_dict: Bruce Museum -> Tarrywile Park & Mansion: 78 miles/h
# Current charge: 60.605668758001734, Required charge to next location: 14.323442960464234
# Updated Tour:
# Nearest Location: Yale University
# Nearest Location: Sleeping Giant State Park
# Nearest Location: Wharton Brook State Park
# Nearest Location: Hubbard Park
# Nearest Location: Lake Compounce
# Nearest Location: Hill-Stead Museum
# Nearest Location: Connecticut State Capitol
# Nearest Location: Pratt & Whitney Stadium at Rentschler Field
# Nearest Location: Talcott Mountain State Park
# Nearest Location: New England Air Museum
# Nearest Location: Phelps-Hatheway House & Garden
# Nearest Location: Connecticut Trolley Museum
# Nearest Location: Shenipsit State Forest
# Nearest Location: University of Connecticut
# Nearest Location: Patriots Park
# Nearest Location: Coventry Town Hall, 1712 Main St
# Nearest Location: Windham Textile & History Museum
# Nearest Location: Mohegan Park
# Nearest Location: Mystic Seaport Museum
# Nearest Location: Fort Trumbull State Park
# Nearest Location: Wadsworth Falls State Park
# Nearest Location: Wesleyan University, 161 Cross St
# Nearest Location: Kettletown State Park
# Nearest Location: Pequonnock River Trail
# Nearest Location: Boothe Memorial Park and Museum
# Nearest Location: Silver Sands State Park
# Nearest Location: Seaside Park
# Nearest Location: Fairfield Museum and History Center
# Nearest Location: Westport Country Playhouse
# Nearest Location: The Maritime Aquarium
# Nearest Location: Stamford Museum & Nature Center
# Nearest Location: Bruce Museum
# Nearest Location: Tarrywile Park & Mansion
# Total Distance: 288.57163445655306
# Updated Charge: 46.2822257975375
# Speed: 78 miles/h
# Warning: Charge level below 60%. Looking for the nearest charging station.
# Total Distance After Charging Station Insertion: 289.78568423843063
# Returning to Source City: Yale University
# Total Distance After Returning to Source City: 318.87112770738423
# Final Charge Level: 74.95980811179108
# Nearest Neighbor Algorithm completed after 0 iterations.
# Final Tour:
# Nearest Location: Yale University
# Nearest Location: Sleeping Giant State Park
# Nearest Location: Wharton Brook State Park
# Nearest Location: Hubbard Park
# Nearest Location: Lake Compounce
# Nearest Location: Hill-Stead Museum
# Nearest Location: Connecticut State Capitol
# Nearest Location: Pratt & Whitney Stadium at Rentschler Field
# Nearest Location: Talcott Mountain State Park
# Nearest Location: New England Air Museum
# Nearest Location: Phelps-Hatheway House & Garden
# Nearest Location: Connecticut Trolley Museum
# Nearest Location: Shenipsit State Forest
# Nearest Location: University of Connecticut
# Nearest Location: Patriots Park
# Nearest Charging Station: Coventry Town Hall, 1712 Main St
# Nearest Location: Windham Textile & History Museum
# Nearest Location: Mohegan Park
# Nearest Location: Mystic Seaport Museum
# Nearest Location: Fort Trumbull State Park
# Nearest Location: Wadsworth Falls State Park
# Nearest Charging Station: Wesleyan University, 161 Cross St
# Nearest Location: Kettletown State Park
# Nearest Location: Pequonnock River Trail
# Nearest Location: Boothe Memorial Park and Museum
# Nearest Location: Silver Sands State Park
# Nearest Location: Seaside Park
# Nearest Location: Fairfield Museum and History Center
# Nearest Location: Westport Country Playhouse
# Nearest Location: The Maritime Aquarium
# Nearest Location: Stamford Museum & Nature Center
# Nearest Location: Bruce Museum
# Nearest Location: Tarrywile Park & Mansion
# Nearest Charging Station: WHOLE FOODS MKT, 5c Sugar Hollow Rd
# Nearest Location: Yale University
# Total Distance: 318.87112770738423

# %%
def create_folium_graph(tour, places_df, charging_stations_df):
    # Create a map centered on the mean latitude and longitude of all locations
    map_center = (places_df["Latitude"].mean(), places_df["Longitude"].mean())
    folium_map = folium.Map(location=map_center, zoom_start=8)

    # Add markers for each location in the tour
    for city in tour:
        if city in places_df["Locations"].values:
            location_info = places_df[places_df["Locations"] == city]
            folium.Marker(
                location=[location_info["Latitude"].values[0], location_info["Longitude"].values[0]],
                popup=city,
                icon=folium.Icon(color='blue', icon='info-sign')
            ).add_to(folium_map)
        else:
            station_info = charging_stations_df[charging_stations_df["Charging Stations"] == city]
            folium.Marker(
                location=[station_info["Latitude"].values[0], station_info["Longitude"].values[0]],
                popup=city,
                icon=folium.Icon(color='green', icon='info-sign')
            ).add_to(folium_map)

    # Connect the locations and charging stations in the order of the tour
    locations = []
    for city in tour:
        if city in places_df["Locations"].values:
            location_info = places_df[places_df["Locations"] == city]
            locations.append([location_info["Latitude"].values[0], location_info["Longitude"].values[0]])
        else:
            station_info = charging_stations_df[charging_stations_df["Charging Stations"] == city]
            locations.append([station_info["Latitude"].values[0], station_info["Longitude"].values[0]])

    # Add the first location again to complete the cycle
    locations.append(locations[0])

    folium.PolyLine(
        locations=locations,
        color='red',
        weight=2,
        opacity=1
    ).add_to(folium_map)

    return folium_map

# %%
optimized_folium_map = create_folium_graph(tour, places_df, charging_stations_df)
optimized_folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_50415311cc2b28020ad11b130580f75d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_50415311cc2b28020ad11b130580f75d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_50415311cc2b28020ad11b130580f75d = L.map(
#                 &quot;map_50415311cc2b28020ad11b130580f75d&quot;,
#                 {
#                     center: [41.52708516764705, -72.82677768529413],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ab16f4fa3fafe17dac8141cd0fa06c7c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ab16f4fa3fafe17dac8141cd0fa06c7c.addTo(map_50415311cc2b28020ad11b130580f75d);
#
#
#             var marker_ef44fd6cf98743d630fe6831b586f644 = L.marker(
#                 [41.3163244, -72.9223431],
#                 {}
#             ).addTo(map_50415311cc2b28020ad11b130580f75d);
#
#
#             var icon_4a87d71495840462290a83dfa72dad65 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ef44fd6cf98743d630fe6831b586f644.setIcon(icon_4a87d71495840462290a83dfa72dad65);
#
#
#         var popup_1573761122fc2272d395e3c091f5426d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_24eff2981c5c8c1d01bd308ea4a66003 = $(`&lt;div id=&quot;html_24eff2981c5c8c1d01bd308ea4a66003&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Yale University&lt;/div&gt;`)[0];
#                 popup_1573761122fc2272d395e3c091f5426d.setContent(html_24eff2981c5c8c1d01bd308ea4a66003);
#
#
#
#         marker_ef44fd6cf98743d630fe6831b586f644.bindPopup(popup_1573761122fc2272d395e3c091f5426d)
#         ;
#
#
#
#
#             var marker_5bcfd3d1272b975f73ac13d538514ad3 = L.marker(
#                 [41.4209689, -72.8992361],
#                 {}
#             ).addTo(map_50415311cc2b28020ad11b130580f75d);
#
#
#             var icon_c4face317676321e3474df0e89944c79 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5bcfd3d1272b975f73ac13d538514ad3.setIcon(icon_c4face317676321e3474df0e89944c79);
#
#
#         var popup_3d4050ee1e94d251825968bbdeb91c6d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5ffc5735490096c820e040b1d7627894 = $(`&lt;div id=&quot;html_5ffc5735490096c820e040b1d7627894&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sleeping Giant State Park&lt;/div&gt;`)[0];
#                 popup_3d4050ee1e94d251825968bbdeb91c6d.setContent(html_5ffc5735490096c820e040b1d7627894);
#
#
#
#         marker_5bcfd3d1272b975f73ac13d538514ad3.bindPopup(popup_3d4050ee1e94d251825968bbdeb91c6d)
#         ;
#
#
#
#
#             var marker_9c5d946fa36ee0de58878b60e024de73 = L.marker(
#                 [41.4250948, -72.8376389],
#                 {}
#             ).addTo(map_50415311cc2b28020ad11b130580f75d);
#
#
#             var icon_96e06f7de5c68d2cd795ccec7dcfc1b9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9c5d946fa36ee0de58878b60e024de73.setIcon(icon_96e06f7de5c68d2cd795ccec7dcfc1b9);
#
#
#         var popup_6115899028f52ed92333e2727d7db9f1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_144c75847eaa94a439e4012a4a3234ef = $(`&lt;div id=&quot;html_144c75847eaa94a439e4012a4a3234ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Wharton Brook State Park&lt;/div&gt;`)[0];
#                 popup_6115899028f52ed92333e2727d7db9f1.setContent(html_144c75847eaa94a439e4012a4a3234ef);
#
#
#
#         marker_9c5d946fa36ee0de58878b60e024de73.bindPopup(popup_6115899028f52ed92333e2727d7db9f1)
#         ;
#
#
#
#
#             var marker_278ebfea0c25710526ec18f0480377a2 = L.marker(
#                 [41.5482476, -72.8361313],
#                 {}
#             ).addTo(map_50415311cc2b28020ad11b130580f75d);
#
#
#             var icon_c1577d6ddffeafcc3d17e57018e5c6c6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;,
