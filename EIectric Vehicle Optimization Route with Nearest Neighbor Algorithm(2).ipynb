# %%
# !pip install geopy
# !pip install folium
import pandas as pd
import math
from geopy.distance import geodesic
# Out:
# Requirement already satisfied: geopy in c:\users\promi\anaconda3\lib\site-packages (2.4.1)
# Requirement already satisfied: geographiclib<3,>=1.52 in c:\users\promi\anaconda3\lib\site-packages (from geopy) (2.0)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\promi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\promi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\promi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\promi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\promi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\promi\anaconda3\lib\site-packages)
# Requirement already satisfied: folium in c:\users\promi\anaconda3\lib\site-packages (0.16.0)
# Requirement already satisfied: jinja2>=2.9 in c:\users\promi\anaconda3\lib\site-packages (from folium) (3.1.2)
# Requirement already satisfied: requests in c:\users\promi\anaconda3\lib\site-packages (from folium) (2.28.1)
# Requirement already satisfied: xyzservices in c:\users\promi\anaconda3\lib\site-packages (from folium) (2024.4.0)
# Requirement already satisfied: numpy in c:\users\promi\anaconda3\lib\site-packages (from folium) (1.26.4)
# Requirement already satisfied: branca>=0.6.0 in c:\users\promi\anaconda3\lib\site-packages (from folium) (0.7.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\promi\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\promi\anaconda3\lib\site-packages (from requests->folium) (2023.5.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\promi\anaconda3\lib\site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\promi\anaconda3\lib\site-packages (from requests->folium) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\promi\anaconda3\lib\site-packages (from requests->folium) (1.26.14)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\promi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\promi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\promi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\promi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\promi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\promi\anaconda3\lib\site-packages)

# %%
# Load the charging stations data
charging_stations_df = pd.read_csv("Electric_Vehicle_Charging_Stations.csv")

# Load the places data
places_df = pd.read_csv("coordinates.csv")

# Concatenate "Station Name" and "Street Address" into a new column "Charging Stations"
charging_stations_df["Charging Stations"] = charging_stations_df["Station Name"] + ", " + charging_stations_df["Street Address"]
charging_stations_df = charging_stations_df.drop(columns=["Station Name", "Street Address"])

# Rename the "Places" column to "Locations" in places_df
places_df = places_df.rename(columns={"Places": "Locations"})

# Display the resulting DataFrames
print("Charging Stations DataFrame:")
print(charging_stations_df.head())
print("\nPlaces DataFrame:")
print(places_df.head())
# Out:
# Charging Stations DataFrame:
#            City              Access Days Time EV Level1 EVSE Num  \
# 0        Darien                24 hours daily               NONE
# 1       Meriden  24 hours, for Tesla use only               NONE
# 2  Beacon Falls                24 hours daily               NONE
# 3  Old Saybrook                24 hours daily               NONE
# 4     Fairfield                24 hours daily               NONE
#
#   EV Level2 EVSE Num EV DC Fast Count  Longitude   Latitude  \
# 0                  2             NONE -73.476469  41.072882
# 1               NONE                8 -72.773473  41.527367
# 2                  1             NONE -73.065583  41.445481
# 3                  2             NONE -72.382500  41.310278
# 4                  2             NONE -73.264511  41.143125
#
#                                    Charging Stations
# 0                    BMW OF DARIEN, 138-142 Ledge Rd
# 1        Dunkin’ - Tesla Supercharger, 893 E Main St
# 2  Town of Beacon Falls - Commuter Lot, 105 N Mai...
# 3            OLD SAYBROOK VW, 319 Middlesex Turnpike
# 4           Fairfield Rail Station, 80 Mill Plain Rd
#
# Places DataFrame:
#                                      Locations            City  Longitude  \
# 0                    Connecticut State Capitol        Hartford -72.682280
# 1  Pratt & Whitney Stadium at Rentschler Field   East Hartford -72.618568
# 2                  Talcott Mountain State Park        Simsbury -72.790860
# 3                       New England Air Museum   Windsor Locks -72.691551
# 4               Phelps-Hatheway House & Garden        Suffield -72.652436
#
#     Latitude
# 0  41.764263
# 1  41.759965
# 2  41.835535
# 3  41.947718
# 4  41.980224

# %%
# Create a distance matrix
distance_matrix = pd.DataFrame(index=charging_stations_df["Charging Stations"], columns=places_df["Locations"])

for idx, row in charging_stations_df.iterrows():
    for col in places_df["Locations"]:
        station_coords = (row["Latitude"], row["Longitude"])
        place_coords = (places_df.loc[places_df["Locations"] == col, "Latitude"].values[0],
                        places_df.loc[places_df["Locations"] == col, "Longitude"].values[0])
        distance = geodesic(station_coords, place_coords).miles
        distance_matrix.at[row["Charging Stations"], col] = distance

# %%
# Create a distance matrix with distance for qualifying charging stations
qualifying_charging_stations = charging_stations_df[
    (charging_stations_df["Access Days Time"].str.contains("24 hours")) &
    (
        (pd.to_numeric(charging_stations_df["EV Level2 EVSE Num"], errors='coerce') > 0) |
        (pd.to_numeric(charging_stations_df["EV DC Fast Count"], errors='coerce') > 0)
    )]

qualifying_distance_matrix = pd.DataFrame(index=qualifying_charging_stations["Charging Stations"], columns=places_df["Locations"])

for idx, row in qualifying_charging_stations.iterrows():
    for col in places_df["Locations"]:
        qualifying_distance_matrix.at[row["Charging Stations"], col] = distance_matrix.at[row["Charging Stations"], col]
print(qualifying_distance_matrix)
# Out:
# Locations                                          Connecticut State Capitol  \
# Charging Stations
# BMW OF DARIEN, 138-142 Ledge Rd                                    63.075025
# Dunkin’ - Tesla Supercharger, 893 E Main St                        17.016899
# Town of Beacon Falls - Commuter Lot, 105 N Main St                 29.634424
# OLD SAYBROOK VW, 319 Middlesex Turnpike                            34.974589
# Fairfield Rail Station, 80 Mill Plain Rd                           52.451869
# ...                                                                      ...
# Yankee Doodle, 10 Burnell Boulevard                                58.620315
# 777 MAIN ST, 71 Asylum St                                            0.43666
# Norwich Public Utilities, 173 N Main St                            35.955034
# Fairfield Plaza, 116 Danbury Rd                                    40.647661
# Eastern Connecticut State University - Shakespe...                 24.568266
#
# Locations                                          Pratt & Whitney Stadium at Rentschler Field  \
# Charging Stations
# BMW OF DARIEN, 138-142 Ledge Rd                                                      65.072244
# Dunkin’ - Tesla Supercharger, 893 E Main St                                          17.943901
# Town of Beacon Falls - Commuter Lot, 105 N Main St                                   31.736536
# OLD SAYBROOK VW, 319 Middlesex Turnpike                                              33.360795
# Fairfield Rail Station, 80 Mill Plain Rd                                             54.192729
# ...                                                                                        ...
# Yankee Doodle, 10 Burnell Boulevard                                                  60.603389
# 777 MAIN ST, 71 Asylum St                                                              2.92534
# Norwich Public Utilities, 173 N Main St                                              32.906167
# Fairfield Plaza, 116 Danbury Rd                                                      43.655525
# Eastern Connecticut State University - Shakespe...                                   21.263523
#
# Locations                                          Talcott Mountain State Park  \
# Charging Stations
# BMW OF DARIEN, 138-142 Ledge Rd                                      63.538031
# Dunkin’ - Tesla Supercharger, 893 E Main St                          21.286911
# Town of Beacon Falls - Commuter Lot, 105 N Main St                   30.445097
# OLD SAYBROOK VW, 319 Middlesex Turnpike                               41.97464
# Fairfield Rail Station, 80 Mill Plain Rd                             53.734502
# ...                                                                        ...
# Yankee Doodle, 10 Burnell Boulevard                                  59.168283
# 777 MAIN ST, 71 Asylum St                                             7.662389
# Norwich Public Utilities, 173 N Main St                              43.217362
# Fairfield Plaza, 116 Danbury Rd                                      37.677779
# Eastern Connecticut State University - Shakespe...                   30.833753
#
# Locations                                          New England Air Museum  \
# Charging Stations
# BMW OF DARIEN, 138-142 Ledge Rd                                 72.820038
# Dunkin’ - Tesla Supercharger, 893 E Main St                     29.317788
# Town of Beacon Falls - Commuter Lot, 105 N Main St              39.695127
# OLD SAYBROOK VW, 319 Middlesex Turnpike                         46.811831
# Fairfield Rail Station, 80 Mill Plain Rd                        62.972962
# ...                                                                   ...
# Yankee Doodle, 10 Burnell Boulevard                             68.451176
# 777 MAIN ST, 71 Asylum St                                       12.525848
# Norwich Public Utilities, 173 N Main St                         43.527771
# Fairfield Plaza, 116 Danbury Rd                                 46.193449
# Eastern Connecticut State University - Shakespe...              28.821954
#
# Locations                                          Phelps-Hatheway House & Garden  \
# Charging Stations
# BMW OF DARIEN, 138-142 Ledge Rd                                         75.809603
# Dunkin’ - Tesla Supercharger, 893 E Main St                             31.873587
# Town of Beacon Falls - Commuter Lot, 105 N Main St                       42.64275
# OLD SAYBROOK VW, 319 Middlesex Turnpike                                 48.300665
# Fairfield Rail Station, 80 Mill Plain Rd                                65.907882
# ...                                                                           ...
# Yankee Doodle, 10 Burnell Boulevard                                     71.435252
# 777 MAIN ST, 71 Asylum St                                               14.782011
# Norwich Public Utilities, 173 N Main St                                 43.613563
# Fairfield Plaza, 116 Danbury Rd                                         49.140055
# Eastern Connecticut State University - Shakespe...                      28.347623
#
# Locations                                          Connecticut Trolley Museum  \
# Charging Stations
# BMW OF DARIEN, 138-142 Ledge Rd                                     75.117788
# Dunkin’ - Tesla Supercharger, 893 E Main St                         29.346734
# Town of Beacon Falls - Commuter Lot, 105 N Main St                  41.690526
# OLD SAYBROOK VW, 319 Middlesex Turnpike                             43.734654
# Fairfield Rail Station, 80 Mill Plain Rd                            64.729027
# ...                                                                       ...
# Yankee Doodle, 10 Burnell Boulevard                                 70.686952
# 777 MAIN ST, 71 Asylum St                                           12.105365
# Norwich Public Utilities, 173 N Main St                               38.3069
# Fairfield Plaza, 116 Danbury Rd                                     50.312083
# Eastern Connecticut State University - Shakespe...                  23.105315
#
# Locations                                          Shenipsit State Forest  \
# Charging Stations
# BMW OF DARIEN, 138-142 Ledge Rd                                 82.653065
# Dunkin’ - Tesla Supercharger, 893 E Main St                     35.419798
# Town of Beacon Falls - Commuter Lot, 105 N Main St              49.240636
# OLD SAYBROOK VW, 319 Middlesex Turnpike                         44.971616
# Fairfield Rail Station, 80 Mill Plain Rd                        71.840092
# ...                                                                   ...
# Yankee Doodle, 10 Burnell Boulevard                             78.190201
# 777 MAIN ST, 71 Asylum St                                       19.226618
# Norwich Public Utilities, 173 N Main St                         34.854318
# Fairfield Plaza, 116 Danbury Rd                                 59.152245
# Eastern Connecticut State University - Shakespe...               18.53591
#
# Locations                                          University of Connecticut  \
# Charging Stations
# BMW OF DARIEN, 138-142 Ledge Rd                                    81.251133
# Dunkin’ - Tesla Supercharger, 893 E Main St                        33.122307
# Town of Beacon Falls - Commuter Lot, 105 N Main St                 48.899397
# OLD SAYBROOK VW, 319 Middlesex Turnpike                            34.971529
# Fairfield Rail Station, 80 Mill Plain Rd                           69.673432
# ...                                                                      ...
# Yankee Doodle, 10 Burnell Boulevard                                76.794956
# 777 MAIN ST, 71 Asylum St                                          21.903229
# Norwich Public Utilities, 173 N Main St                            21.702251
# Fairfield Plaza, 116 Danbury Rd                                    62.633156
# Eastern Connecticut State University - Shakespe...                  5.327873
#
# Locations                                          Patriots Park  \
# Charging Stations
# BMW OF DARIEN, 138-142 Ledge Rd                        77.386431
# Dunkin’ - Tesla Supercharger, 893 E Main St            29.291907
# Town of Beacon Falls - Commuter Lot, 105 N Main St     45.149228
# OLD SAYBROOK VW, 319 Middlesex Turnpike                31.778619
# Fairfield Rail Station, 80 Mill Plain Rd               65.788387
# ...                                                          ...
# Yankee Doodle, 10 Burnell Boulevard                    72.933234
# 777 MAIN ST, 71 Asylum St                              19.006567
# Norwich Public Utilities, 173 N Main St                20.781074
# Fairfield Plaza, 116 Danbury Rd                        59.293413
# Eastern Connecticut State University - Shakespe...      5.459239
#
# Locations                                          Wadsworth Falls State Park  \
# Charging Stations
# BMW OF DARIEN, 138-142 Ledge Rd                                     52.126887
# Dunkin’ - Tesla Supercharger, 893 E Main St                           4.58151
# Town of Beacon Falls - Commuter Lot, 105 N Main St                   20.68015
# OLD SAYBROOK VW, 319 Middlesex Turnpike                             22.208087
# Fairfield Rail Station, 80 Mill Plain Rd                            40.541692
# ...                                                                       ...
# Yankee Doodle, 10 Burnell Boulevard                                 47.678455
# 777 MAIN ST, 71 Asylum St                                           15.868392
# Norwich Public Utilities, 173 N Main St                             32.288206
# Fairfield Plaza, 116 Danbury Rd                                     37.954996
# Eastern Connecticut State University - Shakespe...                  28.388461
#
# Locations                                           ... Mystic Seaport Museum  \
# Charging Stations                                   ...
# BMW OF DARIEN, 138-142 Ledge Rd                     ...             81.286476
# Dunkin’ - Tesla Supercharger, 893 E Main St         ...             43.572482
# Town of Beacon Falls - Commuter Lot, 105 N Main St  ...              57.53549
# OLD SAYBROOK VW, 319 Middlesex Turnpike             ...             22.053499
# Fairfield Rail Station, 80 Mill Plain Rd            ...             69.385182
# ...                                                 ...                   ...
# Yankee Doodle, 10 Burnell Boulevard                 ...             77.421964
# 777 MAIN ST, 71 Asylum St                           ...             46.251858
# Norwich Public Utilities, 173 N Main St             ...             12.591171
# Fairfield Plaza, 116 Danbury Rd                     ...             76.671675
# Eastern Connecticut State University - Shakespe...  ...             28.957032
#
# Locations                                          Mohegan Park  \
# Charging Stations
# BMW OF DARIEN, 138-142 Ledge Rd                       80.304596
# Dunkin’ - Tesla Supercharger, 893 E Main St           36.624893
# Town of Beacon Falls - Commuter Lot, 105 N Main St    52.258092
# OLD SAYBROOK VW, 319 Middlesex Turnpike               23.168826
# Fairfield Rail Station, 80 Mill Plain Rd              68.227917
# ...                                                         ...
# Yankee Doodle, 10 Burnell Boulevard                   76.102935
# 777 MAIN ST, 71 Asylum St                             34.839318
# Norwich Public Utilities, 173 N Main St                1.434347
# Fairfield Plaza, 116 Danbury Rd                       69.983793
# Eastern Connecticut State University - Shakespe...    15.021651
#
# Locations                                          Rotary Park & Bandstand  \
# Charging Stations
# BMW OF DARIEN, 138-142 Ledge Rd                                  99.950863
# Dunkin’ - Tesla Supercharger, 893 E Main St                       52.07102
# Town of Beacon Falls - Commuter Lot, 105 N Main St               68.020206
# OLD SAYBROOK VW, 319 Middlesex Turnpike                          48.470468
# Fairfield Rail Station, 80 Mill Plain Rd                          88.19432
# ...                                                                    ...
# Yankee Doodle, 10 Burnell Boulevard                              95.521123
# 777 MAIN ST, 71 Asylum St                                        40.741615
# Norwich Public Utilities, 173 N Main St                           28.00758
# Fairfield Plaza, 116 Danbury Rd                                  81.737043
# Eastern Connecticut State University - Shakespe...               19.666604
#
# Locations                                          Windham Textile & History Museum  \
# Charging Stations
# BMW OF DARIEN, 138-142 Ledge Rd                                           79.374102
# Dunkin’ - Tesla Supercharger, 893 E Main St                               32.018482
# Town of Beacon Falls - Commuter Lot, 105 N Main St                        48.179773
# OLD SAYBROOK VW, 319 Middlesex Turnpike                                   29.133887
# Fairfield Rail Station, 80 Mill Plain Rd                                  67.528757
# ...                                                                             ...
# Yankee Doodle, 10 Burnell Boulevard                                       74.971471
# 777 MAIN ST, 71 Asylum St                                                   24.5358
# Norwich Public Utilities, 173 N Main St                                   14.641373
# Fairfield Plaza, 116 Danbury Rd                                           63.637844
# Eastern Connecticut State University - Shakespe...                         1.910819
#
# Locations                                          Kettletown State Park  \
# Charging Stations
# BMW OF DARIEN, 138-142 Ledge Rd                                28.267775
# Dunkin’ - Tesla Supercharger, 893 E Main St                    23.397717
# Town of Beacon Falls - Commuter Lot, 105 N Main St              7.307301
# OLD SAYBROOK VW, 319 Middlesex Turnpike                        43.472379
# Fairfield Rail Station, 80 Mill Plain Rd                        19.85611
# ...                                                                  ...
# Yankee Doodle, 10 Burnell Boulevard                            23.993672
# 777 MAIN ST, 71 Asylum St                                      36.080589
# Norwich Public Utilities, 173 N Main St                        59.604065
# Fairfield Plaza, 116 Danbury Rd                                14.258022
# Eastern Connecticut State University - Shakespe...              55.90512
#
# Locations                                          Tarrywile Park & Mansion  \
# Charging Stations
# BMW OF DARIEN, 138-142 Ledge Rd                                   21.203763
# Dunkin’ - Tesla Supercharger, 893 E Main St                       36.690559
# Town of Beacon Falls - Commuter Lot, 105 N Main St                20.599557
# OLD SAYBROOK VW, 319 Middlesex Turnpike                           55.841616
# Fairfield Rail Station, 80 Mill Plain Rd                          19.025081
# ...                                                                     ...
# Yankee Doodle, 10 Burnell Boulevard                               18.155599
# 777 MAIN ST, 71 Asylum St                                         48.358351
# Norwich Public Utilities, 173 N Main St                           72.824161
# Fairfield Plaza, 116 Danbury Rd                                    12.39794
# Eastern Connecticut State University - Shakespe...                 69.08624
#
# Locations                                          Lover's Leap State Park  \
# Charging Stations
# BMW OF DARIEN, 138-142 Ledge Rd                                  32.632079
# Dunkin’ - Tesla Supercharger, 893 E Main St                      32.957768
# Town of Beacon Falls - Commuter Lot, 105 N Main St               19.033321
# OLD SAYBROOK VW, 319 Middlesex Turnpike                          55.668767
# Fairfield Rail Station, 80 Mill Plain Rd                         28.594933
# ...                                                                    ...
# Yankee Doodle, 10 Burnell Boulevard                               29.32737
# 777 MAIN ST, 71 Asylum St                                        41.019611
# Norwich Public Utilities, 173 N Main St                          69.761637
# Fairfield Plaza, 116 Danbury Rd                                   1.094021
# Eastern Connecticut State University - Shakespe...               63.602557
#
# Locations                                          Burr Pond State Park  \
# Charging Stations
# BMW OF DARIEN, 138-142 Ledge Rd                               58.542312
# Dunkin’ - Tesla Supercharger, 893 E Main St                   28.865341
# Town of Beacon Falls - Commuter Lot, 105 N Main St            29.366873
# OLD SAYBROOK VW, 319 Middlesex Turnpike                       53.367977
# Fairfield Rail Station, 80 Mill Plain Rd                      50.985672
# ...                                                                 ...
# Yankee Doodle, 10 Burnell Boulevard                           54.558472
# 777 MAIN ST, 71 Asylum St                                     22.742357
# Norwich Public Utilities, 173 N Main St                       58.248532
# Fairfield Plaza, 116 Danbury Rd                               27.381543
# Eastern Connecticut State University - Shakespe...            46.567575
#
# Locations                                          Lake Compounce  \
# Charging Stations
# BMW OF DARIEN, 138-142 Ledge Rd                         48.637391
# Dunkin’ - Tesla Supercharger, 893 E Main St             10.997149
# Town of Beacon Falls - Commuter Lot, 105 N Main St      15.385367
# OLD SAYBROOK VW, 319 Middlesex Turnpike                 36.137011
# Fairfield Rail Station, 80 Mill Plain Rd                38.670601
# ...                                                           ...
# Yankee Doodle, 10 Burnell Boulevard                     44.233124
# 777 MAIN ST, 71 Asylum St                               15.493991
# Norwich Public Utilities, 173 N Main St                 45.190237
# Fairfield Plaza, 116 Danbury Rd                         26.286225
# Eastern Connecticut State University - Shakespe...      37.567124
#
# Locations                                          Hill-Stead Museum
# Charging Stations
# BMW OF DARIEN, 138-142 Ledge Rd                            56.292216
# Dunkin’ - Tesla Supercharger, 893 E Main St                13.654466
# Town of Beacon Falls - Commuter Lot, 105 N Main St         22.925067
# OLD SAYBROOK VW, 319 Middlesex Turnpike                     36.38222
# Fairfield Rail Station, 80 Mill Plain Rd                   46.129213
# ...                                                              ...
# Yankee Doodle, 10 Burnell Boulevard                        51.874435
# 777 MAIN ST, 71 Asylum St                                   8.152284
# Norwich Public Utilities, 173 N Main St                    41.432302
# Fairfield Plaza, 116 Danbury Rd                            32.936819
# Eastern Connecticut State University - Shakespe...         31.678699
#
# [301 rows x 34 columns]

# %%
# Create a location distance matrix
location_distance_matrix = pd.DataFrame(index=places_df["Locations"], columns=places_df["Locations"])

for idx1, row1 in places_df.iterrows():
    for idx2, row2 in places_df.iterrows():
        location1_coords = (row1["Latitude"], row1["Longitude"])
        location2_coords = (row2["Latitude"], row2["Longitude"])
        distance = geodesic(location1_coords, location2_coords).miles
        location_distance_matrix.at[row1["Locations"], row2["Locations"]] = distance

# Display the location distance matrix
print("Location Distance Matrix:")
print(location_distance_matrix)
# Out:
# Location Distance Matrix:
# Locations                                   Connecticut State Capitol  \
# Locations
# Connecticut State Capitol                                         0.0
# Pratt & Whitney Stadium at Rentschler Field                  3.305513
# Talcott Mountain State Park                                  7.459013
# New England Air Museum                                      12.670356
# Phelps-Hatheway House & Garden                              14.984078
# Connecticut Trolley Museum                                  12.426005
# Shenipsit State Forest                                      19.631927
# University of Connecticut                                   22.325602
# Patriots Park                                               19.411611
# Wadsworth Falls State Park                                  15.691763
# Hubbard Park                                                16.901365
# Wharton Brook State Park                                    24.752078
# Yale University                                             33.325053
# Sleeping Giant State Park                                    26.22279
# Boothe Memorial Park and Museum                             42.711079
# Seaside Park                                                49.186032
# The Maritime Aquarium                                       59.570117
# Stamford Museum & Nature Center                             62.838247
# Bruce Museum                                                70.915352
# Westport Country Playhouse                                  55.335878
# Fairfield Museum and History Center                         52.097025
# Pequonnock River Trail                                      42.010175
# Silver Sands State Park                                     43.753013
# Fort Trumbull State Park                                     42.10342
# Mystic Seaport Museum                                       46.475617
# Mohegan Park                                                35.133745
# Rotary Park & Bandstand                                     41.174668
# Windham Textile & History Museum                            24.910038
# Kettletown State Park                                       35.665304
# Tarrywile Park & Mansion                                    47.929578
# Lover's Leap State Park                                     40.582972
# Burr Pond State Park                                        22.414253
# Lake Compounce                                              15.066512
# Hill-Stead Museum                                             7.71563
#
# Locations                                   Pratt & Whitney Stadium at Rentschler Field  \
# Locations
# Connecticut State Capitol                                                      3.305513
# Pratt & Whitney Stadium at Rentschler Field                                         0.0
# Talcott Mountain State Park                                                   10.313711
# New England Air Museum                                                        13.494078
# Phelps-Hatheway House & Garden                                                 15.30149
# Connecticut Trolley Museum                                                    11.692456
# Shenipsit State Forest                                                        17.648036
# University of Connecticut                                                     19.119187
# Patriots Park                                                                 16.126857
# Wadsworth Falls State Park                                                    15.785157
# Hubbard Park                                                                  18.447182
# Wharton Brook State Park                                                      25.746877
# Yale University                                                               34.430711
# Sleeping Giant State Park                                                     27.545941
# Boothe Memorial Park and Museum                                               44.273593
# Seaside Park                                                                  50.787443
# The Maritime Aquarium                                                         61.522157
# Stamford Museum & Nature Center                                               65.040615
# Bruce Museum                                                                   73.03012
# Westport Country Playhouse                                                    57.258983
# Fairfield Museum and History Center                                           53.798252
# Pequonnock River Trail                                                         44.18988
# Silver Sands State Park                                                       45.105939
# Fort Trumbull State Park                                                      39.557751
# Mystic Seaport Museum                                                         43.687972
# Mohegan Park                                                                  32.043024
# Rotary Park & Bandstand                                                       38.089947
# Windham Textile & History Museum                                              21.610488
# Kettletown State Park                                                         38.049175
# Tarrywile Park & Mansion                                                      50.558272
# Lover's Leap State Park                                                       43.554294
# Burr Pond State Park                                                          25.632739
# Lake Compounce                                                                 17.74258
# Hill-Stead Museum                                                              10.76093
#
# Locations                                   Talcott Mountain State Park  \
# Locations
# Connecticut State Capitol                                      7.459013
# Pratt & Whitney Stadium at Rentschler Field                   10.313711
# Talcott Mountain State Park                                         0.0
# New England Air Museum                                         9.282897
# Phelps-Hatheway House & Garden                                12.273853
# Connecticut Trolley Museum                                    12.634645
# Shenipsit State Forest                                        21.562537
# University of Connecticut                                     27.782438
# Patriots Park                                                 25.447602
# Wadsworth Falls State Park                                    21.310879
# Hubbard Park                                                  19.964701
# Wharton Brook State Park                                      28.429212
# Yale University                                               36.474165
# Sleeping Giant State Park                                     29.155712
# Boothe Memorial Park and Museum                               44.602144
# Seaside Park                                                  50.871589
# The Maritime Aquarium                                         60.195744
# Stamford Museum & Nature Center                               62.695674
# Bruce Museum                                                  70.970639
# Westport Country Playhouse                                    56.089933
# Fairfield Museum and History Center                           53.487585
# Pequonnock River Trail                                        42.227466
# Silver Sands State Park                                       46.124782
# Fort Trumbull State Park                                      49.558532
# Mystic Seaport Museum                                         53.912339
# Mohegan Park                                                   42.34241
# Rotary Park & Bandstand                                       45.727951
# Windham Textile & History Museum                              31.431509
# Kettletown State Park                                         35.383485
# Tarrywile Park & Mansion                                      46.517208
# Lover's Leap State Park                                       37.805346
# Burr Pond State Park                                          15.752389
# Lake Compounce                                                15.064613
# Hill-Stead Museum                                              7.980657
#
# Locations                                   New England Air Museum  \
# Locations
# Connecticut State Capitol                                12.670356
# Pratt & Whitney Stadium at Rentschler Field              13.494078
# Talcott Mountain State Park                               9.282897
# New England Air Museum                                         0.0
# Phelps-Hatheway House & Garden                            3.015383
# Connecticut Trolley Museum                                6.007109
# Shenipsit State Forest                                   14.626535
# University of Connecticut                                24.550286
# Patriots Park                                            23.444868
# Wadsworth Falls State Park                               28.353311
# Hubbard Park                                             28.564044
# Wharton Brook State Park                                 36.851561
# Yale University                                          45.183303
# Sleeping Giant State Park                                37.907581
# Boothe Memorial Park and Museum                          53.727783
# Seaside Park                                             60.048593
# The Maritime Aquarium                                    69.478219
# Stamford Museum & Nature Center                          71.941868
# Bruce Museum                                             80.230041
# Westport Country Playhouse                               65.368746
# Fairfield Museum and History Center                      62.712744
# Pequonnock River Trail                                   51.509129
# Silver Sands State Park                                  55.135879
# Fort Trumbull State Park                                 51.901526
# Mystic Seaport Museum                                    55.286493
# Mohegan Park                                             42.428739
# Rotary Park & Bandstand                                  40.279311
# Windham Textile & History Museum                         29.933396
# Kettletown State Park                                    44.649313
# Tarrywile Park & Mansion                                 55.562933
# Lover's Leap State Park                                  46.413644
# Burr Pond State Park                                     21.347877
# Lake Compounce                                            24.31004
# Hill-Stead Museum                                        16.937335
#
# Locations                                   Phelps-Hatheway House & Garden  \
# Locations
# Connecticut State Capitol                                        14.984078
# Pratt & Whitney Stadium at Rentschler Field                       15.30149
# Talcott Mountain State Park                                      12.273853
# New England Air Museum                                            3.015383
# Phelps-Hatheway House & Garden                                         0.0
# Connecticut Trolley Museum                                        5.308687
# Shenipsit State Forest                                           12.642028
# University of Connecticut                                        23.746233
# Patriots Park                                                    23.115752
# Wadsworth Falls State Park                                       30.644581
# Hubbard Park                                                     31.287255
# Wharton Brook State Park                                         39.491005
# Yale University                                                   47.90075
# Sleeping Giant State Park                                        40.652518
# Boothe Memorial Park and Museum                                  56.603106
# Seaside Park                                                     62.947538
# The Maritime Aquarium                                            72.458748
# Stamford Museum & Nature Center                                  74.951411
# Bruce Museum                                                     83.236212
# Westport Country Playhouse                                       68.340569
# Fairfield Museum and History Center                              65.638918
# Pequonnock River Trail                                           54.499801
# Silver Sands State Park                                          57.959503
# Fort Trumbull State Park                                         52.572709
# Mystic Seaport Museum                                            55.625645
# Mohegan Park                                                     42.452652
# Rotary Park & Bandstand                                          38.446447
# Windham Textile & History Museum                                 29.612282
# Kettletown State Park                                            47.652598
# Tarrywile Park & Mansion                                         58.573104
# Lover's Leap State Park                                           49.37386
# Burr Pond State Park                                             23.913329
# Lake Compounce                                                   27.262282
# Hill-Stead Museum                                                19.816682
#
# Locations                                   Connecticut Trolley Museum  \
# Locations
# Connecticut State Capitol                                    12.426005
# Pratt & Whitney Stadium at Rentschler Field                  11.692456
# Talcott Mountain State Park                                  12.634645
# New England Air Museum                                        6.007109
# Phelps-Hatheway House & Garden                                5.308687
# Connecticut Trolley Museum                                         0.0
# Shenipsit State Forest                                        9.093944
# University of Connecticut                                    18.642831
# Patriots Park                                                17.830134
# Wadsworth Falls State Park                                   27.470621
# Hubbard Park                                                 29.319744
# Wharton Brook State Park                                     37.125062
# Yale University                                              45.734139
# Sleeping Giant State Park                                     38.64879
# Boothe Memorial Park and Museum                              55.086325
# Seaside Park                                                 61.539756
# The Maritime Aquarium                                        71.666303
# Stamford Museum & Nature Center                              74.618485
# Bruce Museum                                                 82.800901
# Westport Country Playhouse                                   67.467974
# Fairfield Museum and History Center                          64.398258
# Pequonnock River Trail                                       53.900459
# Silver Sands State Park                                      56.174175
# Fort Trumbull State Park                                     47.400232
# Mystic Seaport Museum                                        50.347769
# Mohegan Park                                                 37.144085
# Rotary Park & Bandstand                                       34.40587
# Windham Textile & History Museum                             24.331737
# Kettletown State Park                                        47.290921
# Tarrywile Park & Mansion                                     58.919391
# Lover's Leap State Park                                      50.433409
# Burr Pond State Park                                         26.790687
# Lake Compounce                                               26.556763
# Hill-Stead Museum                                            18.858902
#
# Locations                                   Shenipsit State Forest  \
# Locations
# Connecticut State Capitol                                19.631927
# Pratt & Whitney Stadium at Rentschler Field              17.648036
# Talcott Mountain State Park                              21.562537
# New England Air Museum                                   14.626535
# Phelps-Hatheway House & Garden                           12.642028
# Connecticut Trolley Museum                                9.093944
# Shenipsit State Forest                                         0.0
# University of Connecticut                                13.270304
# Patriots Park                                            14.405933
# Wadsworth Falls State Park                               32.639037
# Hubbard Park                                             36.095174
# Wharton Brook State Park                                  43.17895
# Yale University                                          51.881285
# Sleeping Giant State Park                                45.136678
# Boothe Memorial Park and Museum                          61.908741
# Seaside Park                                             68.426853
# The Maritime Aquarium                                    79.123152
# Stamford Museum & Nature Center                            82.4701
# Bruce Museum                                             90.537042
# Westport Country Playhouse                               74.870234
# Fairfield Museum and History Center                      71.446203
# Pequonnock River Trail                                   61.638842
# Silver Sands State Park                                  62.669583
# Fort Trumbull State Park                                 45.619142
# Mystic Seaport Museum                                    47.388765
# Mohegan Park                                             33.528545
# Rotary Park & Bandstand                                  25.805208
# Windham Textile & History Museum                         20.213876
# Kettletown State Park                                     55.27367
# Tarrywile Park & Mansion                                 67.321178
# Lover's Leap State Park                                  59.229245
# Burr Pond State Park                                     35.829887
# Lake Compounce                                           34.577182
# Hill-Stead Museum                                        26.945393
#
# Locations                                   University of Connecticut  \
# Locations
# Connecticut State Capitol                                   22.325602
# Pratt & Whitney Stadium at Rentschler Field                 19.119187
# Talcott Mountain State Park                                 27.782438
# New England Air Museum                                      24.550286
# Phelps-Hatheway House & Garden                              23.746233
# Connecticut Trolley Museum                                  18.642831
# Shenipsit State Forest                                      13.270304
# University of Connecticut                                         0.0
# Patriots Park                                                3.900541
# Wadsworth Falls State Park                                   29.14065
# Hubbard Park                                                35.042092
# Wharton Brook State Park                                    40.137614
# Yale University                                             48.479437
# Sleeping Giant State Park                                   42.769655
# Boothe Memorial Park and Museum                             59.411593
# Seaside Park                                                65.864999
# The Maritime Aquarium                                       77.595812
# Stamford Museum & Nature Center                              81.89738
# Bruce Museum                                                89.521377
# Westport Country Playhouse                                  73.301495
# Fairfield Museum and History Center                         69.150337
# Pequonnock River Trail                                      61.261512
# Silver Sands State Park                                     59.487223
# Fort Trumbull State Park                                    33.051451
# Mystic Seaport Museum                                        34.28481
# Mohegan Park                                                20.345424
# Rotary Park & Bandstand                                     19.232202
# Windham Textile & History Museum                             7.130304
# Kettletown State Park                                        55.77718
# Tarrywile Park & Mansion                                    68.754334
# Lover's Leap State Park                                     62.479506
# Burr Pond State Park                                        43.494408
# Lake Compounce                                              36.435284
# Hill-Stead Museum                                           29.863716
#
# Locations                                   Patriots Park  \
# Locations
# Connecticut State Capitol                       19.411611
# Pratt & Whitney Stadium at Rentschler Field     16.126857
# Talcott Mountain State Park                     25.447602
# New England Air Museum                          23.444868
# Phelps-Hatheway House & Garden                  23.115752
# Connecticut Trolley Museum                      17.830134
# Shenipsit State Forest                          14.405933
# University of Connecticut                        3.900541
# Patriots Park                                         0.0
# Wadsworth Falls State Park                      25.265137
# Hubbard Park                                    31.295876
# Wharton Brook State Park                        36.252544
# Yale University                                 44.580612
# Sleeping Giant State Park                       38.904819
# Boothe Memorial Park and Museum                 55.523338
# Seaside Park                                    61.972185
# The Maritime Aquarium                           73.728108
# Stamford Museum & Nature Center                 78.074416
# Bruce Museum                                    85.669351
# Westport Country Playhouse                      69.434812
# Fairfield Museum and History Center             65.262127
# Pequonnock River Trail                          57.477446
# Silver Sands State Park                         55.587708
# Fort Trumbull State Park                        31.213549
# Mystic Seaport Museum                           33.173663
# Mohegan Park                                    19.533032
# Rotary Park & Bandstand                         22.882345
# Windham Textile & History Museum                 6.503458
# Kettletown State Park                           52.082138
# Tarrywile Park & Mansion                        65.121358
# Lover's Leap State Park                          59.10451
# Burr Pond State Park                            41.196205
# Lake Compounce                                  33.027642
# Hill-Stead Museum                               26.743396
#
# Locations                                   Wadsworth Falls State Park  ...  \
# Locations                                                               ...
# Connecticut State Capitol                                    15.691763  ...
# Pratt & Whitney Stadium at Rentschler Field                  15.785157  ...
# Talcott Mountain State Park                                  21.310879  ...
# New England Air Museum                                       28.353311  ...
# Phelps-Hatheway House & Garden                               30.644581  ...
# Connecticut Trolley Museum                                   27.470621  ...
# Shenipsit State Forest                                       32.639037  ...
# University of Connecticut                                     29.14065  ...
# Patriots Park                                                25.265137  ...
# Wadsworth Falls State Park                                         0.0  ...
# Hubbard Park                                                  7.821177  ...
# Wharton Brook State Park                                     11.020041  ...
# Yale University                                              19.554366  ...
# Sleeping Giant State Park                                    13.654454  ...
# Boothe Memorial Park and Museum                              30.294587  ...
# Seaside Park                                                 36.775916  ...
# The Maritime Aquarium                                        48.465498  ...
# Stamford Museum & Nature Center                              52.937425  ...
# Bruce Museum                                                 60.432384  ...
# Westport Country Playhouse                                   44.173422  ...
# Fairfield Museum and History Center                          40.029762  ...
# Pequonnock River Trail                                       32.598199  ...
# Silver Sands State Park                                        30.5441  ...
# Fort Trumbull State Park                                     33.535845  ...
# Mystic Seaport Museum                                         39.40561  ...
# Mohegan Park                                                 32.070332  ...
# Rotary Park & Bandstand                                      47.890099  ...
# Windham Textile & History Museum                             27.623564  ...
# Kettletown State Park                                        27.934675  ...
# Tarrywile Park & Mansion                                     41.236093  ...
# Lover's Leap State Park                                      37.473439  ...
# Burr Pond State Park                                         31.178478  ...
# Lake Compounce                                               14.196553  ...
# Hill-Stead Museum                                            14.550841  ...
#
# Locations                                   Mystic Seaport Museum  \
# Locations
# Connecticut State Capitol                               46.475617
# Pratt & Whitney Stadium at Rentschler Field             43.687972
# Talcott Mountain State Park                             53.912339
# New England Air Museum                                  55.286493
# Phelps-Hatheway House & Garden                          55.625645
# Connecticut Trolley Museum                              50.347769
# Shenipsit State Forest                                  47.388765
# University of Connecticut                                34.28481
# Patriots Park                                           33.173663
# Wadsworth Falls State Park                               39.40561
# Hubbard Park                                            47.086624
# Wharton Brook State Park                                45.617874
# Yale University                                         49.943951
# Sleeping Giant State Park                               48.781516
# Boothe Memorial Park and Museum                         60.247428
# Seaside Park                                            65.216802
# The Maritime Aquarium                                   77.776562
# Stamford Museum & Nature Center                         83.961222
# Bruce Museum                                            89.628869
# Westport Country Playhouse                              73.981972
# Fairfield Museum and History Center                     68.613936
# Pequonnock River Trail                                   66.93928
# Silver Sands State Park                                 58.518609
# Fort Trumbull State Park                                 6.819643
# Mystic Seaport Museum                                         0.0
# Mohegan Park                                            13.977789
# Rotary Park & Bandstand                                 38.452949
# Windham Textile & History Museum                        27.197209
# Kettletown State Park                                   64.612223
# Tarrywile Park & Mansion                                77.384308
# Lover's Leap State Park                                 76.054872
# Burr Pond State Park                                    68.203365
# Lake Compounce                                          53.344849
# Hill-Stead Museum                                       50.916716
#
# Locations                                   Mohegan Park  \
# Locations
# Connecticut State Capitol                      35.133745
# Pratt & Whitney Stadium at Rentschler Field    32.043024
# Talcott Mountain State Park                     42.34241
# New England Air Museum                         42.428739
# Phelps-Hatheway House & Garden                 42.452652
# Connecticut Trolley Museum                     37.144085
# Shenipsit State Forest                         33.528545
# University of Connecticut                      20.345424
# Patriots Park                                  19.533032
# Wadsworth Falls State Park                     32.070332
# Hubbard Park                                   39.839382
# Wharton Brook State Park                       40.847544
# Yale University                                47.182425
# Sleeping Giant State Park                      44.036359
# Boothe Memorial Park and Museum                58.287167
# Seaside Park                                   64.075353
# The Maritime Aquarium                          76.652337
# Stamford Museum & Nature Center                 82.19676
# Bruce Museum                                   88.784587
# Westport Country Playhouse                     72.551421
# Fairfield Museum and History Center            67.537436
# Pequonnock River Trail                         63.235274
# Silver Sands State Park                        57.253092
# Fort Trumbull State Park                       14.128115
# Mystic Seaport Museum                          13.977789
# Mohegan Park                                         0.0
# Rotary Park & Bandstand                         26.71389
# Windham Textile & History Museum               13.317111
# Kettletown State Park                          59.562385
# Tarrywile Park & Mansion                       72.812068
# Lover's Leap State Park                        69.527733
# Burr Pond State Park                           57.480688
# Lake Compounce                                 44.746447
# Hill-Stead Museum                              40.783094
#
# Locations                                   Rotary Park & Bandstand  \
# Locations
# Connecticut State Capitol                                 41.174668
# Pratt & Whitney Stadium at Rentschler Field               38.089947
# Talcott Mountain State Park                               45.727951
# New England Air Museum                                    40.279311
# Phelps-Hatheway House & Garden                            38.446447
# Connecticut Trolley Museum                                 34.40587
# Shenipsit State Forest                                    25.805208
# University of Connecticut                                 19.232202
# Patriots Park                                             22.882345
# Wadsworth Falls State Park                                47.890099
# Hubbard Park                                              54.172349
# Wharton Brook State Park                                   58.74756
# Yale University                                           66.793284
# Sleeping Giant State Park                                 61.535755
# Boothe Memorial Park and Museum                           77.913203
# Seaside Park                                              84.273505
# The Maritime Aquarium                                      96.27661
# Stamford Museum & Nature Center                          100.820276
# Bruce Museum                                             108.298699
# Westport Country Playhouse                                91.995695
# Fairfield Museum and History Center                       87.628636
# Pequonnock River Trail                                    80.312762
# Silver Sands State Park                                   77.717474
# Fort Trumbull State Park                                  40.632265
# Mystic Seaport Museum                                     38.452949
# Mohegan Park                                               26.71389
# Rotary Park & Bandstand                                         0.0
# Windham Textile & History Museum                          20.822416
# Kettletown State Park                                     74.963849
# Tarrywile Park & Mansion                                  87.978657
# Lover's Leap State Park                                   81.614866
# Burr Pond State Park                                      61.009079
# Lake Compounce                                            55.619829
# Hill-Stead Museum                                          48.84115
#
# Locations                                   Windham Textile & History Museum  \
# Locations
# Connecticut State Capitol                                          24.910038
# Pratt & Whitney Stadium at Rentschler Field                        21.610488
# Talcott Mountain State Park                                        31.431509
# New England Air Museum                                             29.933396
# Phelps-Hatheway House & Garden                                     29.612282
# Connecticut Trolley Museum                                         24.331737
# Shenipsit State Forest                                             20.213876
# University of Connecticut                                           7.130304
# Patriots Park                                                       6.503458
# Wadsworth Falls State Park                                         27.623564
# Hubbard Park                                                       34.521822
# Wharton Brook State Park                                           38.236175
# Yale University                                                    46.083365
# Sleeping Giant State Park                                          41.142667
# Boothe Memorial Park and Museum                                    57.257852
# Seaside Park                                                       63.564039
# The Maritime Aquarium                                              75.692316
# Stamford Museum & Nature Center                                    80.456165
# Bruce Museum                                                       87.770232
# Westport Country Playhouse                                          71.42854
# Fairfield Museum and History Center                                 66.94364
# Pequonnock River Trail                                             60.221693
# Silver Sands State Park                                            56.958746
# Fort Trumbull State Park                                           25.968455
# Mystic Seaport Museum                                              27.197209
# Mohegan Park                                                       13.317111
# Rotary Park & Bandstand                                            20.822416
# Windham Textile & History Museum                                         0.0
# Kettletown State Park                                              55.330165
# Tarrywile Park & Mansion                                            68.55914
# Lover's Leap State Park                                            63.363884
# Burr Pond State Park                                               47.110882
# Lake Compounce                                                     37.406142
# Hill-Stead Museum                                                  31.801554
#
# Locations                                   Kettletown State Park  \
# Locations
# Connecticut State Capitol                               35.665304
# Pratt & Whitney Stadium at Rentschler Field             38.049175
# Talcott Mountain State Park                             35.383485
# New England Air Museum                                  44.649313
# Phelps-Hatheway House & Garden                          47.652598
# Connecticut Trolley Museum                              47.290921
# Shenipsit State Forest                                   55.27367
# University of Connecticut                                55.77718
# Patriots Park                                           52.082138
# Wadsworth Falls State Park                              27.934675
# Hubbard Park                                            20.844998
# Wharton Brook State Park                                19.039335
# Yale University                                         16.530154
# Sleeping Giant State Park                               15.845752
# Boothe Memorial Park and Museum                         14.138123
# Seaside Park                                            18.350614
# The Maritime Aquarium                                   25.074476
# Stamford Museum & Nature Center                         27.342132
# Bruce Museum                                            35.589154
# Westport Country Playhouse                              21.181421
# Fairfield Museum and History Center                      19.87884
# Pequonnock River Trail                                   7.112902
# Silver Sands State Park                                 17.191806
# Fort Trumbull State Park                                58.027402
# Mystic Seaport Museum                                   64.612223
# Mohegan Park                                            59.562385
# Rotary Park & Bandstand                                 74.963849
# Windham Textile & History Museum                        55.330165
# Kettletown State Park                                         0.0
# Tarrywile Park & Mansion                                13.305249
# Lover's Leap State Park                                 13.283974
# Burr Pond State Park                                     31.13395
# Lake Compounce                                          20.749427
# Hill-Stead Museum                                       28.448076
#
# Locations                                   Tarrywile Park & Mansion  \
# Locations
# Connecticut State Capitol                                  47.929578
# Pratt & Whitney Stadium at Rentschler Field                50.558272
# Talcott Mountain State Park                                46.517208
# New England Air Museum                                     55.562933
# Phelps-Hatheway House & Garden                             58.573104
# Connecticut Trolley Museum                                 58.919391
# Shenipsit State Forest                                     67.321178
# University of Connecticut                                  68.754334
# Patriots Park                                              65.121358
# Wadsworth Falls State Park                                 41.236093
# Hubbard Park                                               34.038248
# Wharton Brook State Park                                   32.092609
# Yale University                                            27.904255
# Sleeping Giant State Park                                  28.880456
# Boothe Memorial Park and Museum                            20.435024
# Seaside Park                                               20.385422
# The Maritime Aquarium                                      19.306262
# Stamford Museum & Nature Center                            18.153839
# Bruce Museum                                               26.376253
# Westport Country Playhouse                                 17.170181
# Fairfield Museum and History Center                        19.575541
# Pequonnock River Trail                                     11.035983
# Silver Sands State Park                                    23.533752
# Fort Trumbull State Park                                    70.70821
# Mystic Seaport Museum                                      77.384308
# Mohegan Park                                               72.812068
# Rotary Park & Bandstand                                    87.978657
# Windham Textile & History Museum                            68.55914
# Kettletown State Park                                      13.305249
# Tarrywile Park & Mansion                                         0.0
# Lover's Leap State Park                                    11.499626
# Burr Pond State Park                                       38.664395
# Lake Compounce                                             32.866298
# Hill-Stead Museum                                          40.389838
#
# Locations                                   Lover's Leap State Park  \
# Locations
# Connecticut State Capitol                                 40.582972
# Pratt & Whitney Stadium at Rentschler Field               43.554294
# Talcott Mountain State Park                               37.805346
# New England Air Museum                                    46.413644
# Phelps-Hatheway House & Garden                             49.37386
# Connecticut Trolley Museum                                50.433409
# Shenipsit State Forest                                    59.229245
# University of Connecticut                                 62.479506
# Patriots Park                                              59.10451
# Wadsworth Falls State Park                                37.473439
# Hubbard Park                                              29.688539
# Wharton Brook State Park                                  30.732539
# Yale University                                           29.712078
# Sleeping Giant State Park                                 27.748825
# Boothe Memorial Park and Museum                           26.324864
# Seaside Park                                              28.710645
# The Maritime Aquarium                                     30.493828
# Stamford Museum & Nature Center                            29.63451
# Bruce Museum                                              37.789603
# Westport Country Playhouse                                27.814956
# Fairfield Museum and History Center                       28.952372
# Pequonnock River Trail                                    16.826055
# Silver Sands State Park                                   29.552555
# Fort Trumbull State Park                                  69.676218
# Mystic Seaport Museum                                     76.054872
# Mohegan Park                                              69.527733
# Rotary Park & Bandstand                                   81.614866
# Windham Textile & History Museum                          63.363884
# Kettletown State Park                                     13.283974
# Tarrywile Park & Mansion                                  11.499626
# Lover's Leap State Park                                         0.0
# Burr Pond State Park                                      27.899607
# Lake Compounce                                            26.077891
# Hill-Stead Museum                                         32.867453
#
# Locations                                   Burr Pond State Park  \
# Locations
# Connecticut State Capitol                              22.414253
# Pratt & Whitney Stadium at Rentschler Field            25.632739
# Talcott Mountain State Park                            15.752389
# New England Air Museum                                 21.347877
# Phelps-Hatheway House & Garden                         23.913329
# Connecticut Trolley Museum                             26.790687
# Shenipsit State Forest                                 35.829887
# University of Connecticut                              43.494408
# Patriots Park                                          41.196205
# Wadsworth Falls State Park                             31.178478
# Hubbard Park                                           25.894224
# Wharton Brook State Park                               33.452558
# Yale University                                        39.250006
# Sleeping Giant State Park                              32.598981
# Boothe Memorial Park and Museum                        43.853344
# Seaside Park                                           49.174866
# The Maritime Aquarium                                  55.695583
# Stamford Museum & Nature Center                        56.493564
# Bruce Museum                                           64.849982
# Westport Country Playhouse                             52.080585
# Fairfield Museum and History Center                    50.983981
# Pequonnock River Trail                                 38.173692
# Silver Sands State Park                                46.266364
# Fort Trumbull State Park                               63.232979
# Mystic Seaport Museum                                  68.203365
# Mohegan Park                                           57.480688
# Rotary Park & Bandstand                                61.009079
# Windham Textile & History Museum                       47.110882
# Kettletown State Park                                   31.13395
# Tarrywile Park & Mansion                               38.664395
# Lover's Leap State Park                                27.899607
# Burr Pond State Park                                         0.0
# Lake Compounce                                         18.125546
# Hill-Stead Museum                                       17.38903
#
# Locations                                   Lake Compounce Hill-Stead Museum
# Locations
# Connecticut State Capitol                        15.066512           7.71563
# Pratt & Whitney Stadium at Rentschler Field       17.74258          10.76093
# Talcott Mountain State Park                      15.064613          7.980657
# New England Air Museum                            24.31004         16.937335
# Phelps-Hatheway House & Garden                   27.262282         19.816682
# Connecticut Trolley Museum                       26.556763         18.858902
# Shenipsit State Forest                           34.577182         26.945393
# University of Connecticut                        36.435284         29.863716
# Patriots Park                                    33.027642         26.743396
# Wadsworth Falls State Park                       14.196553         14.550841
# Hubbard Park                                      7.799715         12.021779
# Wharton Brook State Park                         15.523718         20.512715
# Yale University                                  22.392728         28.493615
# Sleeping Giant State Park                        15.219215         21.175062
# Boothe Memorial Park and Museum                  29.625963          36.79241
# Seaside Park                                     35.833838          43.13136
# The Maritime Aquarium                            45.239556         52.868338
# Stamford Museum & Nature Center                  48.062861          55.76322
# Bruce Museum                                     56.248811         63.942427
# Westport Country Playhouse                       41.094836         48.697298
# Fairfield Museum and History Center              38.423432         45.844706
# Pequonnock River Trail                           27.366626         35.047394
# Silver Sands State Park                          31.315143         38.219189
# Fort Trumbull State Park                         47.652371         45.850089
# Mystic Seaport Museum                            53.344849         50.916716
# Mohegan Park                                     44.746447         40.783094
# Rotary Park & Bandstand                          55.619829          48.84115
# Windham Textile & History Museum                 37.406142         31.801554
# Kettletown State Park                            20.749427         28.448076
# Tarrywile Park & Mansion                         32.866298         40.389838
# Lover's Leap State Park                          26.077891         32.867453
# Burr Pond State Park                             18.125546          17.38903
# Lake Compounce                                         0.0          7.700823
# Hill-Stead Museum                                 7.700823               0.0
#
# [34 rows x 34 columns]

# %%
def calculate_battery_discharge_rate(distance, speed, Cd, A, Crr, m, g, rho, lambda_, alpha):
    # Calculate the battery discharge rate based on vehicle parameters
    F_drag = 0.5 * rho * Cd * A * (speed ** 2)
    F_rolling = Crr * m * g
    F_total = F_drag + F_rolling
    P_total = F_total * speed
    P_regen = alpha * P_total
    P_net = P_total - P_regen
    energy_consumed = P_net * (distance / speed)
    discharge_rate = energy_consumed / 3600  # Convert from Joules to kWh
    return discharge_rate

# %%
def find_nearest_city(current_tour, location_distance_matrix, places_df, qualifying_distance_matrix):
    print("Finding nearest city...")
    nearest_city = None
    min_distance = float('inf')

    for location in places_df["Locations"]:
        if location not in current_tour:
            if location in qualifying_distance_matrix.columns:
                for station in qualifying_distance_matrix.index:
                    distance = qualifying_distance_matrix.at[station, location]
                    if distance < min_distance:
                        nearest_city = location
                        min_distance = distance
            else:
                for city in current_tour:
                    if city in location_distance_matrix.index:
                        if location_distance_matrix.at[city, location] < min_distance:
                            nearest_city = location
                            min_distance = location_distance_matrix.at[city, location]
                    else:
                        print(f"City '{city}' not found in the location distance matrix. Skipping distance calculation.")

    print("Nearest city found:", nearest_city)
    return nearest_city

# %%
def find_nearest_charging_station(current_station, qualifying_distance_matrix, location_distance_matrix, places_df):
    print("Finding nearest charging station...")
    nearest_station = None
    min_distance = float('inf')

    if current_station in qualifying_distance_matrix.columns:
        for station in qualifying_distance_matrix.index:
            distance = qualifying_distance_matrix.at[station, current_station]
            if distance < min_distance:
                nearest_station = station
                min_distance = distance
    else:
        if current_station in location_distance_matrix.index:
            for location in places_df["Locations"]:
                if location in qualifying_distance_matrix.columns:
                    distance = location_distance_matrix.at[current_station, location]
                    if distance < min_distance:
                        nearest_station = location
                        min_distance = distance
        else:
            print(f"Location '{current_station}' not found in either distance matrix.")

    if nearest_station is not None:
        print("Nearest charging station found:", nearest_station)
    else:
        print("No suitable charging station found.")

    return nearest_station

# %%
def insert_nearest_city(nearest_city, current_tour, location_distance_matrix, qualifying_distance_matrix):
    print("Inserting nearest city...")
    best_insertion = None
    min_increase = float('inf')
    
    for i in range(len(current_tour)):
        if current_tour[i] in location_distance_matrix.index:
            prev_city = current_tour[i]
        else:
            prev_city = current_tour[i-1]
        
        next_i = (i + 1) % len(current_tour)
        
        if current_tour[next_i] in location_distance_matrix.columns:
            next_city = current_tour[next_i]
            increase = location_distance_matrix.at[prev_city, nearest_city] + location_distance_matrix.at[nearest_city, next_city] - location_distance_matrix.at[prev_city, next_city]
        else:
            next_city = current_tour[0]
            if current_tour[i] in qualifying_distance_matrix.index and nearest_city in qualifying_distance_matrix.columns:
                increase = qualifying_distance_matrix.at[current_tour[i], nearest_city]
            else:
                increase = float('inf')
            
            if next_city in location_distance_matrix.columns:
                increase += location_distance_matrix.at[nearest_city, next_city]
            else:
                increase = float('inf')
            
            if current_tour[i] in qualifying_distance_matrix.index and next_city in qualifying_distance_matrix.columns:
                increase -= qualifying_distance_matrix.at[current_tour[i], next_city]
            else:
                increase = float('inf')
        
        if increase < min_increase:
            min_increase = increase
            best_insertion = i + 1
    
    current_tour.insert(best_insertion, nearest_city)
    print("Nearest city inserted into the tour.")

# %%
def nearest_insertion_algorithm(location_distance_matrix, qualifying_distance_matrix, places_df, charging_stations_df, source_city, vehicle_params, charging_params, iteration_count=0):
    current_tour = [source_city]
    visited_cities = set(current_tour)
    current_charge = charging_params['max_charge']
    total_distance = 0

    Cd, A, Crr, m, g, rho, lambda_, alpha = vehicle_params.values()
    level2_charge_rate, dc_fast_charge_rate, min_charge, max_charge = charging_params.values()

    while len(visited_cities) < len(places_df):
        if current_tour[-1] in places_df["Locations"].values:
            nearest_city = find_nearest_city(current_tour, location_distance_matrix, places_df, qualifying_distance_matrix)
            distance_to_next_city = location_distance_matrix.at[current_tour[-1], nearest_city]
        else:
            nearest_city = find_nearest_city(current_tour[:-1], location_distance_matrix, places_df, qualifying_distance_matrix)
            distance_to_next_city = qualifying_distance_matrix.at[current_tour[-1], nearest_city]

        speed = 50  # Assume an average speed of  (50 km/h)
        discharge_rate = calculate_battery_discharge_rate(distance_to_next_city, speed, Cd, A, Crr, m, g, rho, lambda_, alpha)
        required_charge_to_next_city = discharge_rate

        if current_charge - required_charge_to_next_city >= min_charge:
            insert_nearest_city(nearest_city, current_tour, location_distance_matrix, qualifying_distance_matrix)
            visited_cities.add(nearest_city)
            current_charge -= required_charge_to_next_city
            total_distance += distance_to_next_city
        else:
            nearest_station = find_nearest_charging_station(current_tour[-1], qualifying_distance_matrix, location_distance_matrix, places_df)

            if nearest_station is not None:
                distance_to_station = qualifying_distance_matrix.at[nearest_station, current_tour[-1]]
                discharge_rate_to_station = calculate_battery_discharge_rate(distance_to_station, speed, Cd, A, Crr, m, g, rho, lambda_, alpha)
                required_charge_to_station = discharge_rate_to_station

                if current_charge - required_charge_to_station >= min_charge:
                    current_tour.append(nearest_station)
                    if 'DC Fast' in nearest_station:
                        charge_rate = dc_fast_charge_rate
                    else:
                        charge_rate = level2_charge_rate
                    charging_time = (max_charge - current_charge) / charge_rate
                    current_charge = max_charge
                    total_distance += distance_to_station
                else:
                    print(f"Impossible route encountered after {iteration_count} iterations. Restarting with a different source city.")
                    new_source_city = places_df.loc[places_df["Locations"] != source_city, "Locations"].sample().values[0]
                    return nearest_insertion_algorithm(location_distance_matrix, qualifying_distance_matrix, places_df, charging_stations_df, new_source_city, vehicle_params, charging_params, iteration_count + 1)
            else:
                print(f"Impossible route encountered after {iteration_count} iterations. Restarting with a different source city.")
                new_source_city = places_df.loc[places_df["Locations"] != source_city, "Locations"].sample().values[0]
                return nearest_insertion_algorithm(location_distance_matrix, qualifying_distance_matrix, places_df, charging_stations_df, new_source_city, vehicle_params, charging_params, iteration_count + 1)

    print(f"Nearest Insertion Algorithm completed after {iteration_count} iterations.")
    print("Tour:")
    for city in current_tour:
        if city in places_df["Locations"].values:
            print(f"Nearest City: {city}")
        else:
            print(f"Nearest Charging Station: {city}")


    if all(location in current_tour for location in places_df["Locations"]):
        print("Feasible route found.")
        print("Best Cost (Total Distance):", total_distance)
        return current_tour, total_distance
    else:
        print(f"Impossible route encountered after {iteration_count} iterations. Restarting with a different source city.")
        new_source_city = places_df.loc[places_df["Locations"] != source_city, "Locations"].sample().values[0]
        return nearest_insertion_algorithm(location_distance_matrix, qualifying_distance_matrix, places_df, charging_stations_df, new_source_city, vehicle_params, charging_params, iteration_count + 1)
vehicle_params = {
    'Cd': 0.3,
    'A': 2.2,
    'Crr': 0.01,
    'm': 1500,
    'g': 9.81,
    'rho': 1.225,
    'lambda_': 0.80,
    'alpha': 0.25
}

charging_params = {
    'level2_charge_rate': 7,
    'dc_fast_charge_rate': 50,
    'min_charge': 20,  # 20% of 100 kWh battery capacity
    'max_charge': 90  # 90% of 100 kWh battery capacity
}

# %% [markdown]
# These values represent various parameters and coefficients used in vehicle dynamics and aerodynamics calculations. Let's go through each one:
#
# 1. 'Cd': 0.3 stands for the coefficient of drag, which is a dimensionless quantity that represents the aerodynamic drag of an object.
# 2. 'A': 2.2 represents the frontal area of the vehicle in square meters (m^2).
# 3. 'Crr': 0.01 stands for the coefficient of rolling resistance, which is a dimensionless quantity that represents the resistance to motion of the vehicle due to friction between the tires and the road surface.
# 4. 'm': 1500 represents the mass of the vehicle in kilograms (kg).
# 5. 'g': 9.81 represents the acceleration due to gravity in meters per second squared (m/s^2).
# 6. 'rho': 1.225 represents the density of air in kilograms per cubic meter (kg/m^3).
# 7. 'lambda_': 0.80 is a coefficient related to the efficiency of the vehicle's powertrain.
# 8. 'alpha': 0.25 is a coefficient related to the road gradient or slope.

# %%
source_city = "Yale University"

while True:
    print("Starting tour with source city:", source_city)
    tour, total_distance = nearest_insertion_algorithm(location_distance_matrix, distance_matrix, places_df, charging_stations_df, source_city, vehicle_params, charging_params)

    if tour is not None:
        print("Tour:")
        for city in tour:
            if city in places_df["Locations"].values:
                print(f"Nearest City: {city}")
            else:
                print(f"Nearest Charging Station: {city}")
        print("Best Cost (Total Distance):", total_distance)
        break
    else:
        source_city = places_df.loc[places_df["Locations"] != source_city, "Locations"].sample().values[0]
# Out:
# Starting tour with source city: Yale University
# Finding nearest city...
# Nearest city found: Connecticut State Capitol
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: The Maritime Aquarium
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Bruce Museum
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Rotary Park & Bandstand
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: University of Connecticut
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Westport Country Playhouse
# Finding nearest charging station...
# Nearest charging station found: Cargill Chevrolet, 23 Livery St
# Finding nearest city...
# Nearest city found: Westport Country Playhouse
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Windham Textile & History Museum
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Fairfield Museum and History Center
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Wharton Brook State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Burr Pond State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Fort Trumbull State Park
# Finding nearest charging station...
# Nearest charging station found: JAGLRNH, 521 Washington Ave
# Finding nearest city...
# Nearest city found: Fort Trumbull State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Mystic Seaport Museum
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Patriots Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Silver Sands State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Seaside Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Lover's Leap State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Tarrywile Park & Mansion
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Stamford Museum & Nature Center
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Pratt & Whitney Stadium at Rentschler Field
# Finding nearest charging station...
# Location 'JAGLRNH, 521 Washington Ave' not found in either distance matrix.
# No suitable charging station found.
# Impossible route encountered after 0 iterations. Restarting with a different source city.
# Finding nearest city...
# Nearest city found: Connecticut State Capitol
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: The Maritime Aquarium
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Rotary Park & Bandstand
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: University of Connecticut
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Westport Country Playhouse
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Windham Textile & History Museum
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Fairfield Museum and History Center
# Finding nearest charging station...
# Nearest charging station found: Connecticut State Capitol, 210 Capitol Ave
# Finding nearest city...
# Nearest city found: Fairfield Museum and History Center
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Yale University
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Wharton Brook State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Burr Pond State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Fort Trumbull State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Mystic Seaport Museum
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Patriots Park
# Finding nearest charging station...
# Nearest charging station found: WESTLODGE, 811 Burr Mountain Rd
# Finding nearest city...
# Nearest city found: Patriots Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Silver Sands State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Seaside Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Lover's Leap State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Tarrywile Park & Mansion
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Stamford Museum & Nature Center
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Pratt & Whitney Stadium at Rentschler Field
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Mohegan Park
# Finding nearest charging station...
# Nearest charging station found: Grand Central Fashion Plaza Shopping Center - Tesla Supercharger, 1145 High Ridge Rd
# Finding nearest city...
# Nearest city found: Mohegan Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: New England Air Museum
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Wadsworth Falls State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Hill-Stead Museum
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Hubbard Park
# Finding nearest charging station...
# Location 'Grand Central Fashion Plaza Shopping Center - Tesla Supercharger, 1145 High Ridge Rd' not found in either distance matrix.
# No suitable charging station found.
# Impossible route encountered after 1 iterations. Restarting with a different source city.
# Finding nearest city...
# Nearest city found: Connecticut State Capitol
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: The Maritime Aquarium
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Bruce Museum
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Rotary Park & Bandstand
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: University of Connecticut
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Westport Country Playhouse
# Finding nearest charging station...
# Nearest charging station found: Cargill Chevrolet, 23 Livery St
# Finding nearest city...
# Nearest city found: Westport Country Playhouse
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Windham Textile & History Museum
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Fairfield Museum and History Center
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Yale University
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Wharton Brook State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Burr Pond State Park
# Finding nearest charging station...
# Nearest charging station found: Windham Municipal Parking Lot, 48 Church St
# Finding nearest city...
# Nearest city found: Burr Pond State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Fort Trumbull State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Mystic Seaport Museum
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Patriots Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Silver Sands State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Seaside Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Lover's Leap State Park
# Finding nearest charging station...
# Nearest charging station found: Propark - Water Street Garage, 161 Water St
# Finding nearest city...
# Nearest city found: Lover's Leap State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Tarrywile Park & Mansion
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Stamford Museum & Nature Center
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Pratt & Whitney Stadium at Rentschler Field
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Mohegan Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: New England Air Museum
# Finding nearest charging station...
# Location 'Propark - Water Street Garage, 161 Water St' not found in either distance matrix.
# No suitable charging station found.
# Impossible route encountered after 2 iterations. Restarting with a different source city.
# Finding nearest city...
# Nearest city found: Connecticut State Capitol
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: The Maritime Aquarium
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Bruce Museum
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Rotary Park & Bandstand
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: University of Connecticut
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Westport Country Playhouse
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Windham Textile & History Museum
# Finding nearest charging station...
# Nearest charging station found: University of Connecticut - South Parking Garage, 505 Jim Calhoun Way
# Finding nearest city...
# Nearest city found: Windham Textile & History Museum
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Fairfield Museum and History Center
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Yale University
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Wharton Brook State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Burr Pond State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Fort Trumbull State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Mystic Seaport Museum
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Silver Sands State Park
# Finding nearest charging station...
# Location 'University of Connecticut - South Parking Garage, 505 Jim Calhoun Way' not found in either distance matrix.
# No suitable charging station found.
# Impossible route encountered after 3 iterations. Restarting with a different source city.
# Finding nearest city...
# Nearest city found: Connecticut State Capitol
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: The Maritime Aquarium
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Bruce Museum
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Rotary Park & Bandstand
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: University of Connecticut
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Westport Country Playhouse
# Finding nearest charging station...
# Nearest charging station found: Cargill Chevrolet, 23 Livery St
# Finding nearest city...
# Nearest city found: Westport Country Playhouse
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Windham Textile & History Museum
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Fairfield Museum and History Center
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Yale University
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Wharton Brook State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Burr Pond State Park
# Finding nearest charging station...
# Nearest charging station found: Windham Municipal Parking Lot, 48 Church St
# Finding nearest city...
# Nearest city found: Burr Pond State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Fort Trumbull State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Mystic Seaport Museum
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Patriots Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Silver Sands State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Seaside Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Lover's Leap State Park
# Finding nearest charging station...
# Nearest charging station found: Propark - Water Street Garage, 161 Water St
# Finding nearest city...
# Nearest city found: Lover's Leap State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Tarrywile Park & Mansion
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Stamford Museum & Nature Center
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Pratt & Whitney Stadium at Rentschler Field
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Mohegan Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: New England Air Museum
# Finding nearest charging station...
# Location 'Propark - Water Street Garage, 161 Water St' not found in either distance matrix.
# No suitable charging station found.
# Impossible route encountered after 4 iterations. Restarting with a different source city.
# Finding nearest city...
# Nearest city found: Connecticut State Capitol
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: The Maritime Aquarium
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Bruce Museum
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Rotary Park & Bandstand
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: University of Connecticut
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Westport Country Playhouse
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Windham Textile & History Museum
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Fairfield Museum and History Center
# Finding nearest charging station...
# Nearest charging station found: Connecticut State Capitol, 210 Capitol Ave
# Finding nearest city...
# Nearest city found: Fairfield Museum and History Center
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Yale University
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Wharton Brook State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Burr Pond State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Fort Trumbull State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Mystic Seaport Museum
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Patriots Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Silver Sands State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Seaside Park
# Finding nearest charging station...
# Location 'Connecticut State Capitol, 210 Capitol Ave' not found in either distance matrix.
# No suitable charging station found.
# Impossible route encountered after 5 iterations. Restarting with a different source city.
# Finding nearest city...
# Nearest city found: Connecticut State Capitol
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: The Maritime Aquarium
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Bruce Museum
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Rotary Park & Bandstand
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: University of Connecticut
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Westport Country Playhouse
# Finding nearest charging station...
# Nearest charging station found: Connecticut State Capitol, 210 Capitol Ave
# Finding nearest city...
# Nearest city found: Westport Country Playhouse
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Windham Textile & History Museum
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Fairfield Museum and History Center
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Yale University
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Wharton Brook State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Burr Pond State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Fort Trumbull State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Mystic Seaport Museum
# Finding nearest charging station...
# Nearest charging station found: WESTLODGE, 811 Burr Mountain Rd
# Finding nearest city...
# Nearest city found: Mystic Seaport Museum
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Patriots Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Silver Sands State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Seaside Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Lover's Leap State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Stamford Museum & Nature Center
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Pratt & Whitney Stadium at Rentschler Field
# Finding nearest charging station...
# Nearest charging station found: Fairfield Plaza, 116 Danbury Rd
# Finding nearest city...
# Nearest city found: Pratt & Whitney Stadium at Rentschler Field
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Mohegan Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: New England Air Museum
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Wadsworth Falls State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Hill-Stead Museum
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Hubbard Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Boothe Memorial Park and Museum
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Lake Compounce
# Finding nearest charging station...
# Location 'Fairfield Plaza, 116 Danbury Rd' not found in either distance matrix.
# No suitable charging station found.
# Impossible route encountered after 6 iterations. Restarting with a different source city.
# Finding nearest city...
# Nearest city found: Connecticut State Capitol
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: The Maritime Aquarium
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Rotary Park & Bandstand
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: University of Connecticut
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Westport Country Playhouse
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Windham Textile & History Museum
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Fairfield Museum and History Center
# Finding nearest charging station...
# Nearest charging station found: Connecticut State Capitol, 210 Capitol Ave
# Finding nearest city...
# Nearest city found: Fairfield Museum and History Center
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Yale University
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Wharton Brook State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Burr Pond State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Fort Trumbull State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Mystic Seaport Museum
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Patriots Park
# Finding nearest charging station...
# Nearest charging station found: WESTLODGE, 811 Burr Mountain Rd
# Finding nearest city...
# Nearest city found: Patriots Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Silver Sands State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Seaside Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Lover's Leap State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Tarrywile Park & Mansion
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Stamford Museum & Nature Center
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Pratt & Whitney Stadium at Rentschler Field
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Mohegan Park
# Finding nearest charging station...
# Nearest charging station found: Grand Central Fashion Plaza Shopping Center - Tesla Supercharger, 1145 High Ridge Rd
# Finding nearest city...
# Nearest city found: Mohegan Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: New England Air Museum
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Wadsworth Falls State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Hill-Stead Museum
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Hubbard Park
# Finding nearest charging station...
# Location 'Grand Central Fashion Plaza Shopping Center - Tesla Supercharger, 1145 High Ridge Rd' not found in either distance matrix.
# No suitable charging station found.
# Impossible route encountered after 7 iterations. Restarting with a different source city.
# Finding nearest city...
# Nearest city found: Connecticut State Capitol
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: The Maritime Aquarium
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Bruce Museum
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Rotary Park & Bandstand
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: University of Connecticut
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Westport Country Playhouse
# Finding nearest charging station...
# Nearest charging station found: Cargill Chevrolet, 23 Livery St
# Finding nearest city...
# Nearest city found: Westport Country Playhouse
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Windham Textile & History Museum
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Fairfield Museum and History Center
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Yale University
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Wharton Brook State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Burr Pond State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Fort Trumbull State Park
# Finding nearest charging station...
# Nearest charging station found: Grove Street Parking Garage, 65 Grove Street
# Finding nearest city...
# Nearest city found: Fort Trumbull State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Mystic Seaport Museum
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Patriots Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Seaside Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Lover's Leap State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Tarrywile Park & Mansion
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Stamford Museum & Nature Center
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Pratt & Whitney Stadium at Rentschler Field
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Mohegan Park
# Finding nearest charging station...
# Location 'Grove Street Parking Garage, 65 Grove Street' not found in either distance matrix.
# No suitable charging station found.
# Impossible route encountered after 8 iterations. Restarting with a different source city.
# Finding nearest city...
# Nearest city found: Connecticut State Capitol
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: The Maritime Aquarium
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Bruce Museum
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Rotary Park & Bandstand
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: University of Connecticut
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Westport Country Playhouse
# Finding nearest charging station...
# Nearest charging station found: Cargill Chevrolet, 23 Livery St
# Finding nearest city...
# Nearest city found: Westport Country Playhouse
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Windham Textile & History Museum
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Fairfield Museum and History Center
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Yale University
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Wharton Brook State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Burr Pond State Park
# Finding nearest charging station...
# Nearest charging station found: JAGLRNH, 521 Washington Ave
# Finding nearest city...
# Nearest city found: Burr Pond State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Fort Trumbull State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Mystic Seaport Museum
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Patriots Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Silver Sands State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Seaside Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Lover's Leap State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Tarrywile Park & Mansion
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Stamford Museum & Nature Center
# Finding nearest charging station...
# Location 'JAGLRNH, 521 Washington Ave' not found in either distance matrix.
# No suitable charging station found.
# Impossible route encountered after 9 iterations. Restarting with a different source city.
# Finding nearest city...
# Nearest city found: Connecticut State Capitol
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: The Maritime Aquarium
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Bruce Museum
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Rotary Park & Bandstand
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: University of Connecticut
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Westport Country Playhouse
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Windham Textile & History Museum
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Fairfield Museum and History Center
# Finding nearest charging station...
# Nearest charging station found: Connecticut State Capitol, 210 Capitol Ave
# Finding nearest city...
# Nearest city found: Fairfield Museum and History Center
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Yale University
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Wharton Brook State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Burr Pond State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Fort Trumbull State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Mystic Seaport Museum
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Patriots Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Silver Sands State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Seaside Park
# Finding nearest charging station...
# Location 'Connecticut State Capitol, 210 Capitol Ave' not found in either distance matrix.
# No suitable charging station found.
# Impossible route encountered after 10 iterations. Restarting with a different source city.
# Finding nearest city...
# Nearest city found: Connecticut State Capitol
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: The Maritime Aquarium
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Bruce Museum
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Rotary Park & Bandstand
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: University of Connecticut
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Westport Country Playhouse
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Windham Textile & History Museum
# Finding nearest charging station...
# Nearest charging station found: University of Connecticut - South Parking Garage, 505 Jim Calhoun Way
# Finding nearest city...
# Nearest city found: Windham Textile & History Museum
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Fairfield Museum and History Center
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Yale University
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Wharton Brook State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Burr Pond State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Fort Trumbull State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Mystic Seaport Museum
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Silver Sands State Park
# Finding nearest charging station...
# Location 'University of Connecticut - South Parking Garage, 505 Jim Calhoun Way' not found in either distance matrix.
# No suitable charging station found.
# Impossible route encountered after 11 iterations. Restarting with a different source city.
# Finding nearest city...
# Nearest city found: Connecticut State Capitol
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: The Maritime Aquarium
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Rotary Park & Bandstand
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: University of Connecticut
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Westport Country Playhouse
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Windham Textile & History Museum
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Fairfield Museum and History Center
# Finding nearest charging station...
# Nearest charging station found: Connecticut State Capitol, 210 Capitol Ave
# Finding nearest city...
# Nearest city found: Fairfield Museum and History Center
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Yale University
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Wharton Brook State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Burr Pond State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Fort Trumbull State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Mystic Seaport Museum
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Patriots Park
# Finding nearest charging station...
# Nearest charging station found: WESTLODGE, 811 Burr Mountain Rd
# Finding nearest city...
# Nearest city found: Patriots Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Silver Sands State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Seaside Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Lover's Leap State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Tarrywile Park & Mansion
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Stamford Museum & Nature Center
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Pratt & Whitney Stadium at Rentschler Field
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Mohegan Park
# Finding nearest charging station...
# Nearest charging station found: Grand Central Fashion Plaza Shopping Center - Tesla Supercharger, 1145 High Ridge Rd
# Finding nearest city...
# Nearest city found: Mohegan Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: New England Air Museum
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Wadsworth Falls State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Hill-Stead Museum
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Hubbard Park
# Finding nearest charging station...
# Location 'Grand Central Fashion Plaza Shopping Center - Tesla Supercharger, 1145 High Ridge Rd' not found in either distance matrix.
# No suitable charging station found.
# Impossible route encountered after 12 iterations. Restarting with a different source city.
# Finding nearest city...
# Nearest city found: Connecticut State Capitol
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: The Maritime Aquarium
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Bruce Museum
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Rotary Park & Bandstand
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: University of Connecticut
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Westport Country Playhouse
# Finding nearest charging station...
# Nearest charging station found: Cargill Chevrolet, 23 Livery St
# Finding nearest city...
# Nearest city found: Westport Country Playhouse
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Windham Textile & History Museum
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Fairfield Museum and History Center
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Yale University
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Burr Pond State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Fort Trumbull State Park
# Finding nearest charging station...
# Nearest charging station found: Windham Municipal Parking Lot, 48 Church St
# Finding nearest city...
# Nearest city found: Fort Trumbull State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Mystic Seaport Museum
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Patriots Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Silver Sands State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Seaside Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Lover's Leap State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Tarrywile Park & Mansion
# Finding nearest charging station...
# Nearest charging station found: Propark - Water Street Garage, 161 Water St
# Finding nearest city...
# Nearest city found: Tarrywile Park & Mansion
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Stamford Museum & Nature Center
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Pratt & Whitney Stadium at Rentschler Field
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Mohegan Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: New England Air Museum
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Wadsworth Falls State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Hill-Stead Museum
# Finding nearest charging station...
# Nearest charging station found: Wesleyan University, 161 Cross St
# Finding nearest city...
# Nearest city found: Hill-Stead Museum
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Hubbard Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Boothe Memorial Park and Museum
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Lake Compounce
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Phelps-Hatheway House & Garden
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Sleeping Giant State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Talcott Mountain State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Kettletown State Park
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Connecticut Trolley Museum
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Shenipsit State Forest
# Inserting nearest city...
# Nearest city inserted into the tour.
# Finding nearest city...
# Nearest city found: Pequonnock River Trail
# Inserting nearest city...
# Nearest city inserted into the tour.
# Nearest Insertion Algorithm completed after 13 iterations.
# Tour:
# Nearest City: Wharton Brook State Park
# Nearest City: Sleeping Giant State Park
# Nearest City: Yale University
# Nearest City: Silver Sands State Park
# Nearest City: Boothe Memorial Park and Museum
# Nearest City: Seaside Park
# Nearest City: Fairfield Museum and History Center
# Nearest City: Westport Country Playhouse
# Nearest City: The Maritime Aquarium
# Nearest City: Bruce Museum
# Nearest City: Stamford Museum & Nature Center
# Nearest City: Tarrywile Park & Mansion
# Nearest City: Pequonnock River Trail
# Nearest City: Kettletown State Park
# Nearest City: Lover's Leap State Park
# Nearest City: Burr Pond State Park
# Nearest City: Connecticut Trolley Museum
# Nearest City: Phelps-Hatheway House & Garden
# Nearest City: New England Air Museum
# Nearest City: Talcott Mountain State Park
# Nearest City: Hill-Stead Museum
# Nearest City: Connecticut State Capitol
# Nearest City: Pratt & Whitney Stadium at Rentschler Field
# Nearest City: Shenipsit State Forest
# Nearest City: Patriots Park
# Nearest City: University of Connecticut
# Nearest City: Rotary Park & Bandstand
# Nearest Charging Station: Cargill Chevrolet, 23 Livery St
# Nearest City: Windham Textile & History Museum
# Nearest Charging Station: Windham Municipal Parking Lot, 48 Church St
# Nearest City: Mohegan Park
# Nearest City: Mystic Seaport Museum
# Nearest City: Fort Trumbull State Park
# Nearest Charging Station: Propark - Water Street Garage, 161 Water St
# Nearest City: Wadsworth Falls State Park
# Nearest Charging Station: Wesleyan University, 161 Cross St
# Nearest City: Lake Compounce
# Nearest City: Hubbard Park
# Feasible route found.
# Best Cost (Total Distance): 1250.4489881138427
# Tour:
# Nearest City: Wharton Brook State Park
# Nearest City: Sleeping Giant State Park
# Nearest City: Yale University
# Nearest City: Silver Sands State Park
# Nearest City: Boothe Memorial Park and Museum
# Nearest City: Seaside Park
# Nearest City: Fairfield Museum and History Center
# Nearest City: Westport Country Playhouse
# Nearest City: The Maritime Aquarium
# Nearest City: Bruce Museum
# Nearest City: Stamford Museum & Nature Center
# Nearest City: Tarrywile Park & Mansion
# Nearest City: Pequonnock River Trail
# Nearest City: Kettletown State Park
# Nearest City: Lover's Leap State Park
# Nearest City: Burr Pond State Park
# Nearest City: Connecticut Trolley Museum
# Nearest City: Phelps-Hatheway House & Garden
# Nearest City: New England Air Museum
# Nearest City: Talcott Mountain State Park
# Nearest City: Hill-Stead Museum
# Nearest City: Connecticut State Capitol
# Nearest City: Pratt & Whitney Stadium at Rentschler Field
# Nearest City: Shenipsit State Forest
# Nearest City: Patriots Park
# Nearest City: University of Connecticut
# Nearest City: Rotary Park & Bandstand
# Nearest Charging Station: Cargill Chevrolet, 23 Livery St
# Nearest City: Windham Textile & History Museum
# Nearest Charging Station: Windham Municipal Parking Lot, 48 Church St
# Nearest City: Mohegan Park
# Nearest City: Mystic Seaport Museum
# Nearest City: Fort Trumbull State Park
# Nearest Charging Station: Propark - Water Street Garage, 161 Water St
# Nearest City: Wadsworth Falls State Park
# Nearest Charging Station: Wesleyan University, 161 Cross St
# Nearest City: Lake Compounce
# Nearest City: Hubbard Park
# Best Cost (Total Distance): 1250.4489881138427

# %%
import folium


# Create a map centered on Connecticut
m = folium.Map(location=[41.6032, -73.0877], zoom_start=8)

# Create a feature group for markers
marker_group = folium.FeatureGroup(name='Markers')

# Add markers for each location in the tour
for location in tour:
    if location in places_df['Locations'].values:
        lat = places_df.loc[places_df['Locations'] == location, 'Latitude'].values[0]
        lon = places_df.loc[places_df['Locations'] == location, 'Longitude'].values[0]
        marker_group.add_child(folium.Marker([lat, lon], popup=location, icon=folium.Icon(color='blue')))
    elif location in charging_stations_df['Charging Stations'].values:
        lat = charging_stations_df.loc[charging_stations_df['Charging Stations'] == location, 'Latitude'].values[0]
        lon = charging_stations_df.loc[charging_stations_df['Charging Stations'] == location, 'Longitude'].values[0]
        marker_group.add_child(folium.Marker([lat, lon], popup=location, icon=folium.Icon(color='red')))
    else:
        print(f"Coordinates not found for location: {location}")

# Add a polyline for the tour path
# Combine the places and charging stations dataframes for easy lookup
combined_df = pd.concat([
    places_df[['Locations', 'Latitude', 'Longitude']].rename(columns={'Locations': 'Name'}),
    charging_stations_df[['Charging Stations', 'Latitude', 'Longitude']].rename(columns={'Charging Stations': 'Name'})
])

# Ensure the 'Name' column is of string type to avoid any potential matching issues
combined_df['Name'] = combined_df['Name'].astype(str)

# Use list comprehension to build the path based on the 'tour' list
path = [
    combined_df.loc[combined_df['Name'] == location, ['Latitude', 'Longitude']].values.flatten().tolist()
    for location in tour
    if combined_df['Name'].str.contains(location).any()
]

polyline_group = folium.FeatureGroup(name='Polylines')
polyline_group.add_child(folium.PolyLine(path, color='red', weight=2))

# Add feature groups to the map
m.add_child(marker_group)
m.add_child(polyline_group)

# Add layer control to the map
folium.LayerControl().add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_46f20a019b0a3fcbd3e4838d96b1fa83 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_46f20a019b0a3fcbd3e4838d96b1fa83&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_46f20a019b0a3fcbd3e4838d96b1fa83 = L.map(
#                 &quot;map_46f20a019b0a3fcbd3e4838d96b1fa83&quot;,
#                 {
#                     center: [41.6032, -73.0877],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_951faae447d4af79c8495650dfbea83e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_951faae447d4af79c8495650dfbea83e.addTo(map_46f20a019b0a3fcbd3e4838d96b1fa83);
#
#
#             var feature_group_d6fff0591577e133a711af7934919b6e = L.featureGroup(
#                 {}
#             );
#
#
#             var marker_89e6a3b785a81054f34b6eddce60c741 = L.marker(
#                 [41.4250948, -72.8376389],
#                 {}
#             ).addTo(feature_group_d6fff0591577e133a711af7934919b6e);
#
#
#             var icon_ac1ff92ed850fcb28f39cd9734b96934 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_89e6a3b785a81054f34b6eddce60c741.setIcon(icon_ac1ff92ed850fcb28f39cd9734b96934);
#
#
#         var popup_b612f4ec5dff7e1df6bcc723588ce912 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7662094da0e49b3c43e2327c557c805e = $(`&lt;div id=&quot;html_7662094da0e49b3c43e2327c557c805e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Wharton Brook State Park&lt;/div&gt;`)[0];
#                 popup_b612f4ec5dff7e1df6bcc723588ce912.setContent(html_7662094da0e49b3c43e2327c557c805e);
#
#
#
#         marker_89e6a3b785a81054f34b6eddce60c741.bindPopup(popup_b612f4ec5dff7e1df6bcc723588ce912)
#         ;
#
#
#
#
#             var marker_2c5a46410b94896eabc5ff52dd2c8020 = L.marker(
#                 [41.4209689, -72.8992361],
#                 {}
#             ).addTo(feature_group_d6fff0591577e133a711af7934919b6e);
#
#
#             var icon_707068385de5276aae98ad97999fa1bb = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2c5a46410b94896eabc5ff52dd2c8020.setIcon(icon_707068385de5276aae98ad97999fa1bb);
#
#
#         var popup_650dc7c2c83cb0a03f599bf8cc3af8da = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d156423a03563e945e12fd197456d332 = $(`&lt;div id=&quot;html_d156423a03563e945e12fd197456d332&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sleeping Giant State Park&lt;/div&gt;`)[0];
#                 popup_650dc7c2c83cb0a03f599bf8cc3af8da.setContent(html_d156423a03563e945e12fd197456d332);
#
#
#
#         marker_2c5a46410b94896eabc5ff52dd2c8020.bindPopup(popup_650dc7c2c83cb0a03f599bf8cc3af8da)
#         ;
#
#
#
#
#             var marker_d445670ae0a47a8503e6a9e6e48089de = L.marker(
#                 [41.3163244, -72.9223431],
#                 {}
#             ).addTo(feature_group_d6fff0591577e133a711af7934919b6e);
#
#
#             var icon_b8ed5825343652beeb7cd4dc0addf205 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d445670ae0a47a8503e6a9e6e48089de.setIcon(icon_b8ed5825343652beeb7cd4dc0addf205);
#
#
#         var popup_bdd07054588775a8da128f2b6d8f1456 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_aa967e3684c029cb4c8c147c27ff1329 = $(`&lt;div id=&quot;html_aa967e3684c029cb4c8c147c27ff1329&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Yale University&lt;/div&gt;`)[0];
#                 popup_bdd07054588775a8da128f2b6d8f1456.setContent(html_aa967e3684c029cb4c8c147c27ff1329);
#
#
#
#         marker_d445670ae0a47a8503e6a9e6e48089de.bindPopup(popup_bdd07054588775a8da128f2b6d8f1456)
#         ;
#
#
#
#
#             var marker_4ba551885c299ea1e74c49f21eb42fa6 = L.marker(
#                 [41.2003752, -73.0676551],
#                 {}
#             ).addTo(feature_group_d6fff0591577e133a711af7934919b6e);
#
#
#             var icon_b1ad26d91513999e67
